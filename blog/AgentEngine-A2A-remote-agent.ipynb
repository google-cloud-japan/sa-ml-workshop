# %% [markdown]
# # A2A リモートエージェントを Agent Engine にデプロイする例
#
# このノートブックは、下記の記事のコードを実行したサンプルです。
#
# - [【Agent Engine の A2A 対応記念】A2A リモートエージェントを Agent Engine にデプロイする](https://zenn.dev/google_cloud_jp/articles/04cdf10fb5cd70)

# %% [markdown]
# ## プロジェクト環境の準備

# %% [markdown]
# 新しいプロジェクトを作成したら、Cloud Shell のコマンド端末を開いて、必要な API を有効化します。
#
# ```
# gcloud services enable \
#   firestore.googleapis.com \
#   aiplatform.googleapis.com \
#   notebooks.googleapis.com \
#   cloudresourcemanager.googleapis.com
# ```
#
# Agent Egnine へのデプロイに必要なサービスアカウントを作成して、IAM ロールを付与しておきます。また、Firestore の DB `context-session-mapping` を作成します。
#
# ```
# PROJECT_ID=$(gcloud config list --format 'value(core.project)' 2>/dev/null)
# PROJECT_NUMBER=$(gcloud projects describe $PROJECT_ID --format='value(projectNumber)' 2>/dev/null)
# gcloud beta services identity create --service=aiplatform.googleapis.com --project=$PROJECT_ID
#
# # root agent が A2A agent を呼び出すために必要
# gcloud projects add-iam-policy-binding $PROJECT_ID \
#     --member="serviceAccount:service-${PROJECT_NUMBER}@gcp-sa-aiplatform-re.iam.gserviceaccount.com" \
#     --role='roles/aiplatform.user'
#
# # A2A agent が firebase にアクセスするために必要
# gcloud projects add-iam-policy-binding $PROJECT_ID \
#     --member="serviceAccount:service-${PROJECT_NUMBER}@gcp-sa-aiplatform-re.iam.gserviceaccount.com" \
#     --role='roles/datastore.user'
#
# gcloud firestore databases create \
#   --database='context-session-mapping' --location=us-central1 --type=firestore-native
# ```
#
# 続いて、Workbench のインスタンスを作成します。
#
# ```
# PROJECT_ID=$(gcloud config list --format 'value(core.project)' 2>/dev/null)
# gcloud workbench instances create development-instance \
#   --project=$PROJECT_ID \
#   --location=us-central1-a \
#   --machine-type=e2-standard-2
# ```
#
# クラウドコンソールのナビゲーションメニューから「Vertex AI」→「Workbench」を選択すると、作成したインスタンス development-instance があります。インスタンスの起動が完了するのを待って、「JUPYTERLAB を開く」をクリックしたら、「Python 3(ipykernel)」の新規ノートブックを作成します。
#
# この後は、ノートブックのセルでコードを実行していきます。

# %% [markdown]
# ## 環境準備

# %%
# %pip install --user --upgrade \
    google-adk==1.27.2 \
    google-genai==1.68.0 \
    google-cloud-aiplatform==1.141.0 \
    google-cloud-firestore==2.25.0 \
    a2a-sdk==0.3.25

# %%
import IPython
app = IPython.Application.instance()
_ = app.kernel.do_shutdown(True)

# %%
import asyncio, datetime, httpx, json, os
from IPython.display import Markdown, display
from google.auth import default
from google.auth.transport.requests import Request
from google.cloud import firestore
import vertexai
from vertexai.agent_engines import AdkApp

# ADK
from google.genai.types import Part, Content, HttpOptions
from google.adk.agents.callback_context import CallbackContext
from google.adk.agents.llm_agent import LlmAgent
from google.adk.agents.remote_a2a_agent import RemoteA2aAgent
from google.adk.agents.sequential_agent import SequentialAgent
from google.adk.artifacts import InMemoryArtifactService
from google.adk.auth.credential_service.in_memory_credential_service import InMemoryCredentialService
from google.adk.memory.in_memory_memory_service import InMemoryMemoryService
from google.adk.models import LlmResponse, LlmRequest
from google.adk.runners import Runner
from google.adk.sessions import VertexAiSessionService

# A2A
from a2a.client import ClientConfig, ClientFactory
from a2a.types import AgentCard, TransportProtocol
from google.adk.a2a.executor.a2a_agent_executor import A2aAgentExecutor
from google.adk.a2a.utils.agent_card_builder import AgentCardBuilder

# Agent Engine
from vertexai import agent_engines
from vertexai.preview.reasoning_engines import A2aAgent
from vertexai.preview.reasoning_engines.templates.a2a import create_agent_card

[PROJECT_ID] = !gcloud config list --format 'value(core.project)' 2>/dev/null
[PROJECT_NUMBER] = !gcloud projects describe {PROJECT_ID} --format='value(projectNumber)' 2>/dev/null
LOCATION = 'us-central1'

vertexai.init(project=PROJECT_ID, location=LOCATION)
os.environ['GOOGLE_CLOUD_PROJECT'] = PROJECT_ID
os.environ['GOOGLE_CLOUD_LOCATION'] = LOCATION
os.environ['GOOGLE_GENAI_USE_VERTEXAI'] = 'True'

STAGING_BUCKET = f'gs://{PROJECT_ID}'
# !gsutil ls -b {STAGING_BUCKET} 2>/dev/null || \
 gsutil mb -b on -l {LOCATION} {STAGING_BUCKET}
# Out:
# Creating gs://etsuji-adk-test-490901/...

# %%
class ChatClient:
    def __init__(self, adk_app, user_id='default_user'):
        self.adk_app = adk_app
        self.user_id = user_id
        self.session_id = None

    async def async_stream_query(self, message, show=True):
        if not self.session_id:
            session = await self.adk_app.async_create_session(
                user_id=self.user_id,
            )
            self.session_id = getattr(session, 'id', None) or session['id']

        result = []
        async for event in self.adk_app.async_stream_query(
            user_id=self.user_id,
            session_id=self.session_id,
            message=message,
        ):
            author = event['author']
            if ('content' in event and 'parts' in event['content']):
                response = '\n'.join(
                    [p['text'] for p in event['content']['parts'] if 'text' in p]
                )
                if response:
                    if show:
                        display(Markdown(response))
                    result.append(response)
        return '\n'.join(result)

# %% [markdown]
# ## リモートエージェントの定義

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
指定されたテーマの記事を執筆する際に参考となるトピックを５項目程度のリストにまとめます。
後段のエージェントがこのリストに基づいて、調査レポートを作成します。

* 出力形式
日本語で出力。
'''

research_agent1 = LlmAgent(
    name='research_agent1',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
前段のエージェントは、５項目程度の調査対象トピックを指定します。

* 出力形式
日本語で出力。
調査レポートは、トピックごとに客観的情報をまとめます。各トピックについて、５文以上の長さで記述すること。
'''

research_agent2 = LlmAgent(
    name='research_agent2',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、特定のテーマに関する気軽な読み物記事を書くことです。
記事の「テーマ」と、その内容に関連する「調査レポート」が与えられるので、
調査レポートに記載の客観的事実に基づいて、信頼性のある読み物記事を書いてください。

**出力条件**
- トピックに関してある程度の基礎知識がある読者を前提として、数分で気軽に読める内容にしてください。
- 比較的カジュアルで語りかける口調の文章にします。
- 思考過程は出力せずに、最終結果だけを出力します。
- 記事タイトルは付けないで、次の構成で出力します。各セクションタイトルは、内容に合わせてアレンジしてください。
0. 導入：セクションタイトルを付けないで、この記事を読みたくなる導入を１〜２文にまとめます。
1. 概要：トピックの全体像をまとめて簡単に説明します。
2. 最新情報：特に注目したい新しい情報を取り上げます。
3. 実践：トピックに関して、読者自身がやってみるとよさそうな事を１つ紹介します。
4. まとめ

- 各セクションのタイトルはマークダウンヘッダ ## 付けます。必要に応じて箇条書きのマークダウンを使用します。
- それ以外のマークダウンによる装飾は行いません。

**レビュアーの指示に応じた修正**
- レビュアーが修正ポイントを提示した際は、出力条件にこだわらずに、直前の記事を指示に従って修正してください。
- 修正ポイント以外の部分は、修正する必要ありません。
'''

writer_agent = LlmAgent(
    name='writer_agent',
    model='gemini-2.5-flash',
    description='特定のテーマに関する読み物記事を書くエージェント',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、読み物記事をレビューして、記事の条件にあった内容にするための改善コメントを与える事です。

* 記事の条件
- 記事は、はじめに４０文字程度のタイトルがあること。
　今日から役立つ生活情報があって「すぐに読まなきゃ」と読者が感じるタイトルにすること。
　タイトルはマークダウンヘッダ # をつけること。
- タイトルの直後に「なぜいまこのテーマを取り上げるのか」をまとめた導入を加えて、読者にこの記事を読む動機づけを与えます。
- 各セクションのサブタイトルには、絵文字を用いて親しみやすさを出すこと。
- 読者が今日から実践できる具体例が３つ以上紹介されていること。

* 出力形式
- 日本語で出力。
- はじめに、記事の良い点を説明します。
- 次に、修正ポイントを箇条書きで出力します。
'''

review_agent = LlmAgent(
    name='review_agent',
    model='gemini-2.5-flash',
    description='読み物記事をレビューするエージェント',
    instruction=instruction,
)

# %% [markdown]
# ## Agent Engine へのデプロイ

# %%
client = vertexai.Client(
    project=PROJECT_ID,
    location=LOCATION,
    http_options=HttpOptions(
        api_version='v1beta1',
        base_url=f'https://{LOCATION}-aiplatform.googleapis.com/'
    ),
)

def get_agent_resource(agent_name):
    for agent in client.agent_engines.list():
        if agent.api_resource.display_name == agent_name:
            return agent.api_resource.name
    return None

# %%
class MyVertexAiSessionService(VertexAiSessionService):
    """
    A wrapper for VertexAiSessionService that persists the mapping between
    the A2A context_id and the Vertex-generated session_id in Firestore
    """
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        agent_engine_id = os.environ.get('GOOGLE_CLOUD_AGENT_ENGINE_ID')
        self.collection_name = f'AgentEngine-{agent_engine_id}'
        self.firestore_client = firestore.Client(database='context-session-mapping')

    def set_session_id(self, user_id, context_id, session_id):
        key = f'User-{user_id}-Context-{context_id}'
        doc_ref = self.firestore_client.collection(self.collection_name).document(key)
        doc_ref.set({'session_id': session_id}) 
        print(f"Persisted mapping: context_id '{context_id}' -> session_id '{session_id}'", flush=True)

    def get_session_id(self, user_id, context_id):
        key = f'User-{user_id}-Context-{context_id}'
        doc_ref = self.firestore_client.collection(self.collection_name).document(key)
        doc = doc_ref.get()
        if doc.exists:
            session_id = doc.to_dict().get('session_id')
            print(f"Found mapping: context_id '{context_id}' -> session_id '{session_id}'.", flush=True)
            return session_id
        else:
            print(f"Not found mapping for context_id '{context_id}'.", flush=True)
            return None

    async def create_session(
        self, app_name, user_id, state={}, session_id=None # A2A context_id
    ):
        real_session_id = None
        context_id = session_id if session_id else None

        # Create the session in Vertex AI, which will generate its own unique ID.
        session = await super().create_session(
            app_name=app_name,
            user_id=user_id,
            state=state,
        )
        real_session_id = session.id
        print(f"Created new Vertex session '{real_session_id}' for user '{user_id}'.", flush=True)

        # If a context_id was provided, persist the mapping.
        if context_id:
            self.set_session_id(user_id, context_id, real_session_id)

        return session

    async def get_session(
        self, app_name, user_id, session_id, # A2A context_id
        config=None,
    ):
        context_id = session_id
        real_session_id = self.get_session_id(user_id, context_id)
        
        # Create a new session if not exist.
        if real_session_id is None:
            new_session = await self.create_session(
                app_name=app_name,
                user_id=user_id,
                session_id=context_id,
            )
            real_session_id = new_session.id
            
        session = await super().get_session(
            app_name=app_name,
            user_id=user_id,
            session_id=real_session_id,
            config=config,
        )

        return session


def get_create_runner_class(agent):
    async def create_runner():
        project_id = os.environ.get('GOOGLE_CLOUD_PROJECT')
        location = os.environ.get('GOOGLE_CLOUD_LOCATION')
        agent_engine_id = os.environ.get('GOOGLE_CLOUD_AGENT_ENGINE_ID')
        resource_name = None
        if project_id and location and agent_engine_id:
            resource_name = f'projects/{project_id}/locations/{location}/reasoningEngines/{agent_engine_id}'
        return Runner(
            # Use resource_name as app_name for VertexAiSessionService.
            app_name=resource_name or agent.name,
            agent=agent,
            artifact_service=InMemoryArtifactService(),
            session_service=MyVertexAiSessionService(),
            memory_service=InMemoryMemoryService(),
            credential_service=InMemoryCredentialService(),
        )
    return create_runner


def get_agent_executor_class(agent):
    def agent_executor_builder():
        return A2aAgentExecutor(
            runner=get_create_runner_class(agent),
        )       
    return agent_executor_builder


async def get_agent_card(agent):
    builder = AgentCardBuilder(agent=agent)
    adk_agent_card = await builder.build()
    return create_agent_card(
        agent_name=adk_agent_card.name,
        description=adk_agent_card.description,
        skills=adk_agent_card.skills
    )

# %%
agents = {
    'research_agent1_a2a': research_agent1,
    'research_agent2_a2a': research_agent2,
    'writer_agent_a2a': writer_agent,
    'review_agent_a2a': review_agent,
}

async def deploy_or_update_agent(agent_name, agent, client, staging_bucket):
    a2a_agent = A2aAgent(
        agent_card=await get_agent_card(agent),
        agent_executor_builder=get_agent_executor_class(agent)
    )

    config = {
        'display_name': agent_name,
        'description': a2a_agent.agent_card.description,
        'requirements': [
            'google-adk==1.27.2',
            'google-genai==1.68.0',
            'google-cloud-aiplatform==1.141.0',
            'google-cloud-firestore==2.25.0',
            'a2a-sdk==0.3.25',
        ],
        'staging_bucket': staging_bucket,
        'gcs_dir_name': f'{agent_name}-{datetime.datetime.now().strftime("%Y%m%d-%H%M%S%f")}',
    }

    resource_name = get_agent_resource(agent_name)
    
    if resource_name is None:
        print(f'Deploying... {agent_name}: {agent.description}')
        remote_a2a_agent = await asyncio.to_thread(
            client.agent_engines.create,
            agent=a2a_agent,
            config=config,
        )
    else:
        print(f'Updating... {agent_name}: {agent.description}')
        remote_a2a_agent = await asyncio.to_thread(
            client.agent_engines.update,
            name=resource_name,
            agent=a2a_agent,
            config=config,
        )
        
    return remote_a2a_agent

async def deploy_all_agents():
    tasks = [
        deploy_or_update_agent(agent_name, agent, client, STAGING_BUCKET)
        for agent_name, agent in agents.items()
    ]
    results = await asyncio.gather(*tasks)
    return results

await deploy_all_agents()
# Out:
# /var/tmp/ipykernel_184622/716963542.py:106: UserWarning: [EXPERIMENTAL] AgentCardBuilder: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   builder = AgentCardBuilder(agent=agent)
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# Updating... research_agent1_a2a: 記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）
# Updating... research_agent2_a2a: 記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）
# Updating... writer_agent_a2a: 特定のテーマに関する読み物記事を書くエージェント
# Updating... review_agent_a2a: 読み物記事をレビューするエージェント
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# [AgentEngine(api_resource.name='projects/313025352162/locations/us-central1/reasoningEngines/1449737417304047616'),
#  AgentEngine(api_resource.name='projects/313025352162/locations/us-central1/reasoningEngines/7994312100803510272'),
#  AgentEngine(api_resource.name='projects/313025352162/locations/us-central1/reasoningEngines/4111364797080010752'),
#  AgentEngine(api_resource.name='projects/313025352162/locations/us-central1/reasoningEngines/2879630298994180096')]

# %% [markdown]
# ## RemoteA2aAgent を用いた root agent の定義

# %%
class GoogleAuthRefresh(httpx.Auth):
    def __init__(self, scopes):
        self.credentials, _ = default(scopes=scopes)
        self.transport_request = Request()
        self.credentials.refresh(self.transport_request)

    def auth_flow(self, request):
        if not self.credentials.valid:
            self.credentials.refresh(self.transport_request)
        request.headers['Authorization'] = f'Bearer {self.credentials.token}'
        yield request


factory = ClientFactory(
    ClientConfig(
        supported_transports=[TransportProtocol.http_json],
        use_client_preference=True,
        httpx_client=httpx.AsyncClient(
            timeout=60,
            headers={'Content-Type': 'application/json'},
            auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
        ),
    ),
)

# %%
resource_name = get_agent_resource('research_agent1_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
research_agent1_remote = RemoteA2aAgent(
    name="research_agent1",
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('research_agent2_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
research_agent2_remote = RemoteA2aAgent(
    name="research_agent2",
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('writer_agent_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
writer_agent_remote = RemoteA2aAgent(
    name="writer_agent",
    description='特定のテーマに関する読み物記事を書くエージェント',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('review_agent_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
review_agent_remote = RemoteA2aAgent(
    name="review_agent",
    description='読み物記事をレビューするエージェント',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)
# Out:
# /var/tmp/ipykernel_184622/1893291524.py:3: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent1_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_184622/1893291524.py:12: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent2_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_184622/1893291524.py:21: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   writer_agent_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_184622/1893291524.py:30: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   review_agent_remote = RemoteA2aAgent(

# %%
def get_print_agent(text):
    def before_model_callback(
        callback_context: CallbackContext, llm_request: LlmRequest
    ) -> LlmResponse:
        return LlmResponse(
            content=Content(
                role='model', parts=[Part(text=text)],
            )
        )
    return LlmAgent(
        name='print_agent',
        model='gemini-2.5-flash', # not used
        description='',
        instruction = '',
        before_model_callback=before_model_callback,
    )

research_agent = SequentialAgent(
    name='research_agent',
    sub_agents=[
        get_print_agent('\n---\n## リサーチエージェントが調査レポートを作成します。\n---\n'),
        get_print_agent('\n## 調査対象のトピックを選定します。\n'),
        research_agent1_remote,
        get_print_agent('\n## 選定したトピックに基づいて、調査レポートを作成します。\n'),
        research_agent2_remote,
        get_print_agent('\n#### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？\n'),
    ],
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント',
)

write_and_review_agent = SequentialAgent(
    name='write_and_review_agent',
    sub_agents=[
        get_print_agent('\n---\n## ライターエージェントが記事を執筆します。\n---\n'),
        writer_agent_remote,
        get_print_agent('\n---\n## レビューエージェントが記事をレビューします。\n---\n'),
        review_agent_remote,
       get_print_agent('\n#### レビューに基づいて記事の修正を依頼しますか？\n'),
    ],
    description='記事を作成、レビューする。',
)

root_agent = LlmAgent(
    name='article_generation_flow',
    model='gemini-2.5-flash',
    instruction = '''
何ができるか聞かれた場合は、以下の処理をすることをわかりやすくフレンドリーな文章にまとめて返答してください。

- ユーザーが指定したテーマの記事を作成する業務フローを実行する。
- はじめに、テーマに関する調査レポートを作成する。
- その後、ライターエージェントとレビューエージェントが協力して、編集方針に則した記事を作成する。

ユーザーが記事のテーマを指定した場合は、次のフローを実行します。

1. そのテーマの記事の作成に取り掛かる旨を伝えて、research_agent に転送して、調査レポートを依頼します。
2. ユーザー記事の作成を指示したら、write_and_review_agent に転送して、記事の作成とレビューを依頼します。
3. ユーザーが記事の修正を希望する場合は、write_and_review_agent に転送します。

**条件**
research_agent のニックネームは、リサーチエージェント
write_and_review_agent のネックネームは、ライターエージェントとレビューエージェント

''',
    sub_agents=[
        research_agent,
        write_and_review_agent,
    ],
    description='記事を作成する業務フローを実行するエージェント'
)


adk_app = AdkApp(
    agent=root_agent,
    app_name='article_generation_app',
)
# Out:
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.

# %% [markdown]
# ## 実行例

# %%
chat_client = ChatClient(adk_app)

query = '''
こんにちは。何ができますか？
'''
response = await chat_client.async_stream_query(query)
# Out:
# こんにちは！私は記事作成の業務フローを実行するエージェントです。
#
# 具体的には、以下のようなことができます。
#
# *   ユーザーさんが指定したテーマに関する**記事の作成業務フロー**を進めます。
# *   まず、テーマについて**リサーチエージェント**が徹底的に調査し、調査レポートを作成します。
# *   その後、**ライターエージェント**と**レビューエージェント**が協力して、編集方針に沿った質の高い記事を作成します。
#
# もし記事のテーマを指定していただければ、リサーチエージェントが調査レポートを作成し、その後ライターエージェントとレビューエージェントが記事を執筆・レビューいたします。記事の修正のご希望にも対応できますので、お気軽にお申し付けください！

# %%
query = '''
「近場で秋を感じる工夫」をテーマに記事を作成してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 承知いたしました。「近場で秋を感じる工夫」をテーマにした記事の作成に取り掛かります。
#
# まずは、リサーチエージェントにこのテーマに関する調査レポートの作成を依頼しますね。
# ---
# ## リサーチエージェントが調査レポートを作成します。
# ---
# ## 調査対象のトピックを選定します。
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# はい、承知いたしました。「近場で秋を感じる工夫」に関する記事作成のための調査レポートを作成します。
#
# まずは、以下の5つのトピックについて調査を進めます。
#
# ---
#
# ### **「近場で秋を感じる工夫」調査レポート用トピックリスト**
#
# 1.  **自宅で手軽に秋を取り入れるアイデア：** インテリア小物、香り、音楽、読書など、家の中で季節感を演出する方法。
# 2.  **近所の散歩で見つける「秋の気配」：** 公園や街路樹、道端で紅葉、落ち葉、木の実、秋の草花、虫の声など、身近な自然から秋を感じるヒント。
# 3.  **五感を刺激する秋の味覚体験：** 旬の食材を使った簡単なレシピ、地元のスーパーやマルシェで手に入る秋の味覚、秋限定のスイーツや飲み物。
# 4.  **五感で楽しむ秋の過ごし方：** 視覚（秋の色）、聴覚（虫の声、風の音）、嗅覚（キンモクセイの香り）、触覚（肌で感じる空気）、味覚（旬の食べ物）を通じて秋を深める方法。
# 5.  **近場で体験できる秋のアクティビティ：** 地域のお祭りやイベント、身近なカフェやお店の秋限定サービス、簡単な秋のDIYや写真撮影など。
#
# ---
# ## 選定したトピックに基づいて、調査レポートを作成します。
# ## 調査レポート：「近場で秋を感じる工夫」
#
# ### 1. 自宅で手軽に秋を取り入れるアイデア
#
# 自宅で秋を感じる工夫としては、インテリアに季節の要素を取り入れることが効果的です。例えば、オレンジ、ブラウン、深緑などの暖色系のクッションカバーやブランケットをソファに置いたり、木の実や落ち葉を飾ったりすることで、視覚的に秋の雰囲気を演出できます。また、アロマディフューザーでキンモクセイ、アップルシナモン、ウッディ系などの秋らしい香りを部屋に広げることで、嗅覚からも季節感を楽しめます。BGMとして、穏やかなジャズやクラシック音楽、焚き火の音などを流すことも、リラックスした秋の夜長を過ごすのに寄与します。さらに、秋の夜長を利用して、温かい飲み物を片手に秋をテーマにした小説やエッセイを読むことで、内面からも季節の移ろいを感じることができます。これらのアイデアは、大掛かりな模様替えをせずとも手軽に実践できるため、多くの人々に取り入れられています。
#
# ### 2. 近所の散歩で見つける「秋の気配」
#
# 近所の公園や街路樹を散歩するだけでも、多くの秋の気配を発見できます。特に、モミジやイチョウが色づき始める紅葉は、視覚的に秋の到来を知らせる最も分かりやすいサインの一つです。足元にはカサカサと音を立てる落ち葉が敷き詰められ、その感触や音も秋ならではのものです。公園の木々には、ドングリや栗、柿などの木の実が実り始め、これらを探すのも楽しい秋の散歩の醍醐味です。また、道端にはコスモスやススキ、彼岸花といった秋の草花が咲き誇り、季節の移ろいを感じさせます。夕暮れ時には、コオロギや鈴虫などの虫の声が響き渡り、聴覚からも秋の深まりを感じることができます。
#
# ### 3. 五感を刺激する秋の味覚体験
#
# 秋は「食欲の秋」とも言われるように、旬の食材を通じて五感を刺激する絶好の機会です。地元のスーパーやマルシェでは、栗、さつまいも、きのこ、新米、梨、柿など、多種多様な秋の味覚が手に入ります。これらの旬の食材を使った簡単なレシピ、例えば栗ご飯、きのこのソテー、焼き芋、梨のコンポートなどは、自宅で手軽に秋の味覚を楽しむ方法です。多くのカフェや洋菓子店では、モンブラン、かぼちゃプリン、栗きんとんなどの秋限定スイーツが販売され、特別な甘味で季節を感じさせます。また、ホットワインや日本酒のひやおろし、秋限定のフレーバーティーなども、秋の食事を彩る飲み物として人気があります。
#
# ### 4. 五感で楽しむ秋の過ごし方
#
# 秋は五感をフル活用して楽しむのに最適な季節です。視覚的には、燃えるような赤や鮮やかな黄色に染まる紅葉、夕焼けのグラデーション、クリアな空気の中で見上げる夜空の星々が感動を与えます。聴覚は、風が吹き抜ける音、落ち葉が舞う音、そしてコオロギや鈴虫の澄んだ鳴き声が秋の情景を際立たせます。嗅覚で特に印象的なのは、甘く上品なキンモクセイの香りで、街中に広がるその香りは秋の訪れを強く意識させます。肌で感じるひんやりとした秋の空気は、夏との違いを明確にし、心地よい季節の移ろいを体感させます。そして、味覚においては、前述の通り旬の食材が豊富であり、栗やきのこ、さつまいも、新米などの豊かな風味を楽しむことができます。
#
# ### 5. 近場で体験できる秋のアクティビティ
#
# 近場でも、秋を満喫できる様々なアクティビティが楽しめます。地域によっては、収穫祭や紅葉祭り、ハロウィンイベントなど、秋限定のお祭りが開催され、地元の文化や賑わいに触れる良い機会です。身近なカフェやレストランでは、秋の食材を使った期間限定メニューやスイーツが提供され、特別感を味わうことができます。また、公園や河川敷などで、秋の風景を背景に写真撮影を楽しむ人々も多く見られます。自宅で簡単にできる秋のDIYとして、落ち葉や木の実を使ったリース作りや、ハロウィンの飾り付けなども人気があります。これらのアクティビティは、遠出をせずとも秋の豊かな魅力を体験させてくれます。
# #### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました！調査レポートを元に、ライターエージェントとレビューエージェントが「近場で秋を感じる工夫」に関する記事の作成とレビューを行います。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# 秋の気配を感じたいけれど、遠出はなかなか難しい…」なんて思っていませんか？実は、わざわざ遠出しなくても、私たちの身近な場所にはたくさんの「秋」が隠れているんです。
#
# ## 身近に潜む秋のヒント
#
# 秋の訪れは、実は私たちのすぐ近くで感じられます。自宅のインテリアに温かい色合いのクッションを加えたり、アロマで秋らしい香りを漂わせたりするだけで、ぐっと季節感が増します。近所を散歩すれば、色づき始めた葉や、カサカサと音を立てる落ち葉、そしてドングリなどの木の実に出会えます。スーパーに並ぶ栗やさつまいも、きのこなどの旬の食材も、食卓から秋を感じさせてくれる大切な要素です。五感を意識して過ごすだけで、いつもの日常が秋色に染まりますよ。
#
# ## 五感を研ぎ澄ます、新しい秋の楽しみ方
#
# 最近は、より繊細な感覚で秋を楽しむ方法が注目されています。例えば、デジタルツールを活用して、焚き火の音や虫の声をBGMとして流すことで、家の中にいながらにして自然の中の秋を演出できます。また、地域によっては、秋限定のカフェメニューや地元の収穫祭など、その土地ならではの秋の恵みを楽しむイベントが開催されることも。これらは、普段の生活にちょっとした特別感をプラスし、新たな発見をもたらしてくれます。キンモクセイの甘い香りや、ひんやりとした秋の空気など、五感を意識して日常を過ごすことが、秋を深める新しいカギになるでしょう。
#
# ## 今日からできる「秋の五感散歩」
#
# 「よし、秋を感じてみよう！」と思ったら、まずは近所の公園やいつもの散歩道を、ちょっとだけ「五感」を意識して歩いてみませんか？
#
# *   **視覚:** 赤や黄色に色づいた葉、夕焼け空の色合い。
# *   **聴覚:** 落ち葉を踏む音、風の音、夕暮れの虫の声。
# *   **嗅覚:** 金木犀の甘い香り、土の匂い、焼き芋の香り（運が良ければ！）。
# *   **触覚:** ひんやりとした空気、カサカサの落ち葉の感触。
#
# 普段何気なく通り過ぎていた景色の中に、きっと新しい秋の表情が見つかるはずです。
#
# ## まとめ
#
# 遠くへ行かなくても、工夫次第で秋は私たちのすぐそばにあります。自宅で、散歩中に、そして食卓で、五感をフルに使って身近な秋を見つけてみてください。そうすることで、何気ない日常が、きっともっと豊かで心安らぐ時間になるはずです。今年の秋は、ぜひ「近場の秋」を存分に楽しんでみませんか？
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 記事の良い点としては、以下の点が挙げられます。
#
# *   「近場で秋を感じる工夫」というテーマに沿った内容が具体的に書かれています。
# *   自宅、散歩、食卓など、多様な場面での秋の感じ方を紹介しており、読者が共感しやすいです。
# *   五感を意識したアプローチが強調されており、単なる情報提供に留まらない深みがあります。
# *   全体的に親しみやすく、読みやすい文章で構成されています。
#
# しかし、記事の要件を満たすために、いくつか修正が必要な点があります。
#
# ### 修正ポイント
#
# *   **タイトル:** 記事の冒頭に、40文字程度の「今日から役立つ生活情報があって『すぐに読まなきゃ』と読者が感じる」タイトルをマークダウンヘッダ `#` で追加してください。
# *   **導入:** タイトルの直後に「なぜいまこのテーマを取り上げるのか」をまとめた導入文（読者にこの記事を読む動機づけを与える内容）を追加してください。現在の記事冒頭の文章を調整して活用できます。
# *   **サブタイトル:** 各セクションのサブタイトルに、絵文字を加えて親しみやすさを出してください。
# *   **具体例の提示:** 「読者が今日から実践できる具体例」を3つ以上、箇条書きなどで明確に示し、より実践しやすくしてください。現在の「今日からできる「秋の五感散歩」」のセクションは良いですが、さらに独立した具体的な行動としてまとめられると、読者にとって分かりやすくなります。
# #### レビューに基づいて記事の修正を依頼しますか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。レビューエージェントの指摘に基づき、ライターエージェントとレビューエージェントが記事の修正を行います。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# # 遠出しなくても大丈夫！今日から始める「近場で秋を感じる」3つの秘訣
#
# 「秋の気配を感じたいけれど、遠出はなかなか難しい…」なんて思っていませんか？実は、わざわざ遠出しなくても、私たちの身近な場所にはたくさんの「秋」が隠れているんです。日々の忙しさの中で季節の移ろいを見過ごしがちな今だからこそ、この記事を読んで、心豊かな秋を身近で発見するヒントを見つけましょう。
#
# ## 身近に潜む秋のヒント🍂
#
# 秋の訪れは、実は私たちのすぐ近くで感じられます。自宅のインテリアに温かい色合いのクッションを加えたり、アロマで秋らしい香りを漂わせたりするだけで、ぐっと季節感が増します。近所を散歩すれば、色づき始めた葉や、カサカサと音を立てる落ち葉、そしてドングリなどの木の実に出会えます。スーパーに並ぶ栗やさつまいも、きのこなどの旬の食材も、食卓から秋を感じさせてくれる大切な要素です。五感を意識して過ごすだけで、いつもの日常が秋色に染まりますよ。
#
# ## 五感を研ぎ澄ます、新しい秋の楽しみ方👂✨
#
# 最近は、より繊細な感覚で秋を楽しむ方法が注目されています。例えば、デジタルツールを活用して、焚き火の音や虫の声をBGMとして流すことで、家の中にいながらにして自然の中の秋を演出できます。また、地域によっては、秋限定のカフェメニューや地元の収穫祭など、その土地ならではの秋の恵みを楽しむイベントが開催されることも。これらは、普段の生活にちょっとした特別感をプラスし、新たな発見をもたらしてくれます。キンモクセイの甘い香りや、ひんやりとした秋の空気など、五感を意識して日常を過ごすことが、秋を深める新しいカギになるでしょう。
#
# ## 今日からできる！身近な場所で秋を見つける実践アイデア3選🚶‍♀️🏠🍽️
#
# 「よし、秋を感じてみよう！」と思ったら、ぜひ今日からこれらのアイデアを試してみてください。
#
# *   **自宅で秋の香りに包まれる🍂**
#     *   アロマディフューザーでキンモクセイ、アップルシナモン、ウッディ系などの秋らしい香りを部屋に広げてみましょう。お気に入りの香りが、リラックスした秋の空間を演出してくれます。
# *   **いつもの道を「五感散歩」する🚶‍♀️**
#     *   近所の公園やいつもの散歩道を、ちょっとだけ「五感」を意識して歩いてみませんか？
#         *   **視覚:** 赤や黄色に色づいた葉、夕焼け空の色合い。
#         *   **聴覚:** 落ち葉を踏む音、風の音、夕暮れの虫の声。
#         *   **嗅覚:** 金木犀の甘い香り、土の匂い。
#         *   **触覚:** ひんやりとした空気、カサカサの落ち葉の感触。
#     普段何気なく通り過ぎていた景色の中に、きっと新しい秋の表情が見つかるはずです。
# *   **食卓で旬の味覚を味わう🍽️**
#     *   地元のスーパーやマルシェで、栗、さつまいも、きのこ、新米、梨、柿など、秋の旬の食材を探してみましょう。それらを使った簡単なレシピ（栗ご飯、きのこのソテー、焼き芋など）に挑戦して、秋の恵みを食卓で楽しむのも良いアイデアです。
#
# ## まとめ🍁
#
# 遠くへ行かなくても、工夫次第で秋は私たちのすぐそばにあります。自宅で、散歩中に、そして食卓で、五感をフルに使って身近な秋を見つけてみてください。そうすることで、何気ない日常が、きっともっと豊かで心安らぐ時間になるはずです。今年の秋は、ぜひ「近場の秋」を存分に楽しんでみませんか？
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 以前のレビューを踏まえた修正、お疲れ様でした。記事の全ての条件が満たされており、素晴らしい内容になっています。
#
# ### 記事の良い点
#
# *   **魅力的なタイトルと導入:** 40文字程度の「すぐに読まなきゃ」と思わせるタイトルと、その直後の「なぜ今このテーマを取り上げるのか」を明確にした導入が追加され、読者の関心を引きつけ、読み進める動機付けができています。
# *   **親しみやすいサブタイトル:** 全てのサブタイトルに絵文字が効果的に使われており、記事全体が親しみやすく、視覚的にも楽しい印象を与えています。
# *   **実践的な具体例:** 「今日からできる！身近な場所で秋を見つける実践アイデア3選」として、具体的で分かりやすい行動が3つ以上明確に提示されており、読者がすぐに実践できる内容になっています。
# *   **五感を意識した構成:** 全体を通して「五感」をキーワードに秋の感じ方を紹介しており、記事に深みと説得力が増しています。
# *   **読みやすい文章:** 全体的に、読者にとって分かりやすく、共感を呼ぶ丁寧な文章で書かれています。
#
# ### 修正ポイント
#
# 今回の修正で全ての要件が満たされていますので、**修正点はありません。** 素晴らしい記事に仕上がりました！
# #### レビューに基づいて記事の修正を依頼しますか？

# %%
query = '''
これで完成です。完成した記事を表示してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。レビューが完了し、全ての要件を満たした記事が完成しました。
#
# 以下が最終版の記事です。
#
# # 遠出しなくても大丈夫！今日から始める「近場で秋を感じる」3つの秘訣
#
# 「秋の気配を感じたいけれど、遠出はなかなか難しい…」なんて思っていませんか？実は、わざわざ遠出しなくても、私たちの身近な場所にはたくさんの「秋」が隠れているんです。日々の忙しさの中で季節の移ろいを見過ごしがちな今だからこそ、この記事を読んで、心豊かな秋を身近で発見するヒントを見つけましょう。
#
# ## 身近に潜む秋のヒント🍂
#
# 秋の訪れは、実は私たちのすぐ近くで感じられます。自宅のインテリアに温かい色合いのクッションを加えたり、アロマで秋らしい香りを漂わせたりするだけで、ぐっと季節感が増します。近所を散歩すれば、色づき始めた葉や、カサカサと音を立てる落ち葉、そしてドングリなどの木の実に出会えます。スーパーに並ぶ栗やさつまいも、きのこなどの旬の食材も、食卓から秋を感じさせてくれる大切な要素です。五感を意識して過ごすだけで、いつもの日常が秋色に染まりますよ。
#
# ## 五感を研ぎ澄ます、新しい秋の楽しみ方👂✨
#
# 最近は、より繊細な感覚で秋を楽しむ方法が注目されています。例えば、デジタルツールを活用して、焚き火の音や虫の声をBGMとして流すことで、家の中にいながらにして自然の中の秋を演出できます。また、地域によっては、秋限定のカフェメニューや地元の収穫祭など、その土地ならではの秋の恵みを楽しむイベントが開催されることも。これらは、普段の生活にちょっとした特別感をプラスし、新たな発見をもたらしてくれます。キンモクセイの甘い香りや、ひんやりとした秋の空気など、五感を意識して日常を過ごすことが、秋を深める新しいカギになるでしょう。
#
# ## 今日からできる！身近な場所で秋を見つける実践アイデア3選🚶‍♀️🏠🍽️
#
# 「よし、秋を感じてみよう！」と思ったら、ぜひ今日からこれらのアイデアを試してみてください。
#
# *   **自宅で秋の香りに包まれる🍂**
#     *   アロマディフューザーでキンモクセイ、アップルシナモン、ウッディ系などの秋らしい香りを部屋に広げてみましょう。お気に入りの香りが、リラックスした秋の空間を演出してくれます。
# *   **いつもの道を「五感散歩」する🚶‍♀️**
#     *   近所の公園やいつもの散歩道を、ちょっとだけ「五感」を意識して歩いてみませんか？
#         *   **視覚:** 赤や黄色に色づいた葉、夕焼け空の色合い。
#         *   **聴覚:** 落ち葉を踏む音、風の音、夕暮れの虫の声。
#         *   **嗅覚:** 金木犀の甘い香り、土の匂い。
#         *   **触覚:** ひんやりとした空気、カサカサの落ち葉の感触。
#     普段何気なく通り過ぎていた景色の中に、きっと新しい秋の表情が見つかるはずです。
# *   **食卓で旬の味覚を味わう🍽️**
#     *   地元のスーパーやマルシェで、栗、さつまいも、きのこ、新米、梨、柿など、秋の旬の食材を探してみましょう。それらを使った簡単なレシピ（栗ご飯、きのこのソテー、焼き芋など）に挑戦して、秋の恵みを食卓で楽しむのも良いアイデアです。
#
# ## まとめ🍁
#
# 遠くへ行かなくても、工夫次第で秋は私たちのすぐそばにあります。自宅で、散歩中に、そして食卓で、五感をフルに使って身近な秋を見つけてみてください。そうすることで、何気ない日常が、きっともっと豊かで心安らぐ時間になるはずです。今年の秋は、ぜひ「近場の秋」を存分に楽しんでみませんか？

# %% [markdown]
# ## root agent を Agent Engine にデプロイ

# %%
class MyClientFactory(ClientFactory):
    def create(self, card, consumers=None, interceptors=None):
        if not self._config.httpx_client:
            self._config.httpx_client=httpx.AsyncClient(
                timeout=60,
                headers={'Content-Type': 'application/json'},
                auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
            )
            self._register_defaults(self._config.supported_transports)
        return super().create(card, consumers, interceptors)


class MyRemoteA2aAgent(RemoteA2aAgent):
    async def _ensure_httpx_client(self):
        if not self._httpx_client:
            self._httpx_client=httpx.AsyncClient(
                timeout=60,
                headers={'Content-Type': 'application/json'},
                auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
            )
        return self._httpx_client


factory = MyClientFactory(
    ClientConfig(
        supported_transports=[TransportProtocol.http_json],
        use_client_preference=True,
    )
)

resource_name = get_agent_resource('research_agent1_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
research_agent1_remoteA2a = MyRemoteA2aAgent(
    name='research_agent1',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('research_agent2_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
research_agent2_remoteA2a = MyRemoteA2aAgent(
    name='research_agent2',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('writer_agent_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
writer_agent_remoteA2a = MyRemoteA2aAgent(
    name='writer_agent',
    description='特定のテーマに関する読み物記事を書くエージェント',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('review_agent_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
review_agent_remoteA2a = MyRemoteA2aAgent(
    name='review_agent',
    description='読み物記事をレビューするエージェント',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

def get_print_agent(text):
    def before_model_callback(
        callback_context: CallbackContext, llm_request: LlmRequest
    ) -> LlmResponse:
        return LlmResponse(
            content=Content(
                role='model', parts=[Part(text=text)],
            )
        )
    return LlmAgent(
        name='print_agent',
        model='gemini-2.5-flash', # not used
        description='',
        instruction = '',
        before_model_callback=before_model_callback,
    )

research_agent = SequentialAgent(
    name='research_agent',
    sub_agents=[
        get_print_agent('\n---\n## リサーチエージェントが調査レポートを作成します。\n---\n'),
        get_print_agent('\n## 調査対象のトピックを選定します。\n'),
        research_agent1_remoteA2a,
        get_print_agent('\n## 選定したトピックに基づいて、調査レポートを作成します。\n'),
        research_agent2_remoteA2a,
        get_print_agent('\n#### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？\n'),
    ],
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント',
)

write_and_review_agent = SequentialAgent(
    name='write_and_review_agent',
    sub_agents=[
        get_print_agent('\n---\n## ライターエージェントが記事を執筆します。\n---\n'),
        writer_agent_remoteA2a,
        get_print_agent('\n---\n## レビューエージェントが記事をレビューします。\n---\n'),
        review_agent_remoteA2a,
       get_print_agent('\n#### レビューに基づいて記事の修正を依頼しますか？\n'),
    ],
    description='記事を作成、レビューする。',
)

root_agent = LlmAgent(
    name='article_generation_flow',
    model='gemini-2.5-flash',
    instruction = '''
何ができるか聞かれた場合は、以下の処理をすることをわかりやすくフレンドリーな文章にまとめて返答してください。

- ユーザーが指定したテーマの記事を作成する業務フローを実行する。
- はじめに、テーマに関する調査レポートを作成する。
- その後、ライターエージェントとレビューエージェントが協力して、編集方針に則した記事を作成する。

ユーザーが記事のテーマを指定した場合は、次のフローを実行します。

1. そのテーマの記事の作成に取り掛かる旨を伝えて、research_agent に転送して、調査レポートを依頼します。
2. ユーザー記事の作成を指示したら、write_and_review_agent に転送して、記事の作成とレビューを依頼します。
3. ユーザーが記事の修正を希望する場合は、write_and_review_agent に転送します。

**条件**
research_agent のニックネームは、リサーチエージェント
write_and_review_agent のネックネームは、ライターエージェントとレビューエージェント

''',
    sub_agents=[
        research_agent,
        write_and_review_agent,
    ],
    description='記事を作成する業務フローを実行するエージェント'
)

adk_app = AdkApp(
    agent=root_agent,
    app_name='article_generation_app',
)
# Out:
# /var/tmp/ipykernel_184622/1283827700.py:33: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent1_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_184622/1283827700.py:42: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent2_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_184622/1283827700.py:51: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   writer_agent_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_184622/1283827700.py:60: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   review_agent_remoteA2a = MyRemoteA2aAgent(
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.

# %%
agent_name = adk_app._tmpl_attrs['agent'].name
description = adk_app._tmpl_attrs['agent'].description

config = {
    'agent_framework': 'google-adk',
    'display_name': agent_name,
    'description': description,
    'requirements': [
        'google-adk==1.27.2',
        'google-genai==1.68.0',
        'google-cloud-aiplatform==1.141.0',
        'a2a-sdk==0.3.25'
    ],
    'staging_bucket': f'gs://{PROJECT_ID}',
    'gcs_dir_name': f'{agent_name}-{datetime.datetime.now().strftime("%Y%m%d-%H%M%S%f")}',
}
    
resource_name = get_agent_resource(agent_name)
   
if resource_name is None:
    print(f'Deploying... {agent_name}: {description}')
    remote_app = client.agent_engines.create(
        agent=adk_app,
        config=config,
    )
else:
    print(f'Updating... {agent_name}: {description}')
    remote_app = client.agent_engines.update(
        name=resource_name,
        agent=adk_app,
        config=config,
    )
# Out:
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# Updating... article_generation_flow: 記事を作成する業務フローを実行するエージェント

# %%
chat_client = ChatClient(remote_app)

query = '''
こんにちは。何ができますか？
'''
response = await chat_client.async_stream_query(query)
# Out:
# こんにちは！私はユーザーさんが指定したテーマで記事を作成するお手伝いができます。
#
# 具体的には、このような流れで進めますね。
#
# *   まず、ご指定のテーマに関する**調査レポート**を作成します。
# *   その後、**ライターエージェント**と**レビューエージェント**が協力して、編集方針に沿った記事を作成します。
#
# もし、記事のテーマを指定してくださった場合は、私が以下のように対応します。
#
# 1.  記事の作成に取り掛かる旨をお伝えし、**リサーチエージェント**に転送して調査レポートの作成を依頼します。
# 2.  記事の作成を指示された場合は、**ライターエージェントとレビューエージェント**に転送して、記事の作成とレビューを依頼します。
# 3.  記事の修正をご希望される場合も、**ライターエージェントとレビューエージェント**に転送して対応します。
#
# 何か記事にしたいテーマがあれば、ぜひ教えてくださいね！

# %%
query = '''
「近場で秋を感じる工夫」をテーマに記事を作成してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。「近場で秋を感じる工夫」をテーマに記事を作成しますね。まずは、このテーマに関する調査レポートをリサーチエージェントに依頼します。
# ---
# ## リサーチエージェントが調査レポートを作成します。
# ---
# ## 調査対象のトピックを選定します。
# 承知いたしました。「近場で秋を感じる工夫」というテーマで、記事執筆に役立つ調査トピックを以下に選定します。
#
# ---
# ### 調査レポートのトピックリスト：近場で秋を感じる工夫
#
# 1.  **身近な自然で秋を見つける楽しみ方**
#     *   公園、庭、街路樹などで見られる紅葉、落ち葉、木の実などの自然の変化の探し方。
#     *   近所での散歩やウォーキングをより楽しむための視点やアイデア。
#     *   ベランダや室内で楽しめる秋の植物（鑑賞植物、ミニ盆栽など）。
# 2.  **五感を刺激する秋の味覚と食の楽しみ**
#     *   旬の食材（きのこ、さつまいも、栗、柿など）を使った手軽な料理やスイーツのアイデア。
#     *   秋限定の飲み物や香りの良い食材（金木犀、かぼすなど）の活用法。
#     *   近所のスーパーや直売所、道の駅などで秋の味覚を見つけるヒント。
# 3.  **自宅で心地よく秋を感じるインテリアと香り**
#     *   秋らしい色（ブラウン、オレンジ、深緑など）や素材（ウール、木、陶器など）を取り入れたインテリアコーディネート。
#     *   アロマやハーブ、生花（金木犀、菊など）で秋の香りを楽しむ方法。
#     *   読書、映画鑑賞、音楽など、おうち時間を充実させる秋の過ごし方。
# 4.  **地域や街中で見つける秋のイベント・アクティビティ**
#     *   地元の収穫祭、マルシェ、芸術展、文化イベントなど、近場で開催される秋の催し物。
#     *   少し足を延ばして楽しめる、地域の紅葉スポットや景観の良い場所。
#     *   身近な場所で楽しめる、写真撮影やスケッチなどのクリエイティブな活動。
# 5.  **秋の訪れを感じるための小さな工夫と習慣**
#     *   ファッションや小物で秋を取り入れる方法（スカーフ、アクセサリー、ストールなど）。
#     *   日常のルーティン（朝の散歩、カフェ巡りなど）に秋の要素を加えるアイデア。
#     *   秋の夜長を楽しむための過ごし方（キャンドル、お風呂、ホットドリンクなど）。
# ---
# ## 選定したトピックに基づいて、調査レポートを作成します。
# ## 調査レポート：近場で秋を感じる工夫
#
# ---
#
# ### 1. 身近な自然で秋を見つける楽しみ方
#
# 秋は、公園や街路樹の葉が赤や黄色に色づく紅葉の季節であり、都市部でもイチョウの黄色、モミジの赤など、樹木の種類によって異なる色彩を楽しめます。足元に目を向ければ、カサカサと音を立てる落ち葉や、ドングリ、栗などの木の実を見つけることができ、これらを拾い集めて自宅で飾るのも良いでしょう。近所を散歩する際は、普段通らない道を選んだり、時間帯を変えたりすることで、新たな発見があるかもしれません。カメラやスケッチブックを持参し、気になった風景や植物を記録することで、よりクリエイティブな視点で秋の散歩を楽しめます。ベランダや室内では、パンジーやビオラ、ミニ盆栽のモミジ、秋の切り花（キク、リンドウなど）を取り入れることで、手軽に秋の雰囲気を感じることができます。
#
# ### 2. 五感を刺激する秋の味覚と食の楽しみ
#
# 秋の代表的な旬の食材には、きのこ、さつまいも、栗、柿などがあります。きのこは炊き込みご飯やパスタに、さつまいもは大学芋やスイートポテトにと、手軽に秋の風味を楽しめる料理が多数存在します。栗ご飯やモンブランは、手間をかけることでより豊かな味わいが堪能でき、柿はそのまま食べるだけでなく、生ハムと合わせるなど意外な組み合わせも楽しめます。飲み物では、シナモンやナツメグを加えた温かい紅茶やコーヒー、金木犀や柚子の香りを活かしたお茶やシロップなどが秋限定の楽しみ方として挙げられます。近所のスーパーマーケットの特設コーナーや地元の農産物直売所、道の駅では、採れたての新鮮な野菜や果物、珍しい品種に出会えるため、足を運んでみることをお勧めします。
#
# ### 3. 自宅で心地よく秋を感じるインテリアと香り
#
# 自宅で秋を感じるインテリアには、ブラウン、オレンジ、テラコッタ、深緑などの暖色系やアースカラーを取り入れると、落ち着いた空間を演出できます。クッションカバーやブランケット、ラグなどをウールやフェルト素材のものに替えるだけで、温かみのある肌触りが秋らしさを高めます。木製の家具や小物、陶器製の食器などを配置することで、自然素材の持つ温もりを取り入れることができます。アロマディフューザーでシナモン、クローブ、サンダルウッドなどのエッセンシャルオイルを焚いたり、金木犀や菊の生花を飾ったりすることで、秋らしい香りを室内に広げることが可能です。秋の夜長は、読書、映画鑑賞、クラシック音楽やジャズを聴くなど、ゆったりとしたおうち時間を充実させるのに最適な季節です。
#
# ### 4. 地域や街中で見つける秋のイベント・アクティビティ
#
# 秋には、各地で収穫祭やフードフェスティバルが開催され、地元の新鮮な野菜や果物、特産品を味わうことができます。週末には手作り市やマルシェが開催されることが多く、個性的な雑貨や食品、クラフト作品に出会えるでしょう。地域の公民館やギャラリーでは、芸術の秋にちなんだ絵画展や写真展、陶芸展などが開催され、文化的な刺激を受けることができます。少し足を延ばせば、公園や植物園、渓谷、湖畔など、市街地から離れた場所に有名な紅葉スポットや景勝地が存在し、ドライブやハイキングに適しています。身近な場所でも、紅葉や落ち葉、木の実を被写体とした写真撮影やスケッチ、拾った材料でのクラフト作品作りなど、クリエイティブな活動を通じて秋を楽しむことができます。
#
# ### 5. 秋の訪れを感じるための小さな工夫と習慣
#
# ファッションでは、ブラウン、ボルドー、マスタード、カーキなどの秋色を取り入れることで、手軽に季節感を演出できます。首元にスカーフやストールを巻いたり、ベレー帽やニット帽を被ったりすることも、秋の装いを完成させる要素の一つです。日常のルーティンに秋の要素を加えるには、朝の散歩時に公園の紅葉を眺めたり、近所のカフェで秋限定のドリンクを楽しんだりすることが挙げられます。通勤や通学の際に、季節の移ろいを感じさせる街路樹の変化に注意を払うだけでも、短い時間で秋を感じられます。秋の夜長は、部屋の照明を落とし、アロマキャンドルの柔らかな光を灯したり、温かい湯船にゆっくりと浸かったり、ハーブティーなどのホットドリンクを味わったりすることで、心身をリラックスさせ、豊かな時間を過ごすことができます。
# #### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。調査レポートを基に、ライターエージェントとレビューエージェントが記事の作成とレビューを行います。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# 気がつけばもう秋の気配。遠出はなかなか難しいけれど、身近な場所で秋の訪れを感じる方法って、実はたくさんあるんですよ！
#
# ## 身近な「秋」を見つけに行こう！
#
# 秋は、鮮やかな紅葉や美味しい味覚、心地よい香りに包まれる素敵な季節です。遠くまで足を運ばなくても、自宅の周りやちょっとした工夫で、五感を刺激する秋の楽しみを見つけることができます。例えば、近所の公園で色づく葉や木の実を探したり、スーパーで旬の食材を手に入れて食卓を彩ったり。また、お部屋に秋色のアイテムや香りをプラスするだけでも、ぐっと季節感が増しますよ。日常の中に隠れている小さな変化に目を向けることで、いつもの景色が違って見えてくるはずです。
#
# ## マルシェや直売所で秋を深める
#
# 最近は、地域のコミュニティで開かれるマルシェやファーマーズマーケット、道の駅などが人気を集めています。ここでは、旬の採れたて野菜や果物はもちろん、手作りの加工品や地域の特産品に出会えることも。生産者さんの話を聞きながら食材を選ぶのは、スーパーでは味わえない特別な体験です。こうした場所へ足を運ぶことで、食を通じて地域の秋を感じ、さらに新しい発見があるかもしれません。地元の情報をチェックして、ぜひ訪れてみてくださいね。
#
# ## 秋の恵みでクリエイティブ体験！
#
# おすすめは、近所の公園や庭、河川敷などをゆっくり散歩して、秋の恵み探しをすること。色とりどりの落ち葉やユニークな形の木の実、小枝など、お気に入りの素材を見つけて持ち帰りましょう。
# 持ち帰った素材は、そのままガラスの器に飾ったり、リースにしたり、写真に撮ったりと、あなた次第で様々なアレンジが楽しめます。子供と一緒に楽しむのも良いですし、大人の趣味としても心が豊かになりますよ。自然の造形美に触れることで、心もリフレッシュできるはずです。
#
# ## さあ、あなたの秋を見つけよう！
#
# 特別な場所に行かなくても、日々の暮らしの中に隠れている秋の気配はたくさんあります。五感をフル活用して、身近な自然や食、香り、そして地域のイベントに目を向けてみましょう。ほんの少しの工夫で、毎日がもっと豊かになります。あなただけの「近場の秋」を、ぜひ見つけて楽しんでくださいね！
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 記事を拝見しました。近場で秋を感じる工夫について、読者が実践しやすい具体的なアイデアが盛り込まれていて、とても良いですね！
#
# ### 記事の良い点
# *   **具体例が豊富:** 近所の公園での散歩から、マルシェ訪問、室内での飾り付けまで、読者が今日から実践できるアイデアが複数紹介されています。
# *   **親しみやすいトーン:** 全体的に温かく、語りかけるような文章で、読者がリラックスして読み進められます。
# *   **五感を刺激する描写:** 食材や香り、彩りなど、秋の五感に訴えかける表現が使われており、情景が目に浮かびやすいです。
#
# ### 修正ポイント
# *   **タイトルの変更と設置:**
#     *   現在、記事冒頭の文章がタイトル代わりになっていますが、マークダウンヘッダ # をつけて「今日から役立つ生活情報」と感じる40文字程度のタイトルに変更してください。読者が「すぐに読まなきゃ！」と思うような、具体的なメリットや発見を期待させる表現が望ましいです。
#     *   （例：# 【今日から実践】遠出なしでも秋を満喫！身近で楽しむ絶景＆グルメの秘訣）
# *   **導入の明確化:**
#     *   タイトルの直後に、「なぜいまこのテーマを取り上げるのか」を明確に述べる導入文を追加してください。例えば、「忙しい日々や遠出が難しい状況でも、身近な場所で季節の移ろいを深く感じられることの価値」などを加えると、読者は記事を読む動機を見つけやすくなります。
# *   **サブタイトルへの絵文字追加:**
#     *   各セクションのサブタイトルに、内容に合わせた絵文字を1つ程度加えて、親しみやすさをさらにアップさせてください。（例：🍂、🍎、🎨、💡など）
# *   **構成の見直し:**
#     *   新しいタイトルと導入文の後に、現在の「身近な『秋』を見つけに行こう！」のセクションが来るように調整すると、記事の流れがよりスムーズになります。
# #### レビューに基づいて記事の修正を依頼しますか？

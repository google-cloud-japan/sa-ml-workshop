# %% [markdown]
# # A2A リモートエージェントを Agent Engine にデプロイする例
#
# このノートブックは、下記の記事のコードを実行したサンプルです。
#
# - [【Agent Engine の A2A 対応記念】A2A リモートエージェントを Agent Engine にデプロイする](https://zenn.dev/google_cloud_jp/articles/04cdf10fb5cd70)

# %% [markdown]
# ## プロジェクト環境の準備

# %% [markdown]
# 新しいプロジェクトを作成したら、Cloud Shell のコマンド端末を開いて、必要な API を有効化します。
#
# ```
# gcloud services enable \
#   aiplatform.googleapis.com \
#   notebooks.googleapis.com \
#   cloudresourcemanager.googleapis.com
# ```
#
# Firestore を使用するので、Agent Engine にデプロイしたエージェントが Firestore にアクセスできるように、必要なサービスアカウントを作成して、IAM ロールを付与しておきます。また、Firestore の DB `context-session-mapping` を作成します。
#
# ```
# PROJECT_ID=$(gcloud config list --format 'value(core.project)' 2>/dev/null)
# PROJECT_NUMBER=$(gcloud projects describe $PROJECT_ID --format='value(projectNumber)' 2>/dev/null)
# gcloud beta services identity create --service=aiplatform.googleapis.com --project=$PROJECT_ID
# gcloud projects add-iam-policy-binding $PROJECT_ID \
#     --member="serviceAccount:service-${PROJECT_NUMBER}@gcp-sa-aiplatform-re.iam.gserviceaccount.com" \
#     --role='roles/datastore.user'
# gcloud firestore databases create \
#   --database='context-session-mapping' --location=us-central1 --type=firestore-native
# ```
#
# 続いて、Workbench のインスタンスを作成します。
#
# ```
# PROJECT_ID=$(gcloud config list --format 'value(core.project)' 2>/dev/null)
# gcloud workbench instances create development-instance \
#   --project=$PROJECT_ID \
#   --location=us-central1-a \
#   --machine-type=e2-standard-2
# ```
#
# クラウドコンソールのナビゲーションメニューから「Vertex AI」→「Workbench」を選択すると、作成したインスタンス development-instance があります。インスタンスの起動が完了するのを待って、「JUPYTERLAB を開く」をクリックしたら、「Python 3(ipykernel)」の新規ノートブックを作成します。
#
# この後は、ノートブックのセルでコードを実行していきます。

# %% [markdown]
# ## 環境準備

# %%
# %pip install --user --upgrade \
    google-adk==1.27.2 \
    google-genai==1.68.0 \
    google-cloud-aiplatform==1.141.0 \
    google-cloud-firestore==2.25.0 \
    a2a-sdk==0.3.25

# %%
import IPython
app = IPython.Application.instance()
_ = app.kernel.do_shutdown(True)

# %%
import asyncio, httpx, json, os, uuid
from IPython.display import Markdown, display
from google.auth import default
from google.auth.transport.requests import Request
from google.cloud import firestore
import vertexai
from vertexai.agent_engines import AdkApp

# ADK
from google.genai.types import Part, Content, HttpOptions
from google.adk.agents.callback_context import CallbackContext
from google.adk.agents.llm_agent import LlmAgent
from google.adk.agents.remote_a2a_agent import RemoteA2aAgent
from google.adk.agents.sequential_agent import SequentialAgent
from google.adk.artifacts import InMemoryArtifactService
from google.adk.auth.credential_service.in_memory_credential_service import InMemoryCredentialService
from google.adk.memory.in_memory_memory_service import InMemoryMemoryService
from google.adk.models import LlmResponse, LlmRequest
from google.adk.runners import Runner
from google.adk.sessions import VertexAiSessionService

# A2A
from a2a.client import ClientConfig, ClientFactory
from a2a.types import AgentCard, TransportProtocol
from google.adk.a2a.executor.a2a_agent_executor import A2aAgentExecutor
from google.adk.a2a.utils.agent_card_builder import AgentCardBuilder

# Agent Engine
from vertexai import agent_engines
from vertexai.preview.reasoning_engines import A2aAgent
from vertexai.preview.reasoning_engines.templates.a2a import create_agent_card

[PROJECT_ID] = !gcloud config list --format 'value(core.project)' 2>/dev/null
[PROJECT_NUMBER] = !gcloud projects describe {PROJECT_ID} --format='value(projectNumber)' 2>/dev/null
LOCATION = 'us-central1'

vertexai.init(project=PROJECT_ID, location=LOCATION)

os.environ['GOOGLE_CLOUD_PROJECT'] = PROJECT_ID
os.environ['GOOGLE_CLOUD_LOCATION'] = LOCATION
os.environ['GOOGLE_GENAI_USE_VERTEXAI'] = 'True'

# %%
class ChatClient:
    def __init__(self, adk_app, user_id='default_user'):
        self.adk_app = adk_app
        self.user_id = user_id
        self.session_id = None

    async def async_stream_query(self, message, show=True):
        if not self.session_id:
            session = await self.adk_app.async_create_session(
                user_id=self.user_id,
            )
            self.session_id = getattr(session, 'id', None) or session['id']

        result = []
        async for event in self.adk_app.async_stream_query(
            user_id=self.user_id,
            session_id=self.session_id,
            message=message,
        ):
            author = event['author']
            if ('content' in event and 'parts' in event['content']):
                response = '\n'.join(
                    [p['text'] for p in event['content']['parts'] if 'text' in p]
                )
                if response:
                    if show:
                        display(Markdown(response))
                    result.append(response)
        return '\n'.join(result)

# %% [markdown]
# ## リモートエージェントの定義

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
指定されたテーマの記事を執筆する際に参考となるトピックを５項目程度のリストにまとめます。
後段のエージェントがこのリストに基づいて、調査レポートを作成します。

* 出力形式
日本語で出力。
'''

research_agent1 = LlmAgent(
    name='research_agent1',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
指定されたテーマの記事を執筆する際に参考となるトピックを５項目程度のリストにまとめます。
後段のエージェントがこのリストに基づいて、調査レポートを作成します。

* 出力形式
日本語で出力。
'''

research_agent1 = LlmAgent(
    name='research_agent1',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
前段のエージェントは、５項目程度の調査対象トピックを指定します。

* 出力形式
日本語で出力。
調査レポートは、トピックごとに客観的情報をまとめます。各トピックについて、５文以上の長さで記述すること。
'''

research_agent2 = LlmAgent(
    name='research_agent2',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、特定のテーマに関する気軽な読み物記事を書くことです。
記事の「テーマ」と、その内容に関連する「調査レポート」が与えられるので、
調査レポートに記載の客観的事実に基づいて、信頼性のある読み物記事を書いてください。

**出力条件**
- トピックに関してある程度の基礎知識がある読者を前提として、数分で気軽に読める内容にしてください。
- 比較的カジュアルで語りかける口調の文章にします。
- 思考過程は出力せずに、最終結果だけを出力します。
- 記事タイトルは付けないで、次の構成で出力します。各セクションタイトルは、内容に合わせてアレンジしてください。
0. 導入：セクションタイトルを付けないで、この記事を読みたくなる導入を１〜２文にまとめます。
1. 概要：トピックの全体像をまとめて簡単に説明します。
2. 最新情報：特に注目したい新しい情報を取り上げます。
3. 実践：トピックに関して、読者自身がやってみるとよさそうな事を１つ紹介します。
4. まとめ

- 各セクションのタイトルはマークダウンヘッダ ## 付けます。必要に応じて箇条書きのマークダウンを使用します。
- それ以外のマークダウンによる装飾は行いません。

**レビュアーの指示に応じた修正**
- レビュアーが修正ポイントを提示した際は、出力条件にこだわらずに、直前の記事を指示に従って修正してください。
- 修正ポイント以外の部分は、修正する必要ありません。
'''

writer_agent = LlmAgent(
    name='writer_agent',
    model='gemini-2.5-flash',
    description='特定のテーマに関する読み物記事を書くエージェント',
    instruction=instruction,
)

# %%
instruction = f'''
あなたの役割は、読み物記事をレビューして、記事の条件にあった内容にするための改善コメントを与える事です。

* 記事の条件
- 記事は、はじめに４０文字程度のタイトルがあること。
　今日から役立つ生活情報があって「すぐに読まなきゃ」と読者が感じるタイトルにすること。
　タイトルはマークダウンヘッダ # をつけること。
- タイトルの直後に「なぜいまこのテーマを取り上げるのか」をまとめた導入を加えて、読者にこの記事を読む動機づけを与えます。
- 各セクションのサブタイトルには、絵文字を用いて親しみやすさを出すこと。
- 読者が今日から実践できる具体例が３つ以上紹介されていること。

* 出力形式
- 日本語で出力。
- はじめに、記事の良い点を説明します。
- 次に、修正ポイントを箇条書きで出力します。
'''

review_agent = LlmAgent(
    name='review_agent',
    model='gemini-2.5-flash',
    description='読み物記事をレビューするエージェント',
    instruction=instruction,
)

# %% [markdown]
# ## Agent Engine へのデプロイ

# %%
client = vertexai.Client(
    project=PROJECT_ID,
    location=LOCATION,
    http_options=HttpOptions(
        api_version='v1beta1',
        base_url=f'https://{LOCATION}-aiplatform.googleapis.com/'
    ),
)

def get_agent_resource(agent_name):
    for agent in client.agent_engines.list():
        if agent.api_resource.display_name == agent_name:
            return agent.api_resource.name
    return None

# %%
class MyVertexAiSessionService(VertexAiSessionService):
    """
    A wrapper for VertexAiSessionService that persists the mapping between
    the A2A context_id and the Vertex-generated session_id in Firestore
    """
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        agent_engine_id = os.environ.get('GOOGLE_CLOUD_AGENT_ENGINE_ID')
        self.collection_name = f'AgentEngine-{agent_engine_id}'
        self.firestore_client = firestore.Client(database='context-session-mapping')

    def set_session_id(self, user_id, context_id, session_id):
        key = f'User-{user_id}-Context-{context_id}'
        doc_ref = self.firestore_client.collection(self.collection_name).document(key)
        doc_ref.set({'session_id': session_id}) 
        print(f"Persisted mapping: context_id '{context_id}' -> session_id '{session_id}'", flush=True)

    def get_session_id(self, user_id, context_id):
        key = f'User-{user_id}-Context-{context_id}'
        doc_ref = self.firestore_client.collection(self.collection_name).document(key)
        doc = doc_ref.get()
        if doc.exists:
            session_id = doc.to_dict().get('session_id')
            print(f"Found mapping: context_id '{context_id}' -> session_id '{session_id}'.", flush=True)
            return session_id
        else:
            print(f"Not found mapping for context_id '{context_id}'.", flush=True)
            return None

    async def create_session(
        self, app_name, user_id, state={}, session_id=None # A2A context_id
    ):
        real_session_id = None
        context_id = session_id if session_id else None

        # Create the session in Vertex AI, which will generate its own unique ID.
        session = await super().create_session(
            app_name=app_name,
            user_id=user_id,
            state=state,
        )
        real_session_id = session.id
        print(f"Created new Vertex session '{real_session_id}' for user '{user_id}'.", flush=True)

        # If a context_id was provided, persist the mapping.
        if context_id:
            self.set_session_id(user_id, context_id, real_session_id)

        return session

    async def get_session(
        self, app_name, user_id, session_id, # A2A context_id
        config=None,
    ):
        context_id = session_id
        real_session_id = self.get_session_id(user_id, context_id)
        
        # Create a new session if not exist.
        if real_session_id is None:
            new_session = await self.create_session(
                app_name=app_name,
                user_id=user_id,
                session_id=context_id,
            )
            real_session_id = new_session.id
            
        session = await super().get_session(
                app_name=app_name,
                user_id=user_id,
                session_id=real_session_id,
                config=config,
            )

        return session


def get_create_runner_class(agent):
    async def create_runner():
        project_id = os.environ.get('GOOGLE_CLOUD_PROJECT')
        location = os.environ.get('GOOGLE_CLOUD_LOCATION')
        agent_engine_id = os.environ.get('GOOGLE_CLOUD_AGENT_ENGINE_ID')
        resource_name = None
        if project_id and location and agent_engine_id:
            resource_name = f'projects/{project_id}/locations/{location}/reasoningEngines/{agent_engine_id}'
        return Runner(
            # Use resource_name as app_name for VertexAiSessionService.
            app_name=resource_name or agent.name,
            agent=agent,
            artifact_service=InMemoryArtifactService(),
            session_service=MyVertexAiSessionService(),
            memory_service=InMemoryMemoryService(),
            credential_service=InMemoryCredentialService(),
        )
    return create_runner


def get_agent_executor_class(agent):
    def agent_executor_builder():
        return A2aAgentExecutor(
            runner=get_create_runner_class(agent),
        )       
    return agent_executor_builder


async def get_agent_card(agent):
    builder = AgentCardBuilder(agent=agent)
    adk_agent_card = await builder.build()
    return create_agent_card(
        agent_name=adk_agent_card.name,
        description=adk_agent_card.description,
        skills=adk_agent_card.skills
    )

# %%
agents = {
    'research_agent1_a2a': research_agent1,
    'research_agent2_a2a': research_agent2,
    'writer_agent_a2a': writer_agent,
    'review_agent_a2a': review_agent,
}

async def deploy_or_update_agent(agent_name, agent, client, project_id):
    # prepare staging bucket
    bucket_uri = f'gs://{project_id}_{agent_name}'
    # !gsutil ls -b {bucket_uri} 2>/dev/null || gsutil mb -b on -l {LOCATION} {bucket_uri}
    
    a2a_agent = A2aAgent(
        agent_card=await get_agent_card(agent),
        agent_executor_builder=get_agent_executor_class(agent)
    )

    config = {
        'display_name': agent_name,
        'description': a2a_agent.agent_card.description,
        'requirements': [
            'google-adk==1.27.2',
            'google-genai==1.68.0',
            'google-cloud-aiplatform==1.141.0',
            'google-cloud-firestore==2.25.0',
            'a2a-sdk==0.3.25'
        ],
        'staging_bucket': bucket_uri,
    }
    
    resource_name = get_agent_resource(agent_name)
    
    if resource_name is None:
        print(f'Deploying... {agent_name}: {agent.description}')
        remote_a2a_agent = await asyncio.to_thread(
            client.agent_engines.create,
            agent=a2a_agent,
            config=config,
        )
    else:
        print(f'Updating... {agent_name}: {agent.description}')
        remote_a2a_agent = await asyncio.to_thread(
            client.agent_engines.update,
            name=resource_name,
            agent=a2a_agent,
            config=config,
        )
        
    return remote_a2a_agent

async def deploy_all_agents():
    tasks = [
        deploy_or_update_agent(agent_name, agent, client, PROJECT_ID)
        for agent_name, agent in agents.items()
    ]
    results = await asyncio.gather(*tasks)
    return results

await deploy_all_agents()
# Out:
# gs://etsuji-15pro-poc_research_agent1_a2a/
# /var/tmp/ipykernel_15789/1444125661.py:106: UserWarning: [EXPERIMENTAL] AgentCardBuilder: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   builder = AgentCardBuilder(agent=agent)
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# Updating... research_agent1_a2a: 記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）
# gs://etsuji-15pro-poc_research_agent2_a2a/
# /var/tmp/ipykernel_15789/1444125661.py:106: UserWarning: [EXPERIMENTAL] AgentCardBuilder: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   builder = AgentCardBuilder(agent=agent)
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# Updating... research_agent2_a2a: 記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）
# gs://etsuji-15pro-poc_writer_agent_a2a/
# Updating... writer_agent_a2a: 特定のテーマに関する読み物記事を書くエージェント
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# gs://etsuji-15pro-poc_review_agent_a2a/
# Updating... review_agent_a2a: 読み物記事をレビューするエージェント
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# [AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/6599239103097602048'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/5230144816376971264'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/4824820849913626624'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/8808254720322830336')]

# %% [markdown]
# ## RemoteA2aAgent を用いた root agent の定義

# %%
class GoogleAuthRefresh(httpx.Auth):
    def __init__(self, scopes):
        self.credentials, _ = default(scopes=scopes)
        self.transport_request = Request()
        self.credentials.refresh(self.transport_request)

    def auth_flow(self, request):
        if not self.credentials.valid:
            self.credentials.refresh(self.transport_request)
        request.headers['Authorization'] = f'Bearer {self.credentials.token}'
        yield request


factory = ClientFactory(
    ClientConfig(
        supported_transports=[TransportProtocol.http_json],
        use_client_preference=True,
        httpx_client=httpx.AsyncClient(
            timeout=60,
            headers={'Content-Type': 'application/json'},
            auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
        ),
    ),
)

# %%
resource_name = get_agent_resource('research_agent1_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
research_agent1_remote = RemoteA2aAgent(
    name="research_agent1",
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('research_agent2_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
research_agent2_remote = RemoteA2aAgent(
    name="research_agent2",
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('writer_agent_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
writer_agent_remote = RemoteA2aAgent(
    name="writer_agent",
    description='特定のテーマに関する読み物記事を書くエージェント',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('review_agent_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
review_agent_remote = RemoteA2aAgent(
    name="review_agent",
    description='読み物記事をレビューするエージェント',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)
# Out:
# /var/tmp/ipykernel_15789/1893291524.py:3: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent1_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_15789/1893291524.py:12: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent2_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_15789/1893291524.py:21: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   writer_agent_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_15789/1893291524.py:30: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   review_agent_remote = RemoteA2aAgent(

# %%
def get_print_agent(text):
    def before_model_callback(
        callback_context: CallbackContext, llm_request: LlmRequest
    ) -> LlmResponse:
        return LlmResponse(
            content=Content(
                role='model', parts=[Part(text=text)],
            )
        )
    return LlmAgent(
        name='print_agent',
        model='gemini-2.0-flash', # not used
        description='',
        instruction = '',
        before_model_callback=before_model_callback,
    )

research_agent = SequentialAgent(
    name='research_agent',
    sub_agents=[
        get_print_agent('\n---\n## リサーチエージェントが調査レポートを作成します。\n---\n'),
        get_print_agent('\n## 調査対象のトピックを選定します。\n'),
        research_agent1_remote,
        get_print_agent('\n## 選定したトピックに基づいて、調査レポートを作成します。\n'),
        research_agent2_remote,
        get_print_agent('\n#### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？\n'),
    ],
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント',
)

write_and_review_agent = SequentialAgent(
    name='write_and_review_agent',
    sub_agents=[
        get_print_agent('\n---\n## ライターエージェントが記事を執筆します。\n---\n'),
        writer_agent_remote,
        get_print_agent('\n---\n## レビューエージェントが記事をレビューします。\n---\n'),
        review_agent_remote,
       get_print_agent('\n#### レビューに基づいて記事の修正を依頼しますか？\n'),
    ],
    description='記事を作成、レビューする。',
)

root_agent = LlmAgent(
    name='article_generation_flow',
    model='gemini-2.0-flash',
    instruction = '''
何ができるか聞かれた場合は、以下の処理をすることをわかりやすくフレンドリーな文章にまとめて返答してください。

- ユーザーが指定したテーマの記事を作成する業務フローを実行する。
- はじめに、テーマに関する調査レポートを作成する。
- その後、ライターエージェントとレビューエージェントが協力して、編集方針に則した記事を作成する。

ユーザーが記事のテーマを指定した場合は、次のフローを実行します。

1. そのテーマの記事の作成に取り掛かる旨を伝えて、research_agent に転送して、調査レポートを依頼します。
2. ユーザー記事の作成を支持したら、write_and_review_agent に転送して、記事の作成とレビューを依頼します。
3. ユーザーが記事の修正を希望する場合は、write_and_review_agent に転送します。

**条件**
research_agent のニックネームは、リサーチエージェント
write_and_review_agent のネックネームは、ライターエージェントとレビューエージェント

''',
    sub_agents=[
        research_agent,
        write_and_review_agent,
    ],
    description='記事を作成する業務フローを実行するエージェント'
)


adk_app = AdkApp(
    agent=root_agent,
    app_name='article_generation_app',
)
# Out:
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.

# %% [markdown]
# ## 実行例

# %%
chat_client = ChatClient(adk_app)

query = '''
こんにちは。何ができますか？
'''
response = await chat_client.async_stream_query(query)
# Out:
# こんにちは！私は、ユーザーさんが指定したテーマの記事を作成するお手伝いをすることができます。
#
# まず、リサーチエージェントがテーマに関する調査レポートを作成します。次に、ライターエージェントとレビューエージェントが協力して、編集方針に沿った記事を作成します。ご希望の記事テーマがあれば教えてください！

# %%
query = '''
「近場で秋を感じる工夫」をテーマに記事を作成してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 承知いたしました。「近場で秋を感じる工夫」というテーマの記事作成に取り掛かります。まずは、リサーチエージェントに調査レポートを依頼します。
# ---
# ## リサーチエージェントが調査レポートを作成します。
# ---
# ## 調査対象のトピックを選定します。
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# 「近場で秋を感じる工夫」をテーマに、以下の5つのトピックで調査レポートを作成します。
#
# 1.  **身近な自然で秋の訪れを楽しむ方法**：公園や街路樹、自宅の庭など、遠出せずに楽しめる紅葉スポットの探し方、落ち葉遊び、秋の草花の観察など、自然の中で秋を感じる具体的なアイデア。
# 2.  **秋の味覚を日常生活に取り入れる工夫**：旬の食材（栗、さつまいも、きのこ、梨、柿など）を使った簡単な家庭料理のレシピ、季節限定スイーツやドリンクの楽しみ方、地元のマルシェやスーパーでの旬の食材の選び方。
# 3.  **自宅で秋の雰囲気を演出するインテリアと香り**：秋色を取り入れた部屋の飾り付け（クッション、ブランケット）、松ぼっくりやドライフラワーなどの自然素材を使ったデコレーション、アロマキャンドルやディフューザーで秋らしい香りを部屋に広げる方法。
# 4.  **地域のイベントや文化活動で秋を満喫する**：地元の収穫祭、文化祭、アートイベント、図書館の秋の特集など、近場で開催される季節限定の催し物や、地域に根ざした秋の風習の楽しみ方。
# 5.  **五感で感じる「小さな秋」の発見と楽しみ方**：朝晩の空気の変化、虫の音、夕日の色、金木犀の香りなど、日常生活の中で意識して秋の訪れを感じ取るヒントや、その感動を味わうための思考法。
# ## 選定したトピックに基づいて、調査レポートを作成します。
# ## 調査レポート：「近場で秋を感じる工夫」
#
# ### 1. 身近な自然で秋の訪れを楽しむ方法
#
# 遠出をしなくても、身近な自然の中で秋の訪れを十分に感じることができます。地域の公園や街路樹は、紅葉のグラデーションを楽しむ絶好のスポットです。特にイチョウ並木やモミジの木は、鮮やかな黄色や赤色に染まり、視覚的に秋の深まりを教えてくれます。また、散歩中に落ち葉の絨毯を踏みしめる音や感触は、秋ならではの趣を演出します。自宅の庭やベランダに秋の草花、例えばコスモスや菊、ススキなどを植えることで、日常的に秋の彩りを楽しむことも可能です。子どもと一緒に落ち葉拾いやどんぐり集めをして、自然の恵みに触れる遊びも、秋を満喫する素晴らしい方法と言えるでしょう。
#
# ### 2. 秋の味覚を日常生活に取り入れる工夫
#
# 秋は収穫の季節であり、旬の味覚を食卓に取り入れることで、手軽に秋を感じることができます。栗ごはんやサツマイモを使った大学芋、キノコをたっぷり入れた鍋料理などは、家庭で簡単に作れる秋の代表的な料理です。地元のスーパーマーケットや道の駅、マルシェでは、新鮮な梨や柿、ブドウといった果物が豊富に並び、季節の移ろいを舌で味わえます。また、カフェやコンビニエンスストアでは、栗やかぼちゃ、サツマイモを使った季節限定のスイーツやドリンクが提供され、手軽に秋の風味を楽しむことができます。これらの旬の食材を意識的に選ぶことで、日々の食事がより豊かな秋の体験へと変わるでしょう。
#
# ### 3. 自宅で秋の雰囲気を演出するインテリアと香り
#
# 自宅の空間を少し工夫するだけで、秋らしい落ち着いた雰囲気を演出することが可能です。ソファにボルドーやマスタードイエロー、深緑などの秋色を取り入れたクッションやブランケットを配置するだけで、部屋全体の印象が暖かく変わります。また、公園で拾った松ぼっくりや小枝、ドライフラワーなどを飾ることで、自然の素材感が秋の素朴な美しさを引き立てます。さらに、アロマキャンドルやディフューザーを使って、金木犀、シナモン、アップル、ウッディ系といった秋らしい香りを部屋に広げることも効果的です。視覚と嗅覚の両方から秋を感じることで、より心地よい空間を作り出すことができます。
#
# ### 4. 地域のイベントや文化活動で秋を満喫する
#
# 地域によっては、秋の訪れを祝う様々なイベントや文化活動が開催されており、これらに参加することで、近場で秋の魅力を満喫できます。地元の収穫祭では、新鮮な農産物の販売や郷土料理の提供が行われ、地域の食文化に触れる良い機会となります。文化祭やアートイベントでは、秋の夜長に芸術に親しむことができ、特別な感動を味わうことができるでしょう。図書館では、読書の秋にちなんで季節限定の特集コーナーが設けられたり、朗読会が開催されたりすることもあります。これらの地域に根ざした催しに参加することで、コミュニティとの繋がりを感じながら、季節ごとの楽しみを発見することができます。
#
# ### 5. 五感で感じる「小さな秋」の発見と楽しみ方
#
# 日常生活の中で意識的に五感を働かせることで、「小さな秋」をたくさん発見し、その感動を味わうことができます。朝晩の空気のひんやりとした変化や、虫の音色、特にコオロギの声は、耳で感じる秋のサインです。夕焼けが夏よりも深く、橙色や赤色に染まる様子は、視覚を通して秋の美しさを伝えます。また、金木犀（キンモクセイ）の甘く芳しい香りが街中に漂い始めると、嗅覚で秋の訪れを強く感じられます。これらの些細な変化に気づき、立ち止まってその瞬間を味わうことで、日常の中に隠された秋の豊かさを感じ取ることができるでしょう。意識的な観察と感受性が、「小さな秋」を見つける鍵となります。
# #### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。それでは、ライターエージェントとレビューエージェントに記事の作成を依頼します。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# 朝晩の風に肌寒さを感じる今日この頃、そろそろ秋の気配が恋しくなってきましたよね。遠くまで出かけなくても、実は私たちの身の回りには「秋」がたくさん隠れています。今回は、そんな身近な秋をたっぷり味わうためのヒントをお届けします！
#
# ## 身近な場所で秋を見つけよう
#
# 秋といえば紅葉狩りや味覚の収穫ですが、わざわざ遠出をしなくても、実は日常生活の中に秋を感じるチャンスはたくさんあります。例えば、近所の公園や街路樹のイチョウやモミジが色づき始めるのを見つけたり、散歩中に落ち葉を踏みしめるカサカサという音を楽しむのも立派な秋の楽しみ方。自宅の庭やベランダにコスモスやススキを飾るだけでも、ぐっと秋らしい雰囲気が生まれますよ。旬の栗やサツマイモ、キノコを使った家庭料理を楽しんだり、カフェの季節限定スイーツで一息つくのも良いでしょう。お部屋に秋色のクッションを取り入れたり、金木犀の香りのアロマを焚いたりするのも手軽な方法です。地域によっては収穫祭や文化祭など、秋ならではのイベントも開催されているので、情報をチェックしてみるのもおすすめです。
#
# ## 五感で味わう「小さな秋」に注目！
#
# 特に注目したいのは、意識的に五感を研ぎ澄まして見つける「小さな秋」です。最近では、デジタルデバイスに囲まれて過ごす時間が多いかもしれませんが、少し立ち止まって周囲に意識を向けてみませんか。朝晩のひんやりとした空気、虫の鳴き声、特にコオロギの音色は耳で感じる秋のサインです。夕焼けが夏よりも深く、オレンジ色や赤色に染まる様子は、視覚から秋の深まりを教えてくれます。そして、何と言っても金木犀（キンモクセイ）の甘く芳しい香りは、嗅覚で感じる秋の代表格ですよね。こうした日常に溶け込んでいる些細な変化に気づき、その瞬間を味わうことが、実は一番贅沢な秋の過ごし方かもしれません。
#
# ## 今すぐできる！秋の味覚を取り入れよう
#
# すぐにでも実践できる秋の楽しみ方として、旬の味覚を食卓に取り入れてみませんか？スーパーマーケットや道の駅には、新鮮な栗、サツマイモ、キノコ、そして梨や柿といった秋の果物がずらりと並んでいます。
# *   栗ごはんや大学芋、キノコたっぷりのお味噌汁など、手間をかけずに作れる秋の家庭料理に挑戦する。
# *   食後のデザートには、旬の果物を添えたり、コンビニエンスストアやカフェの季節限定スイーツやドリンクを楽しんだりする。
# 旬の食材は栄養も豊富で、季節の移ろいを体の中から感じさせてくれます。ぜひ、日々の献立に秋の彩りを加えてみてくださいね。
#
# ## まとめ
#
# 遠くに行かなくても、私たちのすぐそばには、五感を刺激するたくさんの「秋」が隠れています。公園の木々の色づき、旬の味覚、心地よい秋の香り、そして地域のお祭り。いつもの日常に少しだけ意識を向けてみるだけで、秋はもっと豊かに感じられます。さあ、あなたも身近な場所で、自分だけの「小さな秋」を見つけてみませんか？
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 記事のレビュー、ありがとうございます。全体的によくまとまっており、読者が「近場で秋を感じる工夫」を実践するための具体的なヒントが豊富に盛り込まれていますね。特に、五感に訴えかける表現が多く、読者が秋の情景を想像しやすい点が素晴らしいです。
#
# 以下に、記事の条件に沿うための修正点と、さらなる改善のためのアドバイスを箇条書きで示します。
#
# ### 修正ポイント
#
# *   **タイトルがない**:
#     *   記事の冒頭に、**「#」** をつけた魅力的なタイトルを設置してください。例えば、「🍁🍂今日からできる！忙しくても秋をたっぷり味わう【身近な五感活用術】」のような、40文字程度で読者が「すぐに読まなきゃ」と感じる具体的なメリットを提示するタイトルが良いでしょう。
# *   **導入の位置と内容**:
#     *   作成したタイトルの直後に、現在の記事の導入部分（「朝晩の風に肌寒さを感じる今日この頃…」）を移動させてください。
#     *   導入の内容をさらに強化し、「なぜいまこのテーマを取り上げるのか」という動機づけを明確にしてください。例えば、「遠出が難しい今だからこそ、身近な場所で秋を感じる方法を知りたいという声が増えています。」といった、読者のニーズや背景に寄り添う一文を加えると、より引き込まれる導入になります。
# *   **サブタイトルに絵文字がない**:
#     *   各セクションのサブタイトル（例: 「身近な場所で秋を見つけよう」「五感で味わう『小さな秋』に注目！」「今すぐできる！秋の味覚を取り入れよう」）に、内容に合った絵文字（例: 🍁、👂、🌰など）を追加して、親しみやすさを出してください。
# *   **記事構成の一部重複**:
#     *   「身近な場所で秋を見つけよう」セクションと「今すぐできる！秋の味覚を取り入れよう」セクションで、秋の味覚に関する内容が一部重複しているように見えます。
#     *   例えば、「身近な場所で秋を見つけよう」では自然やインテリアに焦点を当て、「今すぐできる！秋の味覚を取り入れよう」では食に特化するなど、各セクションの役割を明確にすると、より内容が整理され読みやすくなります。あるいは、味覚に関する内容を一つの独立したセクションにまとめるのも良いでしょう。
# #### レビューに基づいて記事の修正を依頼しますか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。レビューエージェントからのフィードバックに基づいて、記事の修正をライターエージェントに依頼します。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# # 🍁🍂今日からできる！忙しくても秋をたっぷり味わう【身近な五感活用術】
#
# 朝晩の風に肌寒さを感じる今日この頃、そろそろ秋の気配が恋しくなってきましたよね。遠くまで出かけなくても、実は私たちの身の回りには「秋」がたくさん隠れています。遠出が難しい今だからこそ、身近な場所で秋を感じる方法を知りたいという声が増えています。今回は、そんな身近な秋をたっぷり味わうためのヒントをお届けします！
#
# ## 🍁近場で発見！日常に溶け込む秋の気配
#
# 秋といえば紅葉狩りや味覚の収穫ですが、わざわざ遠出をしなくても、実は日常生活の中に秋を感じるチャンスはたくさんあります。例えば、近所の公園や街路樹のイチョウやモミジが色づき始めるのを見つけたり、散歩中に落ち葉を踏みしめるカサカサという音を楽しむのも立派な秋の楽しみ方。自宅の庭やベランダにコスモスやススキを飾るだけでも、ぐっと秋らしい雰囲気が生まれますよ。お部屋に秋色のクッションを取り入れたり、金木犀の香りのアロマを焚いたりするのも手軽な方法です。地域によっては収穫祭や文化祭など、秋ならではのイベントも開催されているので、情報をチェックしてみるのもおすすめです。
#
# ## 👂五感で研ぎ澄ます「小さな秋」のアンテナ
#
# 特に注目したいのは、意識的に五感を研ぎ澄まして見つける「小さな秋」です。最近では、デジタルデバイスに囲まれて過ごす時間が多いかもしれませんが、少し立ち止まって周囲に意識を向けてみませんか。朝晩のひんやりとした空気、虫の鳴き声、特にコオロギの音色は耳で感じる秋のサインです。夕焼けが夏よりも深く、オレンジ色や赤色に染まる様子は、視覚から秋の深まりを教えてくれます。そして、何と言っても金木犀（キンモクセイ）の甘く芳しい香りは、嗅覚で感じる秋の代表格ですよね。こうした日常に溶け込んでいる些細な変化に気づき、その瞬間を味わうことが、実は一番贅沢な秋の過ごし方かもしれません。
#
# ## 🌰食欲の秋！旬の味覚で秋を味わおう
#
# すぐにでも実践できる秋の楽しみ方として、旬の味覚を食卓に取り入れてみませんか？スーパーマーケットや道の駅には、新鮮な栗、サツマイモ、キノコ、そして梨や柿といった秋の果物がずらりと並んでいます。
#
# *   栗ごはんや大学芋、キノコたっぷりのお味噌汁など、手間をかけずに作れる秋の家庭料理に挑戦する。
# *   食後のデザートには、旬の果物を添えたり、コンビニエンスストアやカフェの季節限定スイーツやドリンクを楽しんだりする。
#
# 旬の食材は栄養も豊富で、季節の移ろいを体の中から感じさせてくれます。ぜひ、日々の献立に秋の彩りを加えてみてくださいね。
#
# ## まとめ
#
# 遠くに行かなくても、私たちのすぐそばには、五感を刺激するたくさんの「秋」が隠れています。公園の木々の色づき、旬の味覚、心地よい秋の香り、そして地域のお祭り。いつもの日常に少しだけ意識を向けてみるだけで、秋はもっと豊かに感じられます。さあ、あなたも身近な場所で、自分だけの「小さな秋」を見つけてみませんか？
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 素晴らしい修正ですね！前回のレビューコメントで指摘した点がすべて的確に反映されており、記事の完成度が格段に上がりました。
#
# ### 記事の良い点
#
# *   **魅力的なタイトルと導入**: 「# 🍁🍂今日からできる！忙しくても秋をたっぷり味わう【身近な五感活用術】」というタイトルは、読者の興味を引きつけ、すぐに読みたくなるような具体的なメリットが提示されています。また、導入もタイトルの直後に配置され、「遠出が難しい今だからこそ、身近な場所で秋を感じる方法を知りたいという声が増えています。」という一文が加わることで、読者がこの記事を読む動機づけが明確になっています。
# *   **親しみやすいサブタイトル**: 各セクションのサブタイトルに絵文字が加わり、「🍁近場で発見！日常に溶け込む秋の気配」「👂五感で研ぎ澄ます「小さな秋」のアンテナ」「🌰食欲の秋！旬の味覚で秋を味わおう」と、内容が一目で分かりやすく、親しみやすい印象を与えます。
# *   **豊富な具体例**: 各セクションで、近所の公園での紅葉の楽しみ方から、自宅での秋の演出、五感を使った「小さな秋」の発見、そして旬の味覚を取り入れた食卓の工夫まで、読者が今日から実践できる具体的なアイデアが多岐にわたって紹介されており、非常に実践的です。
# *   **構成の明確化**: 前回のレビューで指摘した秋の味覚に関する内容の重複が解消され、「🌰食欲の秋！旬の味覚で秋を味わおう」として独立したセクションになったことで、各セクションの役割が明確になり、より読みやすい構成になりました。
#
# ### 修正ポイント
#
# 現状、記事の条件はすべて満たされており、特に修正を必要とする点はありません。非常に完成度の高い記事です。
# #### レビューに基づいて記事の修正を依頼しますか？

# %%
query = '''
これで完成です。完成した記事を表示してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# # 🍁🍂今日からできる！忙しくても秋をたっぷり味わう【身近な五感活用術】
#
# 朝晩の風に肌寒さを感じる今日この頃、そろそろ秋の気配が恋しくなってきましたよね。遠くまで出かけなくても、実は私たちの身の回りには「秋」がたくさん隠れています。遠出が難しい今だからこそ、身近な場所で秋を感じる方法を知りたいという声が増えています。今回は、そんな身近な秋をたっぷり味わうためのヒントをお届けします！
#
# ## 🍁近場で発見！日常に溶け込む秋の気配
#
# 秋といえば紅葉狩りや味覚の収穫ですが、わざわざ遠出をしなくても、実は日常生活の中に秋を感じるチャンスはたくさんあります。例えば、近所の公園や街路樹のイチョウやモミジが色づき始めるのを見つけたり、散歩中に落ち葉を踏みしめるカサカサという音を楽しむのも立派な秋の楽しみ方。自宅の庭やベランダにコスモスやススキを飾るだけでも、ぐっと秋らしい雰囲気が生まれますよ。お部屋に秋色のクッションを取り入れたり、金木犀の香りのアロマを焚いたりするのも手軽な方法です。地域によっては収穫祭や文化祭など、秋ならではのイベントも開催されているので、情報をチェックしてみるのもおすすめです。
#
# ## 👂五感で研ぎ澄ます「小さな秋」のアンテナ
#
# 特に注目したいのは、意識的に五感を研ぎ澄まして見つける「小さな秋」です。最近では、デジタルデバイスに囲まれて過ごす時間が多いかもしれませんが、少し立ち止まって周囲に意識を向けてみませんか。朝晩のひんやりとした空気、虫の鳴き声、特にコオロギの音色は耳で感じる秋のサインです。夕焼けが夏よりも深く、オレンジ色や赤色に染まる様子は、視覚から秋の深まりを教えてくれます。そして、何と言っても金木犀（キンモクセイ）の甘く芳しい香りは、嗅覚で感じる秋の代表格ですよね。こうした日常に溶け込んでいる些細な変化に気づき、その瞬間を味わうことが、実は一番贅沢な秋の過ごし方かもしれません。
#
# ## 🌰食欲の秋！旬の味覚で秋を味わおう
#
# すぐにでも実践できる秋の楽しみ方として、旬の味覚を食卓に取り入れてみませんか？スーパーマーケットや道の駅には、新鮮な栗、サツマイモ、キノコ、そして梨や柿といった秋の果物がずらりと並んでいます。
#
# *   栗ごはんや大学芋、キノコたっぷりのお味噌汁など、手間をかけずに作れる秋の家庭料理に挑戦する。
# *   食後のデザートには、旬の果物を添えたり、コンビニエンスストアやカフェの季節限定スイーツやドリンクを楽しんだりする。
#
# 旬の食材は栄養も豊富で、季節の移ろいを体の中から感じさせてくれます。ぜひ、日々の献立に秋の彩りを加えてみてくださいね。
#
# ## まとめ
#
# 遠くに行かなくても、私たちのすぐそばには、五感を刺激するたくさんの「秋」が隠れています。公園の木々の色づき、旬の味覚、心地よい秋の香り、そして地域のお祭り。いつもの日常に少しだけ意識を向けてみるだけで、秋はもっと豊かに感じられます。さあ、あなたも身近な場所で、自分だけの「小さな秋」を見つけてみませんか？

# %% [markdown]
# ## root agent を Agent Engine にデプロイ

# %%
class MyClientFactory(ClientFactory):
    def create(self, card, consumers=None, interceptors=None):
        if not self._config.httpx_client:
            self._config.httpx_client=httpx.AsyncClient(
                timeout=60,
                headers={'Content-Type': 'application/json'},
                auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
            )
            self._register_defaults(self._config.supported_transports)
        return super().create(card, consumers, interceptors)


class MyRemoteA2aAgent(RemoteA2aAgent):
    async def _ensure_httpx_client(self):
        if not self._httpx_client:
            self._httpx_client=httpx.AsyncClient(
                timeout=60,
                headers={'Content-Type': 'application/json'},
                auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
            )
        return self._httpx_client


factory = MyClientFactory(
    ClientConfig(
        supported_transports=[TransportProtocol.http_json],
        use_client_preference=True,
    )
)

resource_name = get_agent_resource('research_agent1_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
research_agent1_remoteA2a = MyRemoteA2aAgent(
    name='research_agent1',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('research_agent2_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
research_agent2_remoteA2a = MyRemoteA2aAgent(
    name='research_agent2',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('writer_agent_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
writer_agent_remoteA2a = MyRemoteA2aAgent(
    name='writer_agent',
    description='特定のテーマに関する読み物記事を書くエージェント',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('review_agent_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
review_agent_remoteA2a = MyRemoteA2aAgent(
    name='review_agent',
    description='読み物記事をレビューするエージェント',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

def get_print_agent(text):
    def before_model_callback(
        callback_context: CallbackContext, llm_request: LlmRequest
    ) -> LlmResponse:
        return LlmResponse(
            content=Content(
                role='model', parts=[Part(text=text)],
            )
        )
    return LlmAgent(
        name='print_agent',
        model='gemini-2.0-flash', # not used
        description='',
        instruction = '',
        before_model_callback=before_model_callback,
    )

research_agent = SequentialAgent(
    name='research_agent',
    sub_agents=[
        get_print_agent('\n---\n## リサーチエージェントが調査レポートを作成します。\n---\n'),
        get_print_agent('\n## 調査対象のトピックを選定します。\n'),
        research_agent1_remoteA2a,
        get_print_agent('\n## 選定したトピックに基づいて、調査レポートを作成します。\n'),
        research_agent2_remoteA2a,
        get_print_agent('\n#### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？\n'),
    ],
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント',
)

write_and_review_agent = SequentialAgent(
    name='write_and_review_agent',
    sub_agents=[
        get_print_agent('\n---\n## ライターエージェントが記事を執筆します。\n---\n'),
        writer_agent_remoteA2a,
        get_print_agent('\n---\n## レビューエージェントが記事をレビューします。\n---\n'),
        review_agent_remoteA2a,
       get_print_agent('\n#### レビューに基づいて記事の修正を依頼しますか？\n'),
    ],
    description='記事を作成、レビューする。',
)

root_agent = LlmAgent(
    name='article_generation_flow',
    model='gemini-2.0-flash',
    instruction = '''
何ができるか聞かれた場合は、以下の処理をすることをわかりやすくフレンドリーな文章にまとめて返答してください。

- ユーザーが指定したテーマの記事を作成する業務フローを実行する。
- はじめに、テーマに関する調査レポートを作成する。
- その後、ライターエージェントとレビューエージェントが協力して、編集方針に則した記事を作成する。

ユーザーが記事のテーマを指定した場合は、次のフローを実行します。

1. そのテーマの記事の作成に取り掛かる旨を伝えて、research_agent に転送して、調査レポートを依頼します。
2. ユーザー記事の作成を支持したら、write_and_review_agent に転送して、記事の作成とレビューを依頼します。
3. ユーザーが記事の修正を希望する場合は、write_and_review_agent に転送します。

**条件**
research_agent のニックネームは、リサーチエージェント
write_and_review_agent のネックネームは、ライターエージェントとレビューエージェント

''',
    sub_agents=[
        research_agent,
        write_and_review_agent,
    ],
    description='記事を作成する業務フローを実行するエージェント'
)

adk_app = AdkApp(
    agent=root_agent,
    app_name='article_generation_app',
)
# Out:
# /var/tmp/ipykernel_15789/3698050714.py:33: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent1_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_15789/3698050714.py:42: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent2_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_15789/3698050714.py:51: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   writer_agent_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_15789/3698050714.py:60: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   review_agent_remoteA2a = MyRemoteA2aAgent(
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.

# %%
agent_name = adk_app._tmpl_attrs['agent'].name
description = adk_app._tmpl_attrs['agent'].description

config = {
    'agent_framework': 'google-adk',
    'display_name': agent_name,
    'description': description,
    'requirements': [
        'google-adk==1.27.2',
        'google-genai==1.68.0',
        'google-cloud-aiplatform==1.141.0',
        'a2a-sdk==0.3.25'
    ],
    'staging_bucket': f'gs://{PROJECT_ID}',
}
    
resource_name = get_agent_resource(agent_name)
   
if resource_name is None:
    print(f'Deploying... {agent_name}: {description}')
    remote_app = client.agent_engines.create(
        agent=adk_app,
        config=config,
    )
else:
    print(f'Updating... {agent_name}: {description}')
    remote_app = client.agent_engines.update(
        name=resource_name,
        agent=adk_app,
        config=config,
    )
# Out:
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# Updating... article_generation_flow: 記事を作成する業務フローを実行するエージェント

# %%
chat_client = ChatClient(remote_app)

query = '''
こんにちは。何ができますか？
'''
response = await chat_client.async_stream_query(query)
# Out:
# こんにちは！私は記事を作成する業務フローを実行するエージェントです。
#
# 具体的には、以下のことができます。
#
# *   **テーマに関する調査レポートの作成:** まず、リサーチエージェントがテーマについて徹底的に調査し、詳細なレポートを作成します。
# *   **編集方針に沿った記事の作成とレビュー:** 次に、ライターエージェントとレビューエージェントが協力して、編集方針に沿った高品質な記事を作成します。
#
# ご希望のテーマがあれば、記事の作成に取り掛かりますので、お気軽にお申し付けください！

# %%
query = '''
「近場で秋を感じる工夫」をテーマに記事を作成してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。「近場で秋を感じる工夫」をテーマにした記事の作成に取り掛かります。
#
# まずは、リサーチエージェントに調査レポートを依頼します。
# ---
# ## リサーチエージェントが調査レポートを作成します。
# ---
# ## 調査対象のトピックを選定します。
# 承知いたしました。「近場で秋を感じる工夫」というテーマについて、以下の5つのトピックで調査レポートを作成するための項目を提案します。
#
# ---
#
# ### 「近場で秋を感じる工夫」に関する調査レポートのトピック
#
# 1.  **自宅やベランダで楽しむ秋のしつらえと香り:**
#     *   紅葉や実もの、秋色のフェイクグリーンを使ったデコレーションアイデア
#     *   秋らしい色合い（ボルドー、マスタード、カーキなど）のインテリア小物（クッション、ブランケット）の取り入れ方
#     *   金木犀、かぼちゃ、スパイス系の香りなど、秋を感じるアロマやキャンドルの活用法
#     *   温かみのある照明や間接照明で演出する秋の雰囲気
# 2.  **旬の食材で味わう秋の食卓と飲み物:**
#     *   栗、さつまいも、きのこ、かぼちゃ、柿、サンマなど、秋の味覚を使った手軽なレシピ（ご飯、汁物、スイーツなど）
#     *   温かい飲み物（チャイ、ほうじ茶ラテ、ホットワイン、ハーブティーなど）の楽しみ方
#     *   季節限定のお菓子やパン、調味料の活用法
# 3.  **近所の散策や公園で発見する秋の自然:**
#     *   近所の紅葉スポットやイチョウ並木を見つける方法（アプリ、自治体情報など）
#     *   落ち葉や木の実（どんぐり、松ぼっくりなど）を使った簡単なクラフトアイデア
#     *   秋の植物観察や虫の声を楽しむための散歩のヒント
#     *   秋空の下でのピクニックや外カフェの楽しみ方
# 4.  **ファッションや小物で取り入れる秋色と素材:**
#     *   秋らしいカラーパレット（テラコッタ、ネイビー、ブラウン、マスタードなど）を日常着に取り入れる方法
#     *   コーデュロイ、ツイード、ニット、ファーなど、温かみのある素材のアイテム選び
#     *   マフラー、ストール、手袋、ベレー帽など、季節感のある小物の活用術
#     *   秋らしい香りの香水やハンドクリームで気分を高める方法
# 5.  **五感を刺激する秋のエンターテイメントとリラックス:**
#     *   秋をテーマにした映画、読書、音楽（クラシック、ジャズ、自然音など）の楽しみ方
#     *   ハロウィンなどの秋のイベントを家庭で楽しむための飾り付けや簡単なパーティーメニュー
#     *   温かい入浴剤やバスソルト、ボディケアで心身を癒す秋のリラックスタイム
#     *   秋の夜長を楽しむための趣味や活動の提案
#
# ---
# ## 選定したトピックに基づいて、調査レポートを作成します。
# ## 「近場で秋を感じる工夫」に関する調査レポート
#
# 本調査レポートでは、「近場で秋を感じる工夫」というテーマに基づき、自宅での工夫から屋外での活動、さらにはファッションやエンターテイメントに至るまで、多角的な視点から秋を感じるための具体的な方法をまとめました。
#
# ---
#
# ### 1. 自宅やベランダで楽しむ秋のしつらえと香り
#
# 自宅やベランダで秋を感じるためには、視覚と嗅覚に訴えかける工夫が有効です。まず、紅葉した葉や実もの、かぼちゃなどのモチーフを取り入れたデコレーションは、手軽に季節感を演出できます。秋らしいボルドーやマスタード、カーキといった深みのある色のクッションカバーやブランケットをソファにかけるだけでも、部屋全体が温かく落ち着いた雰囲気に変わります。さらに、金木犀やスパイス系、アップルシナモンといった秋を感じさせるアロマキャンドルやディフューザーを焚くことで、嗅覚からも季節の移ろいを感じられます。温かみのあるオレンジ系の間接照明を取り入れることで、日没後の部屋をより一層、居心地の良い秋らしい空間に変えることができます。
#
# ### 2. 旬の食材で味わう秋の食卓と飲み物
#
# 秋の食卓は、旬の食材が豊富で、味覚から季節を感じる絶好の機会です。栗ご飯やさつまいもの味噌汁、きのこのソテー、かぼちゃのポタージュなど、秋の味覚をふんだんに使った料理は、食卓に彩りと温かさをもたらします。また、サンマの塩焼きや柿を使ったデザートも、この時期ならではの贅沢な味わいです。飲み物では、チャイやほうじ茶ラテ、ホットワインやハーブティーなど、体を温める温かい飲み物が秋の夜長にぴったりです。市販の季節限定のお菓子やパン、調味料を活用すれば、手間をかけずに手軽に秋の味覚を楽しむことができます。
#
# ### 3. 近所の散策や公園で発見する秋の自然
#
# 近所の散策や公園でも、意識を向ければ秋の豊かな自然を発見できます。スマートフォンのアプリや自治体のウェブサイト、地域の掲示板などを活用して、近所の紅葉スポットやイチョウ並木を探してみましょう。散歩中には、落ち葉やどんぐり、松ぼっくりといった木の実を集めて、簡単なリースやオブジェを作るクラフトを楽しむこともできます。秋ならではの澄んだ空気の中で、虫の音に耳を傾けたり、色づく植物を観察したりすることで、五感で秋の深まりを感じられます。レジャーシートと温かい飲み物を持参し、秋空の下でピクニックや外カフェを楽しむのも、手軽なリフレッシュ方法です。
#
# ### 4. ファッションや小物で取り入れる秋色と素材
#
# ファッションや小物を通じて、秋の雰囲気を取り入れることもできます。テラコッタ、ネイビー、ブラウン、マスタード、ボルドーといった秋らしいカラーパレットを意識して、洋服やアクセサリーを選んでみましょう。コーデュロイ、ツイード、ニット、ファーなどの温かみのある素材のアイテムは、見た目だけでなく肌触りからも季節感を演出します。マフラー、ストール、手袋、ベレー帽といった季節感のある小物を普段のコーディネートに取り入れるだけで、ぐっと秋らしい印象になります。また、金木犀やウッド系の秋らしい香りの香水やハンドクリームを使用することで、嗅覚からも秋を感じ、気分を高めることができます。
#
# ### 5. 五感を刺激する秋のエンターテイメントとリラックス
#
# 秋の夜長は、五感を刺激するエンターテイメントやリラックスタイムに最適な季節です。秋をテーマにした映画鑑賞や、心落ち着くクラシックやジャズ、自然音の音楽を聴く時間は、豊かな気分をもたらします。ハロウィンなどの秋のイベントは、自宅で飾り付けを楽しんだり、かぼちゃを使った簡単なパーティーメニューを用意したりすることで、手軽に季節感を味わうことができます。温かい入浴剤やバスソルトを入れた湯船にゆっくり浸かることや、アロマオイルを使ったボディケアは、心身を癒し、一日の疲れを和らげます。読書、手芸、パズル、日記をつけるなど、秋の夜長を楽しむための新たな趣味を見つけるのも良いでしょう。
# #### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 記事の作成を指示します。ライターエージェントとレビューエージェントが協力して記事を作成します。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# 秋の気配が感じられる季節になりましたね。遠出はなかなか難しいけど、身近な場所でも秋の訪れを五感で楽しむヒントがあるんです。
#
# ## 秋は五感で楽しむ季節！近場でできること
#
# 秋といえば、紅葉や旬の味覚、そして心地よい風。遠くの観光地に行かなくても、実は私たちの身の回りには秋を感じる工夫がたくさん散らばっています。家の中を秋色に飾ったり、ベランダで金木犀の香りに癒されたり、スーパーに並ぶ栗やさつまいもで季節の料理を楽しむのもいいですね。近所の公園を散歩して、色づいた葉っぱやどんぐりを見つけるだけでも、秋の深まりを感じられます。ファッションに秋色のスカーフを取り入れたり、温かい香りのアロマを焚いてリラックスする時間も、秋ならではの楽しみ方ですよ。
#
# ## スマホを片手に秋探し？デジタル活用術
#
# 「近場で秋を感じる」と聞くと、まずは自分の足で探すイメージがありますよね。もちろんそれも素敵ですが、現代ならではの楽しみ方として、スマホを積極的に活用してみませんか？最近では、自治体のウェブサイトや地域の情報掲示板だけでなく、紅葉の状況をリアルタイムで教えてくれるアプリも増えています。これらの情報を活用すれば、ご近所の隠れた紅葉スポットや、イチョウ並木の「見頃」を逃さずにチェックできます。散歩に出かける前にサッと検索して、最高の秋を見つけに出かけるのも楽しいですよ。
#
# ## 今日からできる！お部屋に秋色をプラスする簡単テクニック
#
# 忙しい日々の中でも、手軽に秋を取り入れるなら、まずはお部屋の模様替えから始めてみましょう。大掛かりなことをする必要はありません。例えば、ソファにボルドーやマスタード、カーキといった深みのある秋色のクッションカバーやブランケットをプラスするだけで、お部屋全体がぐっと温かく、落ち着いた雰囲気に変わります。さらに、金木犀やスパイス系の香りのアロマディフューザーを置いたり、温かみのあるオレンジ色の間接照明を灯せば、視覚と嗅覚の両方から秋の居心地の良さを感じられるはずです。
#
# ## さあ、あなただけの秋を見つけよう
#
# いかがでしたか？「近場で秋を感じる工夫」は、ちょっとした意識とアイデアで、いくらでも見つけられます。自宅でのんびり過ごす時間も、近所をお散歩する時間も、旬の食材を味わう時間も、すべてが秋の楽しみになります。五感をフル活用して、あなただけの「身近な秋」をぜひ見つけて、この素敵な季節を満喫してくださいね。
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 記事を拝見しました。
#
# ### 記事の良い点
#
# *   全体的に丁寧な言葉遣いで、読者にとって読みやすい文章です。
# *   「近場で秋を感じる工夫」というテーマに沿って、自宅での過ごし方から屋外での発見、デジタルツールの活用まで、多角的な視点からアイデアが提示されています。
# *   具体例が豊富で、読者が「やってみよう」と思える内容が複数盛り込まれています。
#
# ### 修正ポイント
#
# *   **タイトルについて**
#     *   現在のタイトル「秋は五感で楽しむ季節！近場でできること」は、テーマを伝えていますが、読者が「すぐに読まなきゃ」と感じるような具体的なメリットや緊急性が不足しています。例えば、「忙しくても大丈夫！【今日から実践】近場で秋を最大限に満喫する秘訣」のように、読者の課題に寄り添い、具体的な行動を促すタイトルに修正をご検討ください。文字数は40文字程度を目安にしてください。
# *   **導入について**
#     *   タイトルの直後に、「なぜいまこのテーマを取り上げるのか」という読者にこの記事を読む動機づけが、現状ではやや弱いと感じます。「遠出が難しい現代の状況」や「日常にこそ隠された秋の魅力」など、読者の共感を呼び、読み進めてもらうための導入をさらに強化してください。
# *   **サブタイトルについて**
#     *   記事の条件として「各セクションのサブタイトルには、絵文字を用いて親しみやすさを出すこと」とあります。現在の記事では絵文字が使用されていませんので、各サブタイトルに秋らしい絵文字や、内容に合った絵文字を追加してください。例：`📱スマホを片手に秋探し？デジタル活用術`、`🍂今日からできる！お部屋に秋色をプラスする簡単テクニック`など。
# *   **具体例について**
#     *   具体例は記事全体に豊富に盛り込まれていますが、より明確に「読者が今日から実践できる具体例が3つ以上」として提示されていることが読者に伝わるよう、必要であれば各セクションの冒頭などで「今日からできる具体的な方法は次の3つです！」のような言及を加えることもご検討ください。（現状でも複数提示されているので、この点の優先度は低めです。）
# #### レビューに基づいて記事の修正を依頼しますか？

# %% [markdown]
# # A2A リモートエージェントを Agent Engine にデプロイする例
#
# このノートブックは、下記の記事のコードを実行したサンプルです。
#
# - [【Agent Engine の A2A 対応記念】A2A リモートエージェントを Agent Engine にデプロイする](https://zenn.dev/google_cloud_jp/articles/04cdf10fb5cd70)

# %% [markdown]
# ## 環境準備

# %%
# %pip install --user --upgrade \
    google-adk==1.27.2 \
    google-genai==1.68.0 \
    google-cloud-aiplatform==1.141.0 \
    a2a-sdk==0.3.25

# %%
import IPython
app = IPython.Application.instance()
_ = app.kernel.do_shutdown(True)

# %%
import asyncio, httpx, json, os, uuid
from IPython.display import Markdown, display
from google.auth import default
from google.auth.transport.requests import Request
import vertexai
from vertexai.agent_engines import AdkApp
# ADK
from google.genai.types import Part, Content, HttpOptions
from google.adk.agents.callback_context import CallbackContext
from google.adk.agents.llm_agent import LlmAgent
from google.adk.agents.remote_a2a_agent import RemoteA2aAgent
from google.adk.agents.sequential_agent import SequentialAgent
from google.adk.artifacts import GcsArtifactService
from google.adk.auth.credential_service.in_memory_credential_service import InMemoryCredentialService
from google.adk.memory.in_memory_memory_service import InMemoryMemoryService
from google.adk.models import LlmResponse, LlmRequest
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService, VertexAiSessionService

# A2A
from a2a.client import ClientConfig, ClientFactory
from a2a.types import AgentCard, TransportProtocol
from google.adk.a2a.executor.a2a_agent_executor import A2aAgentExecutor
from google.adk.a2a.utils.agent_card_builder import AgentCardBuilder

# Agent Engine
from vertexai import agent_engines
from vertexai.preview.reasoning_engines import A2aAgent
from vertexai.preview.reasoning_engines.templates.a2a import create_agent_card

[PROJECT_ID] = !gcloud config list --format 'value(core.project)' 2>/dev/null
[PROJECT_NUMBER] = !gcloud projects describe {PROJECT_ID} --format='value(projectNumber)' 2>/dev/null
LOCATION = 'us-central1'

vertexai.init(project=PROJECT_ID, location=LOCATION)

os.environ['GOOGLE_CLOUD_PROJECT'] = PROJECT_ID
os.environ['GOOGLE_CLOUD_LOCATION'] = LOCATION
os.environ['GOOGLE_GENAI_USE_VERTEXAI'] = 'True'

BUCKET_NAME = f'{PROJECT_ID}_session_mapping'
# !gsutil ls -b gs://{BUCKET_NAME} 2>/dev/null || \
 gsutil mb -b on -l {LOCATION} gs://{BUCKET_NAME}
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# gs://etsuji-15pro-poc_session_mapping/

# %%
class ChatClient:
    def __init__(self, adk_app, user_id='default_user'):
        self.adk_app = adk_app
        self.user_id = user_id
        self.session_id = None

    async def async_stream_query(self, message, show=True):
        if not self.session_id:
            session = await self.adk_app.async_create_session(
                user_id=self.user_id,
            )
            self.session_id = getattr(session, 'id', None) or session['id']

        result = []
        async for event in self.adk_app.async_stream_query(
            user_id=self.user_id,
            session_id=self.session_id,
            message=message,
        ):
            author = event['author']
            if ('content' in event and 'parts' in event['content']):
                response = '\n'.join(
                    [p['text'] for p in event['content']['parts'] if 'text' in p]
                )
                if response:
                    if show:
                        display(Markdown(response))
                    result.append(response)
        return '\n'.join(result)

# %% [markdown]
# ## リモートエージェントの定義

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
指定されたテーマの記事を執筆する際に参考となるトピックを５項目程度のリストにまとめます。
後段のエージェントがこのリストに基づいて、調査レポートを作成します。

* 出力形式
日本語で出力。
'''

research_agent1 = LlmAgent(
    name='research_agent1',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
指定されたテーマの記事を執筆する際に参考となるトピックを５項目程度のリストにまとめます。
後段のエージェントがこのリストに基づいて、調査レポートを作成します。

* 出力形式
日本語で出力。
'''

research_agent1 = LlmAgent(
    name='research_agent1',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
前段のエージェントは、５項目程度の調査対象トピックを指定します。

* 出力形式
日本語で出力。
調査レポートは、トピックごとに客観的情報をまとめます。各トピックについて、５文以上の長さで記述すること。
'''

research_agent2 = LlmAgent(
    name='research_agent2',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、特定のテーマに関する気軽な読み物記事を書くことです。
記事の「テーマ」と、その内容に関連する「調査レポート」が与えられるので、
調査レポートに記載の客観的事実に基づいて、信頼性のある読み物記事を書いてください。

**出力条件**
- トピックに関してある程度の基礎知識がある読者を前提として、数分で気軽に読める内容にしてください。
- 比較的カジュアルで語りかける口調の文章にします。
- 思考過程は出力せずに、最終結果だけを出力します。
- 記事タイトルは付けないで、次の構成で出力します。各セクションタイトルは、内容に合わせてアレンジしてください。
0. 導入：セクションタイトルを付けないで、この記事を読みたくなる導入を１〜２文にまとめます。
1. 概要：トピックの全体像をまとめて簡単に説明します。
2. 最新情報：特に注目したい新しい情報を取り上げます。
3. 実践：トピックに関して、読者自身がやってみるとよさそうな事を１つ紹介します。
4. まとめ

- 各セクションのタイトルはマークダウンヘッダ ## 付けます。必要に応じて箇条書きのマークダウンを使用します。
- それ以外のマークダウンによる装飾は行いません。

**レビュアーの指示に応じた修正**
- レビュアーが修正ポイントを提示した際は、出力条件にこだわらずに、直前の記事を指示に従って修正してください。
- 修正ポイント以外の部分は、修正する必要ありません。
'''

writer_agent = LlmAgent(
    name='writer_agent',
    model='gemini-2.5-flash',
    description='特定のテーマに関する読み物記事を書くエージェント',
    instruction=instruction,
)

# %%
instruction = f'''
あなたの役割は、読み物記事をレビューして、記事の条件にあった内容にするための改善コメントを与える事です。

* 記事の条件
- 記事は、はじめに４０文字程度のタイトルがあること。
　今日から役立つ生活情報があって「すぐに読まなきゃ」と読者が感じるタイトルにすること。
　タイトルはマークダウンヘッダ # をつけること。
- タイトルの直後に「なぜいまこのテーマを取り上げるのか」をまとめた導入を加えて、読者にこの記事を読む動機づけを与えます。
- 各セクションのサブタイトルには、絵文字を用いて親しみやすさを出すこと。
- 読者が今日から実践できる具体例が３つ以上紹介されていること。

* 出力形式
- 日本語で出力。
- はじめに、記事の良い点を説明します。
- 次に、修正ポイントを箇条書きで出力します。
'''

review_agent = LlmAgent(
    name='review_agent',
    model='gemini-2.5-flash',
    description='読み物記事をレビューするエージェント',
    instruction=instruction,
)

# %% [markdown]
# ## Agent Engine へのデプロイ

# %%
client = vertexai.Client(
    project=PROJECT_ID,
    location=LOCATION,
    http_options=HttpOptions(
        api_version='v1beta1',
        base_url=f'https://{LOCATION}-aiplatform.googleapis.com/'
    ),
)

def get_agent_resource(agent_name):
    for agent in client.agent_engines.list():
        if agent.api_resource.display_name == agent_name:
            return agent.api_resource.name
    return None

# %%
class GcsMappedVertexAiSessionService(VertexAiSessionService):
    """
    A wrapper for VertexAiSessionService that persists the mapping between
    the A2A context_id and the Vertex-generated session_id using an
    ArtifactService (like GcsArtifactService).

    This approach creates one artifact (file) per conversation to avoid
    the race conditions of a single shared mapping file.
    """

    def __init__(
        self,
        artifact_service,
        **kwargs
    ):
        super().__init__(**kwargs)
        self._artifact_service = artifact_service

    def _get_mapping_artifact_id(self, user_id, context_id):
        agent_engine_id = os.environ.get('GOOGLE_CLOUD_AGENT_ENGINE_ID')
        return f"user:a2a_session_mappings_{agent_engine_id}_{user_id}_{context_id}" # use-scope artifact

    async def create_session(
        self, app_name, user_id, state={},
        session_id=None # This is the A2A context_id
    ):
        """
        Creates a new session in Vertex, then creates an artifact file that
        maps the provided context_id to the new Vertex-generated session_id.
        """
        # 1. Create the session in Vertex AI, which will generate its own unique ID.
        new_session = await super().create_session(
            app_name=app_name,
            user_id=user_id,
            state=state,
        )
        real_session_id = new_session.id
        print(f"Created new Vertex session '{real_session_id}' for user '{user_id}'.", flush=True)

        # 2. If a context_id was provided, persist the mapping.
        if session_id:
            context_id = session_id
            artifact_id = self._get_mapping_artifact_id(user_id, context_id)
            print(f"Persisting mapping: context_id '{context_id}' -> session_id '{real_session_id}' in artifact '{artifact_id}'.", flush=True)

            mapping_artifact = Part.from_bytes(
                data=real_session_id.encode('utf-8'),
                mime_type='text/plain',
            )
            await self._artifact_service.save_artifact(
                app_name=app_name.replace('/', '_'),
                user_id=user_id,
                session_id=real_session_id,
                filename=artifact_id,
                artifact=mapping_artifact,
            )

        return new_session

    async def get_session(
        self, app_name, user_id,
        session_id, # This is the A2A context_id
        config=None,
    ):
        """
        Uses the A2A context_id to find the corresponding artifact file,
        reads the real Vertex session_id from it, and retrieves the session.
        """
        context_id = session_id
        artifact_id = self._get_mapping_artifact_id(user_id, context_id)

        try:
            # 1. Try to read the mapping file from the artifact store.
            print(f"Looking for mapping artifact '{artifact_id}'.", flush=True)
            mapping_artifact = await self._artifact_service.load_artifact(
                app_name=app_name.replace('/', '_'),
                user_id=user_id,
                session_id=None, # works for user-scope artifact
                filename=artifact_id,
            )
            if mapping_artifact is None:
                print(f"Mapping artifact '{artifact_id}' not found. No session exists for this context_id yet.", flush=True)
                new_session = await self.create_session(
                    app_name=app_name,
                    user_id=user_id,
                    session_id=context_id,
                )
                real_session_id = new_session.id
            else:
                real_session_id = mapping_artifact.inline_data.data.decode('utf-8')
                print(f"Found mapping: context_id '{context_id}' -> real_session_id '{real_session_id}'.", flush=True)

            # 2. Use the real_session_id to get the actual session from Vertex.
            session = await super().get_session(
                app_name=app_name,
                user_id=user_id,
                session_id=real_session_id,
                config=config,
            )
            return session

        except Exception as e:
            print(f"Failed to get session for context_id '{context_id}': {e}", flush=True)
            return None


def get_create_runner_class(agent):
    async def create_runner():
        project_id = os.environ.get('GOOGLE_CLOUD_PROJECT')
        location = os.environ.get('GOOGLE_CLOUD_LOCATION')
        agent_engine_id = os.environ.get('GOOGLE_CLOUD_AGENT_ENGINE_ID')
        resource_name = None
        if project_id and location and agent_engine_id:
            resource_name = f'projects/{project_id}/locations/{location}/reasoningEngines/{agent_engine_id}'
        artifact_service = GcsArtifactService(bucket_name=BUCKET_NAME)
        session_service = GcsMappedVertexAiSessionService(
            artifact_service=artifact_service
        )
        return Runner(
            # Use resource_name as app_name for VertexAiSessionService.
            app_name=resource_name or agent.name,
            agent=agent,
            artifact_service=artifact_service,
            session_service=session_service,
            memory_service=InMemoryMemoryService(),
            credential_service=InMemoryCredentialService(),
        )
    return create_runner


def get_agent_executor_class(agent):
    def agent_executor_builder():
        return A2aAgentExecutor(
            runner=get_create_runner_class(agent),
        )       
    return agent_executor_builder


async def get_agent_card(agent):
    builder = AgentCardBuilder(agent=agent)
    adk_agent_card = await builder.build()
    return create_agent_card(
        agent_name=adk_agent_card.name,
        description=adk_agent_card.description,
        skills=adk_agent_card.skills
    )

# %%
agents = {
    'research_agent1_a2a': research_agent1,
    'research_agent2_a2a': research_agent2,
    'writer_agent_a2a': writer_agent,
    'review_agent_a2a': review_agent,
}

async def deploy_or_update_agent(agent_name, agent, client, project_id):
    # prepare staging bucket
    bucket_uri = f'gs://{project_id}_{agent_name}'
    # !gsutil ls -b {bucket_uri} 2>/dev/null || gsutil mb -b on -l {LOCATION} {bucket_uri}
    
    a2a_agent = A2aAgent(
        agent_card=await get_agent_card(agent),
        agent_executor_builder=get_agent_executor_class(agent)
    )

    config = {
        'display_name': agent_name,
        'description': a2a_agent.agent_card.description,
        'requirements': [
            'google-adk==1.27.2',
            'google-genai==1.68.0',
            'google-cloud-aiplatform==1.141.0',
            'a2a-sdk==0.3.25'
        ],
        'staging_bucket': bucket_uri,
    }
    
    resource_name = get_agent_resource(agent_name)
    
    if resource_name is None:
        print(f'Deploying... {agent_name}: {agent.description}')
        remote_a2a_agent = await asyncio.to_thread(
            client.agent_engines.create,
            agent=a2a_agent,
            config=config,
        )
    else:
        print(f'Updating... {agent_name}: {agent.description}')
        remote_a2a_agent = await asyncio.to_thread(
            client.agent_engines.update,
            name=resource_name,
            agent=a2a_agent,
            config=config,
        )
        
    return remote_a2a_agent

async def deploy_all_agents():
    tasks = [
        deploy_or_update_agent(agent_name, agent, client, PROJECT_ID)
        for agent_name, agent in agents.items()
    ]
    results = await asyncio.gather(*tasks)
    return results

await deploy_all_agents()
# Out:
# gs://etsuji-15pro-poc_research_agent1_a2a/
# /var/tmp/ipykernel_18646/735596227.py:140: UserWarning: [EXPERIMENTAL] AgentCardBuilder: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   builder = AgentCardBuilder(agent=agent)
# The following requirements are missing: {'cloudpickle', 'pydantic'}
# Updating... research_agent1_a2a: 記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）
# gs://etsuji-15pro-poc_research_agent2_a2a/
# Updating... research_agent2_a2a: 記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）
# /var/tmp/ipykernel_18646/735596227.py:140: UserWarning: [EXPERIMENTAL] AgentCardBuilder: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   builder = AgentCardBuilder(agent=agent)
# The following requirements are missing: {'cloudpickle', 'pydantic'}
# gs://etsuji-15pro-poc_writer_agent_a2a/
# The following requirements are missing: {'cloudpickle', 'pydantic'}
# Updating... writer_agent_a2a: 特定のテーマに関する読み物記事を書くエージェント
# gs://etsuji-15pro-poc_review_agent_a2a/
# The following requirements are missing: {'cloudpickle', 'pydantic'}
# Updating... review_agent_a2a: 読み物記事をレビューするエージェント
# [AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/6599239103097602048'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/5230144816376971264'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/4824820849913626624'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/8808254720322830336')]

# %% [markdown]
# ## RemoteA2aAgent を用いた root agent の定義

# %%
class GoogleAuthRefresh(httpx.Auth):
    def __init__(self, scopes):
        self.credentials, _ = default(scopes=scopes)
        self.transport_request = Request()
        self.credentials.refresh(self.transport_request)

    def auth_flow(self, request):
        if not self.credentials.valid:
            self.credentials.refresh(self.transport_request)
        request.headers['Authorization'] = f'Bearer {self.credentials.token}'
        yield request


factory = ClientFactory(
    ClientConfig(
        supported_transports=[TransportProtocol.http_json],
        use_client_preference=True,
        httpx_client=httpx.AsyncClient(
            timeout=60,
            headers={'Content-Type': 'application/json'},
            auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
        ),
    ),
)

# %%
resource_name = get_agent_resource('research_agent1_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
research_agent1_remote = RemoteA2aAgent(
    name="research_agent1",
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('research_agent2_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
research_agent2_remote = RemoteA2aAgent(
    name="research_agent2",
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('writer_agent_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
writer_agent_remote = RemoteA2aAgent(
    name="writer_agent",
    description='特定のテーマに関する読み物記事を書くエージェント',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('review_agent_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
review_agent_remote = RemoteA2aAgent(
    name="review_agent",
    description='読み物記事をレビューするエージェント',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)
# Out:
# /var/tmp/ipykernel_18646/1893291524.py:3: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent1_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_18646/1893291524.py:12: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent2_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_18646/1893291524.py:21: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   writer_agent_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_18646/1893291524.py:30: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   review_agent_remote = RemoteA2aAgent(

# %%
def get_print_agent(text):
    def before_model_callback(
        callback_context: CallbackContext, llm_request: LlmRequest
    ) -> LlmResponse:
        return LlmResponse(
            content=Content(
                role='model', parts=[Part(text=text)],
            )
        )
    return LlmAgent(
        name='print_agent',
        model='gemini-2.0-flash', # not used
        description='',
        instruction = '',
        before_model_callback=before_model_callback,
    )

research_agent = SequentialAgent(
    name='research_agent',
    sub_agents=[
        get_print_agent('\n---\n## リサーチエージェントが調査レポートを作成します。\n---\n'),
        get_print_agent('\n## 調査対象のトピックを選定します。\n'),
        research_agent1_remote,
        get_print_agent('\n## 選定したトピックに基づいて、調査レポートを作成します。\n'),
        research_agent2_remote,
        get_print_agent('\n#### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？\n'),
    ],
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント',
)

write_and_review_agent = SequentialAgent(
    name='write_and_review_agent',
    sub_agents=[
        get_print_agent('\n---\n## ライターエージェントが記事を執筆します。\n---\n'),
        writer_agent_remote,
        get_print_agent('\n---\n## レビューエージェントが記事をレビューします。\n---\n'),
        review_agent_remote,
       get_print_agent('\n#### レビューに基づいて記事の修正を依頼しますか？\n'),
    ],
    description='記事を作成、レビューする。',
)

root_agent = LlmAgent(
    name='article_generation_flow',
    model='gemini-2.0-flash',
    instruction = '''
何ができるか聞かれた場合は、以下の処理をすることをわかりやすくフレンドリーな文章にまとめて返答してください。

- ユーザーが指定したテーマの記事を作成する業務フローを実行する。
- はじめに、テーマに関する調査レポートを作成する。
- その後、ライターエージェントとレビューエージェントが協力して、編集方針に則した記事を作成する。

ユーザーが記事のテーマを指定した場合は、次のフローを実行します。

1. そのテーマの記事の作成に取り掛かる旨を伝えて、research_agent に転送して、調査レポートを依頼します。
2. ユーザー記事の作成を支持したら、write_and_review_agent に転送して、記事の作成とレビューを依頼します。
3. ユーザーが記事の修正を希望する場合は、write_and_review_agent に転送します。

**条件**
research_agent のニックネームは、リサーチエージェント
write_and_review_agent のネックネームは、ライターエージェントとレビューエージェント

''',
    sub_agents=[
        research_agent,
        write_and_review_agent,
    ],
    description='記事を作成する業務フローを実行するエージェント'
)


adk_app = AdkApp(
    agent=root_agent,
    app_name='article_generation_app',
)
# Out:
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.

# %% [markdown]
# ## 実行例

# %%
chat_client = ChatClient(adk_app)

query = '''
こんにちは。何ができますか？
'''
response = await chat_client.async_stream_query(query)
# Out:
# こんにちは！私は、ユーザーさんが指定したテーマの記事を作成するお手伝いをします。
#
# まずは、リサーチエージェントがテーマに関する調査レポートを作成します。その後、ライターエージェントとレビューエージェントが協力して、編集方針に沿った記事を作成します。
#
# 何か記事にしたいテーマはありますか？

# %%
query = '''
「近場で秋を感じる工夫」をテーマに記事を作成してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# はい、「近場で秋を感じる工夫」というテーマの記事作成に取り掛かります！まずは、リサーチエージェントに依頼して、調査レポートを作成してもらいますね。
# ---
# ## リサーチエージェントが調査レポートを作成します。
# ---
# ## 調査対象のトピックを選定します。
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# はい、承知いたしました。「近場で秋を感じる工夫」をテーマにした記事の執筆にあたり、以下のトピックについて調査レポートを作成します。
#
# ---
#
# ### 調査レポート対象トピック：
#
# 1.  **自宅やベランダで秋を取り入れるインテリア・香り・小物使い**
#     *   部屋の飾り付け（落ち葉、木の実、秋色のファブリックなど）
#     *   アロマやフレグランスで秋の香りを演出する方法（金木犀など）
#     *   秋らしい食器やマグカップ、キャンドルなどの活用法
#
# 2.  **近所の公園や庭、散歩道で秋の自然を発見する楽しみ方**
#     *   身近な場所での紅葉・黄葉の探し方や鑑賞のポイント
#     *   落ち葉や木の実、どんぐりなどを拾うアクティビティとその活用法
#     *   秋の草花や野鳥、虫の声を楽しむ方法
#
# 3.  **旬の食材を使った「おうち秋ごはん」と食卓の演出**
#     *   スーパーなどで手軽に購入できる秋の味覚（芋、栗、きのこ、柿など）を使った簡単レシピ
#     *   季節限定のスイーツやお茶、飲み物で秋を味わう方法
#     *   食卓に秋らしい彩りを加える工夫（テーブルウェア、盛り付けなど）
#
# 4.  **五感を刺激して秋を感じるインドア・アウトドアのリラックスタイム**
#     *   秋の読書、音楽、映画鑑賞で感性を磨く方法
#     *   肌触りの良いブランケットや温かい飲み物で触覚から秋を感じる工夫
#     *   秋の気配を感じる朝の散歩や夕焼け鑑賞、風の音を楽しむ時間
#
# 5.  **手軽に楽しめる秋のクラフト・DIYやミニイベント**
#     *   拾った落ち葉や木の実を使った簡単なリースやオーナメント作り
#     *   秋の風景を写真に収めたり、絵手紙にしたりするアートな楽しみ方
#     *   自宅や近隣で開催される小規模な秋のイベント（マルシェ、収穫祭など）への参加
#
# ---
#
# これらのトピックに基づいて、詳細な情報を収集し、記事作成に役立つレポートを作成します。
# ## 選定したトピックに基づいて、調査レポートを作成します。
# ## 調査レポート：近場で秋を感じる工夫
#
# 本レポートでは、「近場で秋を感じる工夫」をテーマに、記事執筆に必要な以下の5つのトピックについて調査した結果をまとめます。各トピックにおいて、自宅から近隣まで、手軽に実践できる秋の楽しみ方について客観的な情報を提供します。
#
# ---
#
# ### 1. 自宅やベランダで秋を取り入れるインテリア・香り・小物使い
#
# 自宅やベランダは、手軽に秋の雰囲気を取り入れられるプライベートな空間です。部屋の飾り付けでは、落ち葉や木の実、ドライフラワーを花瓶に飾ったり、秋色（ボルドー、マスタード、テラコッタなど）のファブリック（ブランケット、クッションカバー、テーブルランナーなど）に交換するだけで、暖かみのある空間が生まれます。香りの演出には、金木犀、りんご、シナモン、グローブといったスパイス系の香りのアロマディフューザーやキャンドルが秋らしさを高めます。また、秋らしい焼き物の食器や落ち着いた色合いのマグカップを使用することで、日々の食事やティータイムも季節感あふれるものになります。窓辺や玄関には、ハロウィンモチーフのかぼちゃの置物や収穫祭をイメージさせる小物類を配置するのも効果的です。
#
# ### 2. 近所の公園や庭、散歩道で秋の自然を発見する楽しみ方
#
# 身近な場所でも、秋の自然は豊かに存在しています。近所の公園や庭、散歩道では、街路樹や公園の木々が紅葉や黄葉で色づき始め、季節の移ろいを視覚的に楽しむことができます。イチョウの鮮やかな黄色やモミジの深紅など、樹種によって異なる葉の色合いを観察するのも一興です。地面に目を向ければ、落ち葉やどんぐり、松ぼっくりなどの木の実を見つけられ、これらを拾い集める活動は子供から大人まで楽しめます。さらに、コスモスや彼岸花、ススキといった秋ならではの草花を見つけて鑑賞したり、夕暮れ時に聞こえるコオロギなどの虫の声や渡り鳥の姿に耳を傾けたりすることも、五感で秋を感じる楽しみ方です。
#
# ### 3. 旬の食材を使った「おうち秋ごはん」と食卓の演出
#
# 秋は食材の宝庫であり、スーパーなどでも手軽に旬の味覚を購入できます。芋（さつまいも、里芋）、栗、きのこ類、柿、梨、サンマといった秋の代表的な食材を使った料理は、食卓に季節感をもたらします。これらの食材を活用した炊き込みご飯、グラタン、シチュー、ポタージュなどは、家庭でも簡単に作れる定番の秋メニューです。また、栗きんとんやスイートポテト、かぼちゃプリンなど、旬の素材を使った季節限定のスイーツを手作りするのも良いでしょう。温かいほうじ茶や和紅茶、ハーブティー、あるいはホットワインなどは、秋の夜長のリラックスタイムにぴったりです。食卓には、落ち着いた色合いのランチョンマットやコースター、カボチャの形をした小皿などを添えることで、より秋らしい雰囲気を演出できます。
#
# ### 4. 五感を刺激して秋を感じるインドア・アウトドアのリラックスタイム
#
# 秋の季節は、五感を研ぎ澄ましてリラックスするのに最適な時期です。肌寒い秋の夜長は、読書、音楽鑑賞、映画鑑賞といったインドアでの感性を磨く活動に集中しやすい環境を提供します。肌触りの良いウールやカシミヤのブランケットにくるまって、温かい飲み物をゆっくりと楽しむことで、触覚から秋の心地よさを感じられます。また、窓を開けて秋の澄んだ空気を感じたり、風の音や雨の音に耳を傾けたりすることも、感覚を刺激するリラックス法です。早朝や夕暮れ時に近所を散歩し、秋の空の色や、土や落ち葉が混じった特有の匂いの変化を感じ取るのも、アウトドアで秋を深く味わう時間となります。焚き火の映像や音、薪ストーブの香りなども、視覚、聴覚、嗅覚で秋を楽しむ手段として人気です。
#
# ### 5. 手軽に楽しめる秋のクラフト・DIYやミニイベント
#
# 手軽にできるクラフトやDIYを通じて、秋を創造的に楽しむことができます。公園で拾った落ち葉や木の実を使って、リースやガーランド、フォトフレームを制作するのは、秋の思い出作りにもなります。子供と一緒にどんぐりや松ぼっくりで動物や人形を作る工作は、親子のコミュニケーションにも繋がり、創造性を育む活動としても最適です。また、紅葉や夕焼け、収穫物といった秋の風景をスマートフォンやカメラで撮影し、SNSに投稿したり、手作りの絵葉書やメッセージカードに秋のモチーフを描いて大切な人に送ったりするのも良いでしょう。地域によっては、小規模なマルシェや農産物直売所、収穫祭などが開催されることがあり、これらに足を運ぶことで、地元の秋の恵みを体験し、地域コミュニティとの繋がりを感じる機会にもなります。
# #### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。それでは、ライターエージェントとレビューエージェントに記事の作成を依頼します。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# 気づけば日も短くなり、吹く風もどこかひんやり。秋の気配をひしひしと感じるこの頃、遠出しなくても身近な場所で秋をもっと楽しんでみませんか？
#
# ## 概要
#
# 秋は、五感を刺激するものがたくさん。実は、自宅や近所のいつもの場所でも、少し意識するだけで豊かな秋を感じることができます。たとえば、お部屋に秋色のクッションやブランケットを取り入れたり、金木犀の香りのアロマを焚いたりするだけで、グッと季節感がアップします。近所の公園や散歩道では、色づいた葉っぱやどんぐり、松ぼっくり探しも楽しいですよね。食卓には、旬のさつまいもや栗、きのこなどを並べて「おうち秋ごはん」を楽しむのも最高です。温かい飲み物片手に読書にふけったり、拾った木の実でクラフトを作ったりと、工夫次第で秋はもっと深く味わえるんですよ。
#
# ## 最新情報
#
# 最近、特に注目されているのは、この「五感を意識的に使う」という秋の楽しみ方です。ただ目で紅葉を「見る」だけでなく、金木犀の甘い香りを「嗅ぎ」、コオロギの鳴き声を「聴き」、温かいお茶で体の内側から「触覚」を刺激し、旬の食材をじっくり「味わう」。デジタルデバイスから少し離れて、全身で秋を感じる「マインドフルネスな秋時間」を過ごす人が増えています。焚き火の映像や音、薪ストーブの香りをデジタルコンテンツで楽しむといった、現代ならではの取り入れ方も広がっていますね。
#
# ## 実践
#
# まずは、いつもの散歩コースを「秋探しコース」に変えてみませんか？ スマートフォンはしまっておいて、周りの景色や音、香り、そして足元の小さな変化に意識を向けて歩いてみましょう。
#
# *   色づいた葉っぱのグラデーションに目を凝らしたり
# *   金木犀の香りがどこから漂ってくるか探したり
# *   風に揺れるススキの音に耳を傾けたり
# *   地面に落ちているどんぐりや松ぼっくりを集めてみたり
#
# 見つけてきた落ち葉や木の実で、簡単なリースやオーナメントを作って玄関やリビングに飾れば、そこがもうあなただけの「秋のギャラリー」に！手軽に始められるクラフトで、身近な秋を最大限に楽しんでみてください。
#
# ## まとめ
#
# 秋は深まるばかり。遠くへ行かなくても、ちょっとした工夫と「五感を意識する」という視点を持つだけで、日々の暮らしの中にたくさんの秋を見つけることができます。あなたなりの秋の彩りを見つけて、この豊かな季節を心ゆくまで味わってくださいね。
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 記事のレビュー依頼ありがとうございます。
#
# ### 記事の良い点
#
# *   秋を五感で楽しむというテーマ設定が明確で、読者にとって身近で実践しやすい内容になっています。
# *   自宅や近所の散歩道など、遠出せずに楽しめる工夫が具体的に書かれています。
# *   「最新情報」でマインドフルネスやデジタルコンテンツの活用に触れている点は、現代的な視点を取り入れていて面白いです。
# *   「実践」セクションでは、複数の具体的な行動が箇条書きで提示されており、読者がすぐに試せるアイデアが豊富です。
#
# ### 修正ポイント
#
# 以下の点について修正を加えることで、より記事の条件に合った魅力的な内容になるでしょう。
#
# *   **タイトルの修正:**
#     *   現在のタイトルは67文字と長いため、40文字程度に短縮してください。
#     *   読者が「すぐに読まなきゃ！」と感じるような、具体的なメリットや緊急性を感じさせる言葉を取り入れてください。
#     *   タイトルの先頭にマークダウンヘッダ `#` を追加してください。
#     *   （例案）`# 🍁たった5分で秋を感じる！今日からできる五感活用術`
# *   **導入の追加:**
#     *   タイトル直後に、「なぜいまこのテーマを取り上げるのか」を明確に伝える導入文（2〜3行程度）を追加してください。
#     *   読者に記事を読む動機づけを与えるような内容にしてください。
# *   **サブタイトルへの絵文字追加:**
#     *   すべてのセクションのサブタイトルに、内容に合った絵文字を追加し、親しみやすさを出してください。
#     *   （例）`## 概要` → `## 🍂はじめに`、`## 実践` → `## 💡今日からできる秋の楽しみ方`
# *   **具体例の提示方法とセクション構成の改善:**
#     *   「実践」セクションで具体的な行動が複数紹介されていますが、記事全体で「読者が今日から実践できる具体例が3つ以上」という条件をより明確に満たすため、各具体例を独立したセクションとして細分化し、それぞれのセクションタイトルにも絵文字を入れてください。
#     *   例えば、「お部屋で秋を感じるには？」「お散歩で見つける秋の宝物」「旬の食材で秋の食卓を彩る」などのように具体的に提示し、各セクションで3つ以上の実践例を盛り込むと良いでしょう。
#     *   現在の「概要」や「最新情報」で触れている内容（インテリア、香り、食、五感の活用など）も、具体的な実践例のセクションに統合・再配置することで、より分かりやすくなります。
#
# これらの修正を行うことで、記事の魅力がさらに増し、読者にとって役立つ情報が詰まった記事になるはずです。
# #### レビューに基づいて記事の修正を依頼しますか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。レビューエージェントからのフィードバックを元に、ライターエージェントに記事の修正を依頼します。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# # 🍁遠出なしで秋を満喫！今日からできる五感活用術
#
# 気づけば日も短くなり、吹く風もどこかひんやり。秋の気配をひしひしと感じるこの頃、「どこか紅葉を見に行きたいけど、なかなか時間が…」なんて思っていませんか？ご安心ください！遠出しなくても、いつもの日常に少し工夫を加えるだけで、五感をフルに使って秋を深く味わうことができるんです。さあ、あなたも今日から「身近な秋」を見つけてみませんか？
#
# ## 🍂はじめに
#
# 秋は、五感を刺激するものがたくさん。実は、自宅や近所のいつもの場所でも、少し意識するだけで豊かな秋を感じることができます。たとえば、お部屋に秋色のクッションやブランケットを取り入れたり、金木犀の香りのアロマを焚いたりするだけで、グッと季節感がアップします。近所の公園や散歩道では、色づいた葉っぱやどんぐり、松ぼっくり探しも楽しいですよね。食卓には、旬のさつまいもや栗、きのこなどを並べて「おうち秋ごはん」を楽しむのも最高です。温かい飲み物片手に読書にふけったり、拾った木の実でクラフトを作ったりと、工夫次第で秋はもっと深く味わえるんですよ。
#
# ## 🏠おうちで秋を感じる工夫
#
# 自宅やベランダは、手軽に秋の雰囲気を取り入れられるプライベートな空間です。
# *   **秋色ファブリックで衣替え:** ボルドー、マスタード、テラコッタといった秋色のブランケットやクッションカバーに変えるだけで、お部屋が暖かく落ち着いた印象になります。
# *   **香りで演出する秋:** 金木犀、りんご、シナモンなどの香りのアロマディフューザーやキャンドルを焚けば、嗅覚から秋を感じられます。
# *   **季節の小物で彩る:** 窓辺にハロウィンモチーフのかぼちゃを置いたり、収穫祭をイメージさせるドライフラワーを飾ったりするのもおすすめです。秋らしい焼き物の食器やマグカップを使うのも良いですね。
#
# ## 🚶‍♀️近所で見つける秋の宝物
#
# 身近な場所でも、秋の自然は豊かに存在しています。いつもの散歩コースも「秋探しコース」に変えてみましょう。
# *   **紅葉・黄葉ハント:** 街路樹や公園の木々が色づき始める様子を観察。イチョウの鮮やかな黄色やモミジの深紅など、樹種による葉の色の違いに注目してみましょう。
# *   **落ち葉＆木の実コレクション:** 地面に目を向ければ、色とりどりの落ち葉やどんぐり、松ぼっくりなどがたくさん。これらを拾い集めるのも楽しいアクティビティです。
# *   **秋の音色に耳を澄ます:** 夕暮れ時に聞こえるコオロギの鳴き声や、風に揺れるススキの音、渡り鳥の姿を探してみるなど、聴覚や視覚で秋を感じてみましょう。
#
# ## 🍽️旬の食材で楽しむ秋の食卓
#
# 秋は食材の宝庫！スーパーでも手軽に旬の味覚が手に入ります。
# *   **「おうち秋ごはん」を楽しむ:** さつまいも、栗、きのこ類、柿、サンマなど、秋の代表的な食材を使った炊き込みご飯やグラタン、ポタージュなど、簡単に作れる秋メニューに挑戦してみましょう。
# *   **季節限定スイーツを味わう:** 栗きんとんやスイートポテト、かぼちゃプリンなど、旬の素材を使った手作りスイーツで贅沢なティータイムを。
# *   **飲み物も秋らしく:** 温かいほうじ茶や和紅茶、ハーブティー、またはホットワインなどは、秋の夜長のリラックスタイムにぴったり。落ち着いた色合いのランチョンマットや小皿で食卓を演出するのも忘れずに。
#
# ## ✨五感を磨くリラックスタイム
#
# 肌寒い秋の季節は、五感を研ぎ澄ましてリラックスするのに最適な時期です。
# *   **インドアで感性を磨く:** 肌触りの良いブランケットにくるまって、読書、音楽鑑賞、映画鑑賞に没頭してみましょう。温かい飲み物をゆっくりと楽しむことで、触覚から秋の心地よさを感じられます。
# *   **アウトドアで深呼吸:** 窓を開けて秋の澄んだ空気を感じたり、風の音や雨の音に耳を傾けたりすることも、感覚を刺激するリラックス法です。早朝や夕暮れ時に散歩して、秋の空の色や土や落ち葉が混じった特有の匂いの変化を感じ取るのも良いでしょう。
# *   **デジタルで秋を体験:** 焚き火の映像や音、薪ストーブの香りなどをデジタルコンテンツで楽しむのも、現代ならではの五感活用法です。
#
# ## 🎨手軽に楽しむ秋のクラフト＆イベント
#
# 創造的な活動で秋をさらに深く味わいましょう。
# *   **秋の自然でクラフト:** 公園で拾った落ち葉や木の実を使って、リースやガーランド、フォトフレームを制作してみませんか？お子さんと一緒にどんぐりや松ぼっくりで動物を作るのも楽しいですよ。
# *   **アートで秋を表現:** 紅葉や夕焼け、収穫物といった秋の風景をカメラで撮影したり、絵手紙にしたりして、SNSで共有したり大切な人に贈ったりするのも素敵です。
# *   **地域のイベントに参加:** 地域によっては、小規模なマルシェや農産物直売所、収穫祭などが開催されることも。地元の秋の恵みを体験し、コミュニティとの繋がりを感じる良い機会です。
#
# ## 🧡まとめ
#
# 秋は深まるばかり。遠くへ行かなくても、ちょっとした工夫と「五感を意識する」という視点を持つだけで、日々の暮らしの中にたくさんの秋を見つけることができます。デジタルデバイスから少し離れて、全身で秋を感じる「マインドフルネスな秋時間」を過ごしてみましょう。あなたなりの秋の彩りを見つけて、この豊かな季節を心ゆくまで味わってくださいね。
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 記事のレビュー依頼ありがとうございます。
#
# ### 記事の良い点
#
# *   **タイトルの改善:** 40文字程度の条件を満たし、読者が「すぐに読まなきゃ！」と感じる魅力的なタイトルに変更されています。マークダウンヘッダも適切に付与されています。
# *   **導入の追加:** タイトル直後に「なぜいまこのテーマを取り上げるのか」が明確に示され、読者の興味を引きつける動機づけができています。
# *   **サブタイトルの絵文字:** 各セクションのサブタイトルに絵文字が効果的に用いられており、記事全体が親しみやすく、視覚的にも楽しい印象を与えています。
# *   **具体的な実践例の豊富さ:** 「おうちで秋を感じる工夫」「近所で見つける秋の宝物」など、セクションごとに多様な具体例が箇条書きで分かりやすく提示されており、読者が今日から実践できるアイデアが非常に豊富です。
# *   **テーマの一貫性:** 「五感を意識して秋を楽しむ」というテーマが記事全体を通して一貫しており、読者に深い秋の体験を促す内容になっています。
# *   **構成の改善:** 前回のレビューで指摘した「概要」や「最新情報」の内容が、より具体的な実践セクションへと適切に再配置・統合されており、記事の流れが非常にスムーズになりました。
#
# ### 修正ポイント
#
# 今回の修正で記事の条件はすべて満たされており、非常に素晴らしい記事に仕上がっています。あえてさらなる改善点を挙げるとすれば、以下の点です。
#
# *   **「🍂はじめに」セクションの役割の明確化:** タイトル直後の導入文と「🍂はじめに」セクションの内容が、秋の楽しみ方の概要を述べる点でやや重複しているようにも感じられます。導入文で期待感を高め、「🍂はじめに」では記事全体のロードマップを示すなど、それぞれのセクションの役割をより明確にすることで、記事の冒頭がさらに引き締まるかもしれません。ただし、現状でも記事の構成として十分に機能しています。
# #### レビューに基づいて記事の修正を依頼しますか？

# %%
query = '''
これで完成です。完成した記事を表示してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# はい、承知いたしました。完成した記事を表示します。
#
# # 🍁遠出なしで秋を満喫！今日からできる五感活用術
#
# 気づけば日も短くなり、吹く風もどこかひんやり。秋の気配をひしひしと感じるこの頃、「どこか紅葉を見に行きたいけど、なかなか時間が…」なんて思っていませんか？ご安心ください！遠出しなくても、いつもの日常に少し工夫を加えるだけで、五感をフルに使って秋を深く味わうことができるんです。さあ、あなたも今日から「身近な秋」を見つけてみませんか？
#
# ## 🍂はじめに
#
# 秋は、五感を刺激するものがたくさん。実は、自宅や近所のいつもの場所でも、少し意識するだけで豊かな秋を感じることができます。たとえば、お部屋に秋色のクッションやブランケットを取り入れたり、金木犀の香りのアロマを焚いたりするだけで、グッと季節感がアップします。近所の公園や散歩道では、色づいた葉っぱやどんぐり、松ぼっくり探しも楽しいですよね。食卓には、旬のさつまいもや栗、きのこなどを並べて「おうち秋ごはん」を楽しむのも最高です。温かい飲み物片手に読書にふけったり、拾った木の実でクラフトを作ったりと、工夫次第で秋はもっと深く味わえるんですよ。
#
# ## 🏠おうちで秋を感じる工夫
#
# 自宅やベランダは、手軽に秋の雰囲気を取り入れられるプライベートな空間です。
# *   **秋色ファブリックで衣替え:** ボルドー、マスタード、テラコッタといった秋色のブランケットやクッションカバーに変えるだけで、お部屋が暖かく落ち着いた印象になります。
# *   **香りで演出する秋:** 金木犀、りんご、シナモンなどの香りのアロマディフューザーやキャンドルを焚けば、嗅覚から秋を感じられます。
# *   **季節の小物で彩る:** 窓辺にハロウィンモチーフのかぼちゃを置いたり、収穫祭をイメージさせるドライフラワーを飾ったりするのもおすすめです。秋らしい焼き物の食器やマグカップを使うのも良いですね。
#
# ## 🚶‍♀️近所で見つける秋の宝物
#
# 身近な場所でも、秋の自然は豊かに存在しています。いつもの散歩コースも「秋探しコース」に変えてみましょう。
# *   **紅葉・黄葉ハント:** 街路樹や公園の木々が色づき始める様子を観察。イチョウの鮮やかな黄色やモミジの深紅など、樹種による葉の色の違いに注目してみましょう。
# *   **落ち葉＆木の実コレクション:** 地面に目を向ければ、色とりどりの落ち葉やどんぐり、松ぼっくりなどがたくさん。これらを拾い集めるのも楽しいアクティビティです。
# *   **秋の音色に耳を澄ます:** 夕暮れ時に聞こえるコオロギの鳴き声や、風に揺れるススキの音、渡り鳥の姿を探してみるなど、聴覚や視覚で秋を感じてみましょう。
#
# ## 🍽️旬の食材で楽しむ秋の食卓
#
# 秋は食材の宝庫！スーパーでも手軽に旬の味覚が手に入ります。
# *   **「おうち秋ごはん」を楽しむ:** さつまいも、栗、きのこ類、柿、サンマなど、秋の代表的な食材を使った炊き込みご飯やグラタン、ポタージュなど、簡単に作れる秋メニューに挑戦してみましょう。
# *   **季節限定スイーツを味わう:** 栗きんとんやスイートポテト、かぼちゃプリンなど、旬の素材を使った手作りスイーツで贅沢なティータイムを。
# *   **飲み物も秋らしく:** 温かいほうじ茶や和紅茶、ハーブティー、またはホットワインなどは、秋の夜長のリラックスタイムにぴったり。落ち着いた色合いのランチョンマットや小皿で食卓を演出するのも忘れずに。
#
# ## ✨五感を磨くリラックスタイム
#
# 肌寒い秋の季節は、五感を研ぎ澄ましてリラックスするのに最適な時期です。
# *   **インドアで感性を磨く:** 肌触りの良いブランケットにくるまって、読書、音楽鑑賞、映画鑑賞に没頭してみましょう。温かい飲み物をゆっくりと楽しむことで、触覚から秋の心地よさを感じられます。
# *   **アウトドアで深呼吸:** 窓を開けて秋の澄んだ空気を感じたり、風の音や雨の音に耳を傾けたりすることも、感覚を刺激するリラックス法です。早朝や夕暮れ時に散歩して、秋の空の色や土や落ち葉が混じった特有の匂いの変化を感じ取るのも良いでしょう。
# *   **デジタルで秋を体験:** 焚き火の映像や音、薪ストーブの香りなどをデジタルコンテンツで楽しむのも、現代ならではの五感活用法です。
#
# ## 🎨手軽に楽しむ秋のクラフト＆イベント
#
# 創造的な活動で秋をさらに深く味わいましょう。
# *   **秋の自然でクラフト:** 公園で拾った落ち葉や木の実を使って、リースやガーランド、フォトフレームを制作してみませんか？お子さんと一緒にどんぐりや松ぼっくりで動物を作るのも楽しいですよ。
# *   **アートで秋を表現:** 紅葉や夕焼け、収穫物といった秋の風景をカメラで撮影したり、絵手紙にしたりして、SNSで共有したり大切な人に贈ったりするのも素敵です。
# *   **地域のイベントに参加:** 地域によっては、小規模なマルシェや農産物直売所、収穫祭などが開催されることも。地元の秋の恵みを体験し、コミュニティとの繋がりを感じる良い機会です。
#
# ## 🧡まとめ
#
# 秋は深まるばかり。遠くへ行かなくても、ちょっとした工夫と「五感を意識する」という視点を持つだけで、日々の暮らしの中にたくさんの秋を見つけることができます。デジタルデバイスから少し離れて、全身で秋を感じる「マインドフルネスな秋時間」を過ごしてみましょう。あなたなりの秋の彩りを見つけて、この豊かな季節を心ゆくまで味わってくださいね。

# %% [markdown]
# ## root agent を Agent Engine にデプロイ

# %%
class MyClientFactory(ClientFactory):
    def create(self, card, consumers=None, interceptors=None):
        if not self._config.httpx_client:
            self._config.httpx_client=httpx.AsyncClient(
                timeout=60,
                headers={'Content-Type': 'application/json'},
                auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
            )
            self._register_defaults(self._config.supported_transports)
        return super().create(card, consumers, interceptors)


class MyRemoteA2aAgent(RemoteA2aAgent):
    async def _ensure_httpx_client(self):
        if not self._httpx_client:
            self._httpx_client=httpx.AsyncClient(
                timeout=60,
                headers={'Content-Type': 'application/json'},
                auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
            )
        return self._httpx_client


factory = MyClientFactory(
    ClientConfig(
        supported_transports=[TransportProtocol.http_json],
        use_client_preference=True,
    )
)

resource_name = get_agent_resource('research_agent1_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
research_agent1_remoteA2a = MyRemoteA2aAgent(
    name='research_agent1',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('research_agent2_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
research_agent2_remoteA2a = MyRemoteA2aAgent(
    name='research_agent2',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('writer_agent_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
writer_agent_remoteA2a = MyRemoteA2aAgent(
    name='writer_agent',
    description='特定のテーマに関する読み物記事を書くエージェント',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('review_agent_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
review_agent_remoteA2a = MyRemoteA2aAgent(
    name='review_agent',
    description='読み物記事をレビューするエージェント',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

def get_print_agent(text):
    def before_model_callback(
        callback_context: CallbackContext, llm_request: LlmRequest
    ) -> LlmResponse:
        return LlmResponse(
            content=Content(
                role='model', parts=[Part(text=text)],
            )
        )
    return LlmAgent(
        name='print_agent',
        model='gemini-2.0-flash', # not used
        description='',
        instruction = '',
        before_model_callback=before_model_callback,
    )

research_agent = SequentialAgent(
    name='research_agent',
    sub_agents=[
        get_print_agent('\n---\n## リサーチエージェントが調査レポートを作成します。\n---\n'),
        get_print_agent('\n## 調査対象のトピックを選定します。\n'),
        research_agent1_remoteA2a,
        get_print_agent('\n## 選定したトピックに基づいて、調査レポートを作成します。\n'),
        research_agent2_remoteA2a,
        get_print_agent('\n#### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？\n'),
    ],
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント',
)

write_and_review_agent = SequentialAgent(
    name='write_and_review_agent',
    sub_agents=[
        get_print_agent('\n---\n## ライターエージェントが記事を執筆します。\n---\n'),
        writer_agent_remoteA2a,
        get_print_agent('\n---\n## レビューエージェントが記事をレビューします。\n---\n'),
        review_agent_remoteA2a,
       get_print_agent('\n#### レビューに基づいて記事の修正を依頼しますか？\n'),
    ],
    description='記事を作成、レビューする。',
)

root_agent = LlmAgent(
    name='article_generation_flow',
    model='gemini-2.0-flash',
    instruction = '''
何ができるか聞かれた場合は、以下の処理をすることをわかりやすくフレンドリーな文章にまとめて返答してください。

- ユーザーが指定したテーマの記事を作成する業務フローを実行する。
- はじめに、テーマに関する調査レポートを作成する。
- その後、ライターエージェントとレビューエージェントが協力して、編集方針に則した記事を作成する。

ユーザーが記事のテーマを指定した場合は、次のフローを実行します。

1. そのテーマの記事の作成に取り掛かる旨を伝えて、research_agent に転送して、調査レポートを依頼します。
2. ユーザー記事の作成を支持したら、write_and_review_agent に転送して、記事の作成とレビューを依頼します。
3. ユーザーが記事の修正を希望する場合は、write_and_review_agent に転送します。

**条件**
research_agent のニックネームは、リサーチエージェント
write_and_review_agent のネックネームは、ライターエージェントとレビューエージェント

''',
    sub_agents=[
        research_agent,
        write_and_review_agent,
    ],
    description='記事を作成する業務フローを実行するエージェント'
)

adk_app = AdkApp(
    agent=root_agent,
    app_name='article_generation_app',
)
# Out:
# /var/tmp/ipykernel_18646/3698050714.py:33: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent1_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_18646/3698050714.py:42: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent2_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_18646/3698050714.py:51: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   writer_agent_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_18646/3698050714.py:60: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   review_agent_remoteA2a = MyRemoteA2aAgent(
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.

# %%
agent_name = adk_app._tmpl_attrs['agent'].name
description = adk_app._tmpl_attrs['agent'].description

config = {
    'agent_framework': 'google-adk',
    'display_name': agent_name,
    'description': description,
    'requirements': [
        'google-adk==1.27.2',
        'google-genai==1.68.0',
        'google-cloud-aiplatform==1.141.0',
        'a2a-sdk==0.3.25'
    ],
    'staging_bucket': f'gs://{PROJECT_ID}',
}
    
resource_name = get_agent_resource(agent_name)
   
if resource_name is None:
    print(f'Deploying... {agent_name}: {description}')
    remote_app = client.agent_engines.create(
        agent=adk_app,
        config=config,
    )
else:
    print(f'Updating... {agent_name}: {description}')
    remote_app = client.agent_engines.update(
        name=resource_name,
        agent=adk_app,
        config=config,
    )
# Out:
# The following requirements are missing: {'cloudpickle', 'pydantic'}
# Deploying... article_generation_flow: 記事を作成する業務フローを実行するエージェント

# %%
chat_client = ChatClient(remote_app)

query = '''
こんにちは。何ができますか？
'''
response = await chat_client.async_stream_query(query)
# Out:
# こんにちは！私は記事を作成するお手伝いができます。具体的には、以下のことができます。
#
# 1.  **テーマに関する調査レポートの作成:** まず、リサーチエージェントがテーマについて徹底的に調査し、記事作成に必要な情報が詰まったレポートを作成します。
# 2.  **記事の作成とレビュー:** 次に、ライターエージェントとレビューエージェントが協力して、編集方針に沿った高品質な記事を作成します。
#
# ご希望のテーマがあれば教えてください。記事の作成に取り掛かります！

# %%
query = '''
「近場で秋を感じる工夫」をテーマに記事を作成してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。「近場で秋を感じる工夫」というテーマで記事を作成します。
#
# まずは、リサーチエージェントに調査レポートを依頼します。
# ---
# ## リサーチエージェントが調査レポートを作成します。
# ---
# ## 調査対象のトピックを選定します。
# はい、承知いたしました。「近場で秋を感じる工夫」をテーマに、記事作成に必要な調査レポートを作成するためのトピックを選定します。
#
# 以下の5つのトピックについて調査を行い、レポートをまとめます。
#
# ---
#
# ### 「近場で秋を感じる工夫」調査レポートのトピック
#
# 1.  **五感を活用した身近な秋の楽しみ方**:
#     *   **視覚**: 紅葉スポット（街路樹、公園など）、秋の草花（コスモス、金木犀など）、夕焼け、秋らしいインテリアやファッション。
#     *   **聴覚**: 虫の声、風の音、秋をテーマにした音楽。
#     *   **嗅覚**: 金木犀の香り、落ち葉の香り、焼き芋や栗などの秋の味覚の香り、秋用アロマ。
#     *   **味覚**: 旬の食材（栗、芋、きのこ、サンマ、柿など）を使った料理やスイーツ。
#     *   **触覚**: ひんやりとした空気、温かい飲み物、ブランケットなどの肌触り。
# 2.  **自宅やベランダ・庭での秋の演出**:
#     *   秋らしいインテリア（色、素材、小物）、キャンドルやアロマ、ハロウィンなどの飾り付け。
#     *   ベランダガーデニングでの秋の草花育成、収穫。
#     *   庭での落ち葉拾いや焚き火（可能な場合）。
# 3.  **近所の散策や小旅行で秋を見つけるヒント**:
#     *   いつもの散歩道や公園での紅葉・黄葉スポットの発見。
#     *   地域のイベント（収穫祭、マルシェなど）。
#     *   近所のカフェやお店での秋限定メニューやアイテムの探索。
#     *   近郊の少し足を延ばせる範囲での日帰り紅葉狩りや味覚狩り。
# 4.  **秋ならではのアクティビティとアイテム**:
#     *   読書、映画鑑賞、芸術鑑賞（美術館、ギャラリーなど）。
#     *   秋の味覚を使った料理やお菓子作り、ピクニック。
#     *   手芸やクラフト（秋の素材を使ったもの）。
#     *   秋を感じさせるファッションアイテム、温かい飲み物、ブランケット、アロマディフューザーなど。
# 5.  **デジタルツールやオンラインコンテンツを活用した秋の体験**:
#     *   オンラインでのバーチャル紅葉ツアーや秋の風景動画。
#     *   秋をテーマにした音楽プレイリストや映画・ドラマ。
#     *   SNSでの秋の風景や楽しみ方の情報収集と共有。
#
# ---
# ## 選定したトピックに基づいて、調査レポートを作成します。
# ## 「近場で秋を感じる工夫」調査レポート
#
# ### 1. 五感を活用した身近な秋の楽しみ方
#
# 秋は五感を通じて豊かに感じられる季節です。視覚的には、街路樹のイチョウやカエデの黄葉・紅葉は、都市部でも手軽に秋の訪れを感じさせる要素となります。公園や庭園ではコスモスや金木犀が咲き誇り、秋特有の景観を創り出します。聴覚においては、晩夏から秋にかけて鳴く虫の声が、夏の喧騒が去り静けさが増す季節の象徴です。特に金木犀の甘く濃厚な香りは、嗅覚を通じて秋の訪れを最も強く意識させる香りの一つとして知られています。味覚では、栗、さつまいも、きのこ類、サンマ、柿など、多様な旬の食材が食欲をそそり、季節感豊かな食卓を彩ります。触覚としては、朝晩のひんやりとした空気や、温かい飲み物、ブランケットの肌触りなどが、季節の移り変わりを肌で感じさせてくれます。
#
# ### 2. 自宅やベランダ・庭での秋の演出
#
# 自宅空間を秋らしく演出することで、手軽に季節感を楽しむことができます。インテリアには、ボルドーやマスタード、テラコッタといった秋らしい色合いのクッションカバーやラグ、ブランケットなどを取り入れると良いでしょう。木材やウール、フェルトなどの自然素材のアイテムは、温もりと落ち着きを演出し、秋の室内空間に調和します。ベランダガーデニングでは、パンジー、ビオラ、ガーデンマム、ケイトウなど、秋に美しく咲く草花を植えることで、手軽に季節の彩りを楽しむことが可能です。また、ハロウィンのカボチャの飾りや、ドライフラワー、松ぼっくりなどの自然素材のデコレーションも、季節感を高めるのに役立ちます。安全が確保できる場所であれば、庭で小さな焚き火を囲むことは、視覚的な暖かさと共に、独特の香りと音で秋の夜長を満喫する方法の一つです。
#
# ### 3. 近所の散策や小旅行で秋を見つけるヒント
#
# 日常の散歩道や近所の公園も、秋には新たな発見をもたらす場所となります。改めて注意深く観察することで、意外な紅葉・黄葉スポットが見つかることがあります。特にイチョウ並木やカエデの木がある場所は、時期になると美しい色彩を見せるでしょう。秋は収穫の季節であり、多くの地域で農産物のお祭りやマルシェが開催されます。これらの地域イベントは、地元で採れた旬の食材を味わい、地域の文化に触れる良い機会となります。近所のカフェやパン屋、雑貨店などでは、栗やカボチャを使ったスイーツ、温かいドリンク、秋らしいデザインの雑貨など、秋限定のメニューや商品が提供されることがあります。少し足を延ばせる範囲であれば、日帰りでの紅葉狩りや味覚狩り（ぶどう、りんご、みかんなど）も、自然の中でリフレッシュしながら秋の豊かな恵みを直接体験できる有効な手段です。
#
# ### 4. 秋ならではのアクティビティとアイテム
#
# 秋の夜長は、読書や映画鑑賞、芸術鑑賞に最適な季節とされています。静かで落ち着いた環境は、物語の世界に没頭したり、美術館やギャラリーでの企画展を通して芸術に触れたりするのに適しています。秋の旬の食材を使った料理やお菓子作りは、家族や友人と楽しむことができ、食卓を豊かに彩るアクティビティです。美しい紅葉の公園などで行うピクニックは、開放感と自然の美しさを同時に味わえるでしょう。秋の快適さを増すアイテムとしては、温かい飲み物を入れるためのマグカップやタンブラー、肌寒さを感じる季節に活躍するブランケットやひざ掛けが挙げられます。また、金木犀やウッド系の香りのアロマディフューザーは、秋らしい空間を演出するのに役立ちます。
#
# ### 5. デジタルツールやオンラインコンテンツを活用した秋の体験
#
# デジタルツールやオンラインコンテンツを活用することで、手軽に秋の体験を広げることができます。遠隔地の紅葉スポットの様子をライブカメラや高画質の動画で配信しているサービスが多く存在し、自宅に居ながらにして全国各地の美しい秋の風景をバーチャルで体験することが可能です。SpotifyやApple Musicなどの音楽ストリーミングサービスでは、「秋のドライブソング」や「リラックスできる秋の音楽」といったテーマのプレイリストが多数用意されています。秋を舞台にした映画やドラマ、ドキュメンタリーをオンライン配信サービスで鑑賞することも、季節感を味わう手軽な方法です。InstagramやX（旧Twitter）などのSNSは、リアルタイムで秋の風景やイベント情報、おすすめの楽しみ方などを収集するのに非常に有効なツールです。自身が発見した秋の魅力をSNSで発信することで、他者との共感や交流も生まれるでしょう。
# #### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 記事の作成に取り掛かります。ライターエージェントとレビューエージェントに記事の作成とレビューを依頼します。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# 気づけば秋の気配…でも忙しくて遠出は難しいな、なんて思っていませんか？実は、身近な場所でも秋をたっぷり感じられる方法がたくさんあるんです。
#
# ## 身近な秋、どうやって楽しむ？
#
# 秋は五感を豊かに刺激してくれる季節。街路樹の葉が色づいたり、金木犀の甘い香りが漂ってきたり、虫の音が心地よかったり、栗や芋、サンマといった旬の味覚が食欲をそそったり、朝晩のひんやりとした空気に季節の移ろいを感じたり。これらを自宅や近所の散策、さらにはデジタルツールを活用して、手軽に楽しむことができます。自宅のインテリアに秋色を取り入れたり、ベランダで秋の花を育てたりするだけでも、気分はぐっと秋めきますよ。
#
# ## デジタルで広がる秋の世界
#
# 最近では、家から一歩も出ずに全国の美しい秋を満喫する方法も増えています。例えば、ライブカメラや高画質動画で遠方の紅葉スポットをバーチャル体験したり、秋をテーマにした音楽プレイリストを聴いて気分を盛り上げたり。オンライン配信サービスで秋を舞台にした映画やドラマを楽しむのもいいですね。さらに、SNSを活用すれば、リアルタイムでみんなの秋の風景やイベント情報、おすすめの楽しみ方をチェックしたり、自分が見つけた秋の魅力を発信して共有したりもできます。デジタルの力で、秋の楽しみ方は無限大に広がっているんです。
#
# ## 今日からできる！五感で感じる「ご近所秋散歩」のススメ
#
# 特別な場所に行かなくても、いつもの散歩道や近所の公園には、たくさんの秋が隠れています。五感を意識しながら、少しだけ周囲に目を向けてみませんか？
#
# 1.  **視覚**: 街路樹の葉がどんな色に変わっているか、足元に落ちている葉っぱの形や色をじっくり観察してみましょう。公園に咲いているコスモスや金木犀を探すのも楽しいですよ。
# 2.  **嗅覚**: どこからか漂ってくる金木犀の甘い香りや、土や落ち葉の混じった独特の秋の匂いを感じてみてください。
# 3.  **聴覚**: 夏の蝉の声が減り、秋の虫の声や、風が木の葉を揺らす音に耳を澄ませてみましょう。
# 4.  **触覚**: 朝晩のひんやりとした空気や、日中の柔らかい日差しを肌で感じてみてください。
#
# こんな風に五感をフル活用すると、いつもの道がまるで違う景色に見えてくるはずです。
#
# ## 日常の中に、私だけの秋を見つけよう
#
# わざわざ遠くへ出かけなくても、日々の暮らしの中には秋の楽しみが無限に隠されています。五感を研ぎ澄ませて、デジタルも活用しながら、あなただけの秋をぜひ見つけてみてください。きっと、新しい発見や小さな喜びがたくさん見つかるはずですよ！
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# レビューお疲れ様でした。記事の内容は、テーマに沿って具体的なアイデアが豊富に盛り込まれており、読者にとって役立つ情報が多いと感じました。
#
# ### 記事の良い点
#
# *   **具体例が豊富:** 特に「今日からできる！五感で感じる「ご近所秋散歩」のススメ」のセクションでは、視覚、嗅覚、聴覚、触覚それぞれの具体的な楽しみ方が提示されており、読者がすぐに実践しやすい点が素晴らしいです。
# *   **多様な楽しみ方:** 自宅での工夫から、デジタルを活用した秋の体験まで、幅広いアプローチで秋の楽しみ方を紹介しており、読者のライフスタイルに合わせた選択肢を提供しています。
# *   **読者への問いかけ:** 冒頭の「気づけば秋の気配…でも忙しくて遠出は難しいな、なんて思っていませんか？」という問いかけは、読者の共感を呼びやすいです。
#
# ### 修正ポイント
#
# 1.  **タイトル:**
#     *   現在、記事の冒頭部分がタイトルとして機能していますが、**マークダウンヘッダ `#` を使用して、記事の条件に沿ったタイトルを作成**してください。
#     *   タイトルは「今日から役立つ生活情報があって」「すぐに読まなきゃ」と読者が感じるような、**約40文字程度のキャッチーなもの**に調整してください。
#         *   例案: `# 遠出しなくても大丈夫！今日からできる「身近な秋」満喫術7選🍁`
# 2.  **導入文:**
#     *   タイトル直後に「なぜいまこのテーマを取り上げるのか」をまとめた導入文を加えて、読者にこの記事を読む動機づけを与えてください。現在の記事冒頭の「気づけば秋の気配…」の部分をより**「今読むべき理由」が明確になるよう加筆修正し、タイトル直後に配置**しましょう。
#         *   例案: 「秋の訪れを感じつつも、日々の忙しさから遠出が難しいと感じている方も多いのではないでしょうか。しかし、季節の移ろいを身近で感じ取ることは、心に安らぎと活力を与え、日々の生活を豊かにしてくれます。この記事では、わざわざ時間を取らなくても、今日からすぐに実践できる「身近な秋の楽しみ方」を具体的にご紹介します。」
# 3.  **セクションのサブタイトル:**
#     *   **各セクションのサブタイトルに絵文字を追加**して、親しみやすさを出してください。
#         *   例案:
#             *   `🍂身近な秋、どうやって楽しむ？`
#             *   `📱デジタルで広がる秋の世界`
#             *   `🚶‍♀️今日からできる！五感で感じる「ご近所秋散歩」のススメ`
#             *   `✨日常の中に、私だけの秋を見つけよう`
# 4.  **具体例の提示方法の改善（推奨）:**
#     *   既に3つ以上の具体例はありますが、より**箇条書きやリスト形式を活用**することで、読者が実践しやすい具体的な行動がさらに分かりやすくなります。特に「身近な秋、どうやって楽しむ？」のセクションで、インテリアやベランダでの工夫がもう少し明確に箇条書きで示されると良いでしょう。
# #### レビューに基づいて記事の修正を依頼しますか？

# %% [markdown]
# # A2A リモートエージェントを Agent Engine にデプロイする例
#
# このノートブックは、下記の記事のコードを実行したサンプルです。
#
# - [【Agent Engine の A2A 対応記念】A2A リモートエージェントを Agent Engine にデプロイする](https://zenn.dev/google_cloud_jp/articles/04cdf10fb5cd70)

# %% [markdown]
# ## プロジェクト環境の準備

# %% [markdown]
# 新しいプロジェクトを作成したら、Cloud Shell のコマンド端末を開いて、必要な API を有効化します。
#
# ```
# gcloud services enable \
#   aiplatform.googleapis.com \
#   notebooks.googleapis.com \
#   cloudresourcemanager.googleapis.com
# ```
#
# Agent Egnine へのデプロイに必要なサービスアカウントを作成して、IAM ロールを付与しておきます。
#
# ```
# PROJECT_ID=$(gcloud config list --format 'value(core.project)' 2>/dev/null)
# PROJECT_NUMBER=$(gcloud projects describe $PROJECT_ID --format='value(projectNumber)' 2>/dev/null)
# gcloud beta services identity create --service=aiplatform.googleapis.com --project=$PROJECT_ID
# # root agent が A2A agent を呼び出すために必要
# gcloud projects add-iam-policy-binding $PROJECT_ID \
#     --member="serviceAccount:service-${PROJECT_NUMBER}@gcp-sa-aiplatform-re.iam.gserviceaccount.com" \
#     --role='roles/aiplatform.user'
# ```
#
# 続いて、Workbench のインスタンスを作成します。
#
# ```
# PROJECT_ID=$(gcloud config list --format 'value(core.project)' 2>/dev/null)
# gcloud workbench instances create development-instance \
#   --project=$PROJECT_ID \
#   --location=us-central1-a \
#   --machine-type=e2-standard-2
# ```
#
# クラウドコンソールのナビゲーションメニューから「Vertex AI」→「Workbench」を選択すると、作成したインスタンス development-instance があります。インスタンスの起動が完了するのを待って、「JUPYTERLAB を開く」をクリックしたら、「Python 3(ipykernel)」の新規ノートブックを作成します。
#
# この後は、ノートブックのセルでコードを実行していきます。

# %% [markdown]
# ## 環境準備

# %%
# %pip install --user --upgrade \
    google-adk==1.27.2 \
    google-genai==1.68.0 \
    google-cloud-aiplatform==1.141.0 \
    a2a-sdk==0.3.25

# %%
import IPython
app = IPython.Application.instance()
_ = app.kernel.do_shutdown(True)

# %%
import asyncio, datetime, httpx, json, os
from IPython.display import Markdown, display
import google.auth
from google.auth.transport.requests import AuthorizedSession
from google.auth.transport.requests import Request
import vertexai
from vertexai.agent_engines import AdkApp

# ADK
from google.genai.types import Part, Content, HttpOptions
from google.adk.agents.callback_context import CallbackContext
from google.adk.agents.llm_agent import LlmAgent
from google.adk.agents.remote_a2a_agent import RemoteA2aAgent
from google.adk.agents.sequential_agent import SequentialAgent
from google.adk.artifacts import InMemoryArtifactService
from google.adk.auth.credential_service.in_memory_credential_service import InMemoryCredentialService
from google.adk.memory.in_memory_memory_service import InMemoryMemoryService
from google.adk.models import LlmResponse, LlmRequest
from google.adk.runners import Runner
from google.adk.sessions import VertexAiSessionService

# A2A
from a2a.client import ClientConfig, ClientFactory
from a2a.types import AgentCard, TransportProtocol
from google.adk.a2a.executor.a2a_agent_executor import A2aAgentExecutor
from google.adk.a2a.utils.agent_card_builder import AgentCardBuilder

# Agent Engine
from vertexai import agent_engines
from vertexai.preview.reasoning_engines import A2aAgent
from vertexai.preview.reasoning_engines.templates.a2a import create_agent_card

[PROJECT_ID] = !gcloud config list --format 'value(core.project)' 2>/dev/null
[PROJECT_NUMBER] = !gcloud projects describe {PROJECT_ID} --format='value(projectNumber)' 2>/dev/null
LOCATION = 'us-central1'

vertexai.init(project=PROJECT_ID, location=LOCATION)
os.environ['GOOGLE_CLOUD_PROJECT'] = PROJECT_ID
os.environ['GOOGLE_CLOUD_LOCATION'] = LOCATION
os.environ['GOOGLE_GENAI_USE_VERTEXAI'] = 'True'

STAGING_BUCKET = f'gs://{PROJECT_ID}'
# !gsutil ls -b {STAGING_BUCKET} 2>/dev/null || \
 gsutil mb -b on -l {LOCATION} {STAGING_BUCKET}
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# gs://etsuji-15pro-poc/

# %%
class ChatClient:
    def __init__(self, adk_app, user_id='default_user'):
        self.adk_app = adk_app
        self.user_id = user_id
        self.session_id = None

    async def async_stream_query(self, message, show=True):
        if not self.session_id:
            session = await self.adk_app.async_create_session(
                user_id=self.user_id,
            )
            self.session_id = getattr(session, 'id', None) or session['id']

        result = []
        async for event in self.adk_app.async_stream_query(
            user_id=self.user_id,
            session_id=self.session_id,
            message=message,
        ):
            author = event['author']
            if ('content' in event and 'parts' in event['content']):
                response = '\n'.join(
                    [p['text'] for p in event['content']['parts'] if 'text' in p]
                )
                if response:
                    if show:
                        display(Markdown(response))
                    result.append(response)
        return '\n'.join(result)

# %% [markdown]
# ## リモートエージェントの定義

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
指定されたテーマの記事を執筆する際に参考となるトピックを５項目程度のリストにまとめます。
後段のエージェントがこのリストに基づいて、調査レポートを作成します。

* 出力形式
日本語で出力。
'''

research_agent1 = LlmAgent(
    name='research_agent1',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、記事の執筆に必要な情報を収集して調査レポートにまとめる事です。
前段のエージェントは、５項目程度の調査対象トピックを指定します。

* 出力形式
日本語で出力。
調査レポートは、トピックごとに客観的情報をまとめます。各トピックについて、５文以上の長さで記述すること。
'''

research_agent2 = LlmAgent(
    name='research_agent2',
    model='gemini-2.5-flash',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、特定のテーマに関する気軽な読み物記事を書くことです。
記事の「テーマ」と、その内容に関連する「調査レポート」が与えられるので、
調査レポートに記載の客観的事実に基づいて、信頼性のある読み物記事を書いてください。

**出力条件**
- トピックに関してある程度の基礎知識がある読者を前提として、数分で気軽に読める内容にしてください。
- 比較的カジュアルで語りかける口調の文章にします。
- 思考過程は出力せずに、最終結果だけを出力します。
- 記事タイトルは付けないで、次の構成で出力します。各セクションタイトルは、内容に合わせてアレンジしてください。
0. 導入：セクションタイトルを付けないで、この記事を読みたくなる導入を１〜２文にまとめます。
1. 概要：トピックの全体像をまとめて簡単に説明します。
2. 最新情報：特に注目したい新しい情報を取り上げます。
3. 実践：トピックに関して、読者自身がやってみるとよさそうな事を１つ紹介します。
4. まとめ

- 各セクションのタイトルはマークダウンヘッダ ## 付けます。必要に応じて箇条書きのマークダウンを使用します。
- それ以外のマークダウンによる装飾は行いません。

**レビュアーの指示に応じた修正**
- レビュアーが修正ポイントを提示した際は、出力条件にこだわらずに、直前の記事を指示に従って修正してください。
- 修正ポイント以外の部分は、修正する必要ありません。
'''

writer_agent = LlmAgent(
    name='writer_agent',
    model='gemini-2.5-flash',
    description='特定のテーマに関する読み物記事を書くエージェント',
    instruction=instruction,
)

# %%
instruction = '''
あなたの役割は、読み物記事をレビューして、記事の条件にあった内容にするための改善コメントを与える事です。

* 記事の条件
- 記事は、はじめに４０文字程度のタイトルがあること。
　今日から役立つ生活情報があって「すぐに読まなきゃ」と読者が感じるタイトルにすること。
　タイトルはマークダウンヘッダ # をつけること。
- タイトルの直後に「なぜいまこのテーマを取り上げるのか」をまとめた導入を加えて、読者にこの記事を読む動機づけを与えます。
- 各セクションのサブタイトルには、絵文字を用いて親しみやすさを出すこと。
- 読者が今日から実践できる具体例が３つ以上紹介されていること。

* 出力形式
- 日本語で出力。
- はじめに、記事の良い点を説明します。
- 次に、修正ポイントを箇条書きで出力します。
'''

review_agent = LlmAgent(
    name='review_agent',
    model='gemini-2.5-flash',
    description='読み物記事をレビューするエージェント',
    instruction=instruction,
)

# %% [markdown]
# ## Agent Engine へのデプロイ

# %%
client = vertexai.Client(
    project=PROJECT_ID,
    location=LOCATION,
    http_options=HttpOptions(
        api_version='v1beta1',
        base_url=f'https://{LOCATION}-aiplatform.googleapis.com/'
    ),
)

def get_agent_resource(agent_name):
    for agent in client.agent_engines.list():
        if agent.api_resource.display_name == agent_name:
            return agent.api_resource.name
    return None

# %%
class MyVertexAiSessionService(VertexAiSessionService):
    def __init__(self, project_id: str, location: str):
        super().__init__()
        self.project_id = project_id
        self.location = location
        
        credentials, _ = google.auth.default(
            scopes=['https://www.googleapis.com/auth/cloud-platform']
        )
        # AuthorizedSession handles automatic token refreshing and header injection
        self.authed_session = AuthorizedSession(credentials)

    def create_reasoning_engine_session(
        self, 
        reasoning_engine_id: str, 
        user_id: str,
        session_state: dict = {},
        session_id: str = None,
    ):
        """
        Creates a new Reasoning Engine Session via the Vertex AI REST API.
        """
        api_endpoint = f'{self.location}-aiplatform.googleapis.com'
        parent = f'projects/{self.project_id}/locations/{self.location}/reasoningEngines/{reasoning_engine_id}'
        url = f'https://{api_endpoint}/v1beta1/{parent}/sessions'
    
        params = {'sessionId': session_id} if session_id else {}
        session_payload = {
            'userId': user_id,
            'sessionState': session_state,
        }
        print(f'Sending request to: {url}', flush=True)        
        response = self.authed_session.post(url, params=params, json=session_payload)

        if response.status_code == 200:
            print('Success! Operation initiated.', flush=True)
            return response.json()
        else:
            print(f'Failed to create session. HTTP Status: {response.status_code}', flush=True)
            print(f'Error Details: {response.text}', flush=True)
            response.raise_for_status()

    async def create_session(
      self,
      *,
      app_name: str,
      user_id: str,
      state: dict = None,
      session_id: str = None,
      **kwargs,
    ):
        try:
            reasoning_engine_id = self._get_reasoning_engine_id(app_name)

            # Wrap the synchronous requests call in a thread to avoid blocking the async event loop
            operation_result = await asyncio.to_thread(
                self.create_reasoning_engine_session,
                reasoning_engine_id=reasoning_engine_id,
                user_id=user_id,
                session_state=state,
                session_id=session_id,
            )
            print(f'Operation result: {operation_result}', flush=True)
            created_session_id = operation_result['name'].split('/')[7]

            session = None
            max_retries = 3
            for attempt in range(max_retries):
                session = await self.get_session(
                    app_name=app_name,
                    user_id=user_id,
                    session_id=created_session_id,
                )
                if session is not None:
                    break
                print(f'Session not ready yet. Retrying... ({attempt + 1}/{max_retries})', flush=True)
                await asyncio.sleep(2**attempt)
                
            if session is None:
                print(f'Failed to fetch session for session_id={created_session_id} after {max_retries} attempts.', flush=True)                

            print(f'Succeeded to create a session with session_id={session.id}', flush=True)                
            return session

        except Exception as e:
            print(f"An error occurred during session creation: {e}", flush=True)
            return None

# %%
def get_create_runner_class(agent):
    async def create_runner():
        project_id = os.environ.get('GOOGLE_CLOUD_PROJECT')
        location = os.environ.get('GOOGLE_CLOUD_LOCATION')
        agent_engine_id = os.environ.get('GOOGLE_CLOUD_AGENT_ENGINE_ID')
        resource_name = None
        if agent_engine_id:
            resource_name = f'projects/{project_id}/locations/{location}/reasoningEngines/{agent_engine_id}'
        session_service = MyVertexAiSessionService(
            project_id=project_id,
            location=location,
        )
        return Runner(
            # Use resource_name as app_name for VertexAiSessionService.
            app_name=resource_name or agent.name,
            agent=agent,
            artifact_service=InMemoryArtifactService(),
            session_service=session_service,
            memory_service=InMemoryMemoryService(),
            credential_service=InMemoryCredentialService(),
        )
    return create_runner


def get_agent_executor_class(agent):
    def agent_executor_builder():
        return A2aAgentExecutor(
            runner=get_create_runner_class(agent),
        )       
    return agent_executor_builder


async def get_agent_card(agent):
    builder = AgentCardBuilder(agent=agent)
    adk_agent_card = await builder.build()
    return create_agent_card(
        agent_name=adk_agent_card.name,
        description=adk_agent_card.description,
        skills=adk_agent_card.skills
    )

# %%
agents = {
    'research_agent1_a2a': research_agent1,
    'research_agent2_a2a': research_agent2,
    'writer_agent_a2a': writer_agent,
    'review_agent_a2a': review_agent,
}

async def deploy_or_update_agent(agent_name, agent, client, staging_bucket):
    a2a_agent = A2aAgent(
        agent_card=await get_agent_card(agent),
        agent_executor_builder=get_agent_executor_class(agent)
    )

    config = {
        'display_name': agent_name,
        'description': a2a_agent.agent_card.description,
        'requirements': [
            'google-adk==1.27.2',
            'google-genai==1.68.0',
            'google-cloud-aiplatform==1.141.0',
            'a2a-sdk==0.3.25',
        ],
        'staging_bucket': staging_bucket,
        'gcs_dir_name': f'{agent_name}-{datetime.datetime.now().strftime("%Y%m%d-%H%M%S%f")}',
    }

    resource_name = get_agent_resource(agent_name)
    
    if resource_name is None:
        print(f'Deploying... {agent_name}: {agent.description}')
        remote_a2a_agent = await asyncio.to_thread(
            client.agent_engines.create,
            agent=a2a_agent,
            config=config,
        )
    else:
        print(f'Updating... {agent_name}: {agent.description}')
        remote_a2a_agent = await asyncio.to_thread(
            client.agent_engines.update,
            name=resource_name,
            agent=a2a_agent,
            config=config,
        )
        
    return remote_a2a_agent

async def deploy_all_agents():
    tasks = [
        deploy_or_update_agent(agent_name, agent, client, STAGING_BUCKET)
        for agent_name, agent in agents.items()
    ]
    results = await asyncio.gather(*tasks)
    return results

await deploy_all_agents()
# Out:
# /var/tmp/ipykernel_112663/3358268784.py:34: UserWarning: [EXPERIMENTAL] AgentCardBuilder: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   builder = AgentCardBuilder(agent=agent)
# /var/tmp/ipykernel_112663/3358268784.py:34: UserWarning: [EXPERIMENTAL] AgentCardBuilder: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   builder = AgentCardBuilder(agent=agent)
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# Updating... research_agent1_a2a: 記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）
# Updating... research_agent2_a2a: 記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# Updating... writer_agent_a2a: 特定のテーマに関する読み物記事を書くエージェント
# Updating... review_agent_a2a: 読み物記事をレビューするエージェント
# [AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/6599239103097602048'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/5230144816376971264'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/4824820849913626624'),
#  AgentEngine(api_resource.name='projects/879055303739/locations/us-central1/reasoningEngines/8808254720322830336')]

# %% [markdown]
# ## RemoteA2aAgent を用いた root agent の定義

# %%
class GoogleAuthRefresh(httpx.Auth):
    def __init__(self, scopes):
        self.credentials, _ = google.auth.default(scopes=scopes)
        self.transport_request = Request()
        self.credentials.refresh(self.transport_request)

    def auth_flow(self, request):
        if not self.credentials.valid:
            self.credentials.refresh(self.transport_request)
        request.headers['Authorization'] = f'Bearer {self.credentials.token}'
        yield request


factory = ClientFactory(
    ClientConfig(
        supported_transports=[TransportProtocol.http_json],
        use_client_preference=True,
        httpx_client=httpx.AsyncClient(
            timeout=60,
            headers={'Content-Type': 'application/json'},
            auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
        ),
    ),
)

# %%
resource_name = get_agent_resource('research_agent1_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
research_agent1_remote = RemoteA2aAgent(
    name="research_agent1",
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('research_agent2_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
research_agent2_remote = RemoteA2aAgent(
    name="research_agent2",
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('writer_agent_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
writer_agent_remote = RemoteA2aAgent(
    name="writer_agent",
    description='特定のテーマに関する読み物記事を書くエージェント',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('review_agent_a2a')
a2a_url = f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a"
review_agent_remote = RemoteA2aAgent(
    name="review_agent",
    description='読み物記事をレビューするエージェント',
    agent_card=f"{a2a_url}/v1/card",
    a2a_client_factory=factory,
)
# Out:
# /var/tmp/ipykernel_112663/1893291524.py:3: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent1_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_112663/1893291524.py:12: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent2_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_112663/1893291524.py:21: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   writer_agent_remote = RemoteA2aAgent(
# /var/tmp/ipykernel_112663/1893291524.py:30: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   review_agent_remote = RemoteA2aAgent(

# %%
def get_print_agent(text):
    def before_model_callback(
        callback_context: CallbackContext, llm_request: LlmRequest
    ) -> LlmResponse:
        return LlmResponse(
            content=Content(
                role='model', parts=[Part(text=text)],
            )
        )
    return LlmAgent(
        name='print_agent',
        model='gemini-2.5-flash', # not used
        description='',
        instruction = '',
        before_model_callback=before_model_callback,
    )

research_agent = SequentialAgent(
    name='research_agent',
    sub_agents=[
        get_print_agent('\n---\n## リサーチエージェントが調査レポートを作成します。\n---\n'),
        get_print_agent('\n## 調査対象のトピックを選定します。\n'),
        research_agent1_remote,
        get_print_agent('\n## 選定したトピックに基づいて、調査レポートを作成します。\n'),
        research_agent2_remote,
        get_print_agent('\n#### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？\n'),
    ],
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント',
)

write_and_review_agent = SequentialAgent(
    name='write_and_review_agent',
    sub_agents=[
        get_print_agent('\n---\n## ライターエージェントが記事を執筆します。\n---\n'),
        writer_agent_remote,
        get_print_agent('\n---\n## レビューエージェントが記事をレビューします。\n---\n'),
        review_agent_remote,
       get_print_agent('\n#### レビューに基づいて記事の修正を依頼しますか？\n'),
    ],
    description='記事を作成、レビューする。',
)

root_agent = LlmAgent(
    name='article_generation_flow',
    model='gemini-2.5-flash',
    instruction = '''
何ができるか聞かれた場合は、以下の処理をすることをわかりやすくフレンドリーな文章にまとめて返答してください。

- ユーザーが指定したテーマの記事を作成する業務フローを実行する。
- はじめに、テーマに関する調査レポートを作成する。
- その後、ライターエージェントとレビューエージェントが協力して、編集方針に則した記事を作成する。

ユーザーが記事のテーマを指定した場合は、次のフローを実行します。

1. そのテーマの記事の作成に取り掛かる旨を伝えて、research_agent に転送して、調査レポートを依頼します。
2. ユーザー記事の作成を指示したら、write_and_review_agent に転送して、記事の作成とレビューを依頼します。
3. ユーザーが記事の修正を希望する場合は、write_and_review_agent に転送します。

**条件**
research_agent のニックネームは、リサーチエージェント
write_and_review_agent のネックネームは、ライターエージェントとレビューエージェント

''',
    sub_agents=[
        research_agent,
        write_and_review_agent,
    ],
    description='記事を作成する業務フローを実行するエージェント'
)


adk_app = AdkApp(
    agent=root_agent,
    app_name='article_generation_app',
)
# Out:
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.

# %% [markdown]
# ## 実行例

# %%
chat_client = ChatClient(adk_app)

query = '''
こんにちは。何ができますか？
'''
response = await chat_client.async_stream_query(query)
# Out:
# こんにちは！私はあなたの代わりに記事を作成する業務フローを実行できます。具体的には、以下のようなことができます。
#
# *   あなたが指定したテーマの記事を作成します。
# *   まずは、そのテーマに関する調査レポートを作成します。
# *   その後、「ライターエージェント」と「レビューエージェント」が協力して、編集方針に沿った記事を執筆します。
#
# もし記事のテーマを指定していただければ、私が「リサーチエージェント」に調査レポートを依頼し、その後「ライターエージェント」と「レビューエージェント」に記事の作成とレビューを依頼します。記事の修正希望も承りますので、お気軽にお申し付けくださいね。

# %%
query = '''
「近場で秋を感じる工夫」をテーマに記事を作成してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 「近場で秋を感じる工夫」をテーマにした記事の作成に取り掛かりますね。まずは、このテーマに関する調査レポートを「リサーチエージェント」に依頼します。
# ---
# ## リサーチエージェントが調査レポートを作成します。
# ---
# ## 調査対象のトピックを選定します。
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# 'NoneType' object has no attribute 'id'
# ## 選定したトピックに基づいて、調査レポートを作成します。
# ## 調査レポート：近場で秋を感じる工夫
#
# ### 1. 身近な自然で秋を感じる
#
# 公園や庭、街路樹など、日常の風景に潜む秋の要素に注目することで、手軽に季節の移ろいを感じることができます。樹木の葉が緑から黄色、オレンジ、赤へと変化する紅葉は、視覚で秋を感じる代表的な現象であり、イチョウ並木の黄金色やモミジの鮮やかな赤など、植物の種類によって異なる色彩の移ろいを楽しめます。散歩中に足元に落ちる枯れ葉やどんぐり、松ぼっくりなどを拾い集めるのも、秋の訪れを感じる手軽な方法です。近所の植物園や神社仏閣の境内など、手入れされた自然の空間では、より美しい紅葉や秋の花々を鑑賞することができます。早朝や夕暮れ時に散歩することで、秋ならではの澄んだ空気や光の移ろいも体感できるでしょう。
#
# ### 2. 秋の味覚で季節を味わう
#
# 食材を通して秋の訪れを感じることは、日本において古くから親しまれている文化です。サンマ、栗、サツマイモ、キノコ類、柿、梨などが秋を代表する旬の味覚として知られています。これらの食材は、栄養価が高く、収穫の時期が秋に集中しているため、季節感を強く感じさせます。秋の味覚を活かした料理として、栗ご飯、芋煮、キノコ鍋、焼きサンマなどがあり、家庭や飲食店で楽しまれています。温かい飲み物としては、ほうじ茶やチャイ、かぼちゃのラテなども秋らしい風味を提供し、心身を温める効果も期待できます。地元の直売所やスーパーマーケットで旬の食材を選ぶことから、秋の味覚を楽しむ工夫が始まります。
#
# ### 3. 香りで秋を演出する
#
# 金木犀の甘く豊かな香りは、秋の訪れを告げる代表的な香りとして多くの人々に認識されています。落ち葉が腐葉土となる過程で生じる独特の土の香りや、湿った木の香りも秋を感じさせる要素です。自宅では、カボチャやシナモン、クローブなどのスパイス系の香りのアロマディフューザーやキャンドルを使用することで、秋らしい空間を演出できます。紅茶やコーヒー、焼き菓子の香りも、温かみとともに秋の季節感を自宅にもたらす効果があります。自然の中では、森の中の散策で土や木の香りを感じたり、収穫期の果物の甘い香りに触れたりすることで、嗅覚から秋を体感できます。
#
# ### 4. 自宅やインテリアで秋を取り入れる
#
# 自宅のインテリアに秋の色を取り入れることで、簡単に季節感を演出できます。赤、オレンジ、茶色、深緑、ボルドーなどの暖色系のカラーは、秋らしさを表現するのに適しています。クッションカバーやブランケットをウールやフリースなどの温かみのある素材に替えることも、視覚と触覚で秋を感じる方法です。玄関やリビングに、紅葉した枝、ドライフラワー、松ぼっくり、カボチャなどの秋らしい飾りを置くことで、季節の移ろいを表現できます。温かい光を放つ間接照明を取り入れることで、日照時間が短くなる秋の夜長を心地よく過ごす空間を創出できます。手作りのリースやガーランドなども、自宅で秋を感じる個性的な工夫となります。
#
# ### 5. 五感で楽しむ秋の過ごし方
#
# 近所の公園や並木道を散歩することは、視覚（紅葉）、聴覚（虫の声、風の音）、嗅覚（土の匂い、金木犀）、触覚（心地よい風、落ち葉の感触）を刺激し、秋を五感で感じる総合的な体験となります。秋の夜長に温かい飲み物（味覚、嗅覚、触覚）を片手に読書や映画鑑賞を楽しむことも、自宅で秋を感じる豊かな過ごし方です。秋の音楽、例えばクラシック音楽の秋の章や、心落ち着くジャズなどを聴くことで、聴覚から季節の情緒を深めることができます。キャンプやピクニックを近場の公園や河原で行い、秋の空気を感じながら旬の食材を味わうのは、視覚、味覚、嗅覚、触覚が複合的に刺激される体験です。自宅で落ち葉や木の実を使ったリース作りや、秋の食材を使った料理に挑戦するなど、創作活動を通じて秋の素材に触れることも、五感を使った楽しみ方の一つです。
# #### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。調査レポートをもとに、ライターエージェントとレビューエージェントに記事の作成とレビューを依頼します。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# 秋の訪れを感じるヒントは、実はすぐそこに隠されています。ちょっとした工夫で、いつもの日常がもっと豊かになるかもしれませんよ。
#
# ## 近場で秋を感じるって、どういうこと？
#
# 秋の気配は、遠くに出かけなくても意外と身近に転がっています。例えば、いつもの公園の木々が色づき始めたり、スーパーに並ぶ食材が秋めいてきたり。そう、私たちが普段過ごしている場所や家の中で、意識的に「秋」を取り入れる工夫のことなんです。鮮やかな紅葉を眺めたり、旬の美味しいものを味わったり、秋らしい香りに包まれたり。五感をフル活用して、季節の移ろいをゆっくりと感じてみましょう。
#
# ## 身近な「五感の秋」で心豊かに
#
# 最近では、単に目で見るだけでなく、五感をフル活用して季節を感じることが注目されています。例えば、金木犀の甘い香りを求めて散歩に出かけたり、温かいほうじ茶を淹れて読書を楽しんだり。自宅で、カボチャやシナモン系の香りのアロマを焚いてみたり、暖色系のクッションカバーに替えてみるのもいいですね。温かい光の間接照明を取り入れれば、日没が早くなる秋の夜長も心地よく過ごせます。SNSなどで見かけるおしゃれな「秋のしつらえ」も、実は身近な場所で手に入るもので工夫されていることがほとんど。特別なことをしなくても、ちょっとしたアイテムや行動で、日々の暮らしに豊かな彩りを添えることができますよ。
#
# ## 今日からできる！ミニ秋デコレーション
#
# せっかくなら、今日からすぐに秋を感じる工夫を始めてみませんか？一番手軽なのは、お部屋のちょっとしたスペースに秋の飾りを取り入れること。例えば、
#
# *   公園で拾った可愛い松ぼっくりやどんぐり、落ち葉を小瓶に入れる。
# *   スーパーで見つけた小さなカボチャ（観賞用）を玄関に置く。
# *   ドライフラワーや秋色（オレンジ、ブラウン、ボルドーなど）の造花を飾る。
# *   紅葉した枝を一本、花瓶に挿す。
#
# これだけでも、部屋の中にグッと秋らしい雰囲気が漂います。ちょっとしたことですが、目にするたびに季節の移ろいを感じて、心が和みますよ。ぜひ、お気に入りの「秋の欠片」を探してみてくださいね。
#
# ## 秋は、すぐそこに
#
# 秋を感じる工夫は、遠くの観光地に行かなくても、日々の暮らしの中で見つけられます。身近な自然に目を向けたり、旬の食材を味わったり、お気に入りの香りに包まれたり。五感を意識するだけで、何気ない日常が豊かな秋色に染まります。忙しい毎日だからこそ、ちょっと立ち止まって、自分だけの秋を見つけてみませんか。
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 記事のレビュー依頼ありがとうございます。
#
# ### 良い点
#
# *   全体的に、近場で秋を感じるというテーマに沿って、具体的なアイデアが分かりやすく説明されています。
# *   「五感の秋」という視点を取り入れている点がユニークで、読者がより深く秋を感じるきっかけとなるでしょう。
# *   「今日からできる！ミニ秋デコレーション」のセクションでは、実践しやすい具体的な例が複数提示されており、読者がすぐに試せる内容になっている点が素晴らしいです。
# *   文章全体から、秋の穏やかで豊かな雰囲気が伝わってきて、心地よく読める記事です。
#
# ### 修正ポイント
#
# 1.  **タイトルの改善**:
#     *   現在のタイトルは導入文に近いので、40文字程度の短くキャッチーなタイトルに変更し、マークダウンヘッダ `#` を付けてください。
#     *   読者が「すぐに読まなきゃ」と感じるような、お得感や緊急性を感じさせる文言（例：「【必見】」「今日からできる」「知らないと損」など）を盛り込むと良いでしょう。
#     *   例: `# 【今日から変わる！】近場で「最高に美しい秋」を感じる簡単テク5選`
#
# 2.  **導入の強化**:
#     *   タイトルの直後に、「なぜいまこのテーマを取り上げるのか」を明確に伝える導入文を追加してください。読者がこの記事を読む動機付けとなるような、現代のライフスタイル（例: 遠出しづらい、忙しい日常）に寄り添った内容にすると効果的です。
#     *   例: 「忙しい毎日、遠出はなかなか難しいけれど、実は私たちの身近には、美しい秋の気配がたくさん隠れています。この記事では、いつもの日常を豊かに彩る、とっておきの秋の楽しみ方をご紹介します。」
#
# 3.  **サブタイトルへの絵文字追加**:
#     *   各セクションのサブタイトルに絵文字を追加して、記事全体に親しみやすさを出してください。
#     *   例:
#         *   `## 🍂近場で秋を感じるって、どういうこと？`
#         *   `## ✨身近な「五感の秋」で心豊かに`
#         *   `## 🍁今日からできる！ミニ秋デコレーション`
#         *   `## 🌰秋は、すぐそこに`
#
# 4.  **具体例の視覚的な強調**:
#     *   具体例は豊富にありますが、箇条書きをより積極的に使用したり、太字で強調するなどして、読者が「今日から実践できる」ポイントがひと目で分かるように工夫すると、さらに親切な記事になります。
# #### レビューに基づいて記事の修正を依頼しますか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。レビューに基づいて、ライターエージェントに記事の修正を依頼します。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/agents/remote_a2a_agent.py:409: UserWarning: [EXPERIMENTAL] convert_genai_part_to_a2a_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   converted_parts = self._genai_part_converter(part)
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:246: UserWarning: [EXPERIMENTAL] convert_a2a_message_to_event: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   return convert_a2a_message_to_event(
# /home/jupyter/.local/lib/python3.10/site-packages/google/adk/a2a/converters/event_converter.py:316: UserWarning: [EXPERIMENTAL] convert_a2a_part_to_genai_part: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   parts = part_converter(a2a_part)
# # 【今日から変わる！】近場で「最高に美しい秋」を感じる簡単テク5選
#
# 忙しい毎日、遠出はなかなか難しいけれど、実は私たちの身近には、美しい秋の気配がたくさん隠れています。この記事では、いつもの日常を豊かに彩る、とっておきの秋の楽しみ方をご紹介します。
#
# ## 🍂近場で秋を感じるって、どういうこと？
#
# 秋の気配は、遠くに出かけなくても意外と身近に転がっています。例えば、いつもの公園の木々が色づき始めたり、スーパーに並ぶ旬の食材が秋めいてきたり。そう、私たちが普段過ごしている場所や家の中で、意識的に「秋」を取り入れる工夫のことなんです。鮮やかな紅葉を眺めたり、旬の美味しいものを味わったり、秋らしい香りに包まれたり。五感をフル活用して、季節の移ろいをゆっくりと感じてみましょう。
#
# ## ✨身近な「五感の秋」で心豊かに
#
# 最近では、単に目で見るだけでなく、五感をフル活用して季節を感じることが注目されています。例えば、
# *   **金木犀の甘い香り**を求めて散歩に出かける
# *   **温かいほうじ茶**を淹れて読書を楽しむ
# *   自宅で、**カボチャやシナモン系の香りのアロマ**を焚いてみる
# *   **暖色系のクッションカバー**に替えてみる
# *   **温かい光の間接照明**を取り入れることで、日没が早くなる秋の夜長も心地よく過ごせます
#
# SNSなどで見かけるおしゃれな「秋のしつらえ」も、実は身近な場所で手に入るもので工夫されていることがほとんど。特別なことをしなくても、ちょっとしたアイテムや行動で、日々の暮らしに豊かな彩りを添えることができますよ。
#
# ## 🍁今日からできる！ミニ秋デコレーション
#
# せっかくなら、今日からすぐに秋を感じる工夫を始めてみませんか？一番手軽なのは、お部屋のちょっとしたスペースに秋の飾りを取り入れること。例えば、
#
# *   公園で拾った**可愛い松ぼっくりやどんぐり、落ち葉**を小瓶に入れる
# *   スーパーで見つけた**小さなカボチャ（観賞用）**を玄関に置く
# *   **ドライフラワーや秋色（オレンジ、ブラウン、ボルドーなど）の造花**を飾る
# *   **紅葉した枝を一本、花瓶に挿す**
#
# これだけでも、部屋の中にグッと秋らしい雰囲気が漂います。ちょっとしたことですが、目にするたびに季節の移ろいを感じて、心が和みますよ。ぜひ、お気に入りの「秋の欠片」を探してみてくださいね。
#
# ## 🌰秋は、すぐそこに
#
# 秋を感じる工夫は、遠くの観光地に行かなくても、日々の暮らしの中で見つけられます。身近な自然に目を向けたり、旬の食材を味わったり、お気に入りの香りに包まれたり。五感を意識するだけで、何気ない日常が豊かな秋色に染まります。忙しい毎日だからこそ、ちょっと立ち止まって、自分だけの秋を見つけてみませんか。
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# レビュー依頼ありがとうございます。
#
# ### 良い点
#
# *   前回のレビューで指摘した点がすべて完璧に修正されています。
# *   **タイトル**は、読者が「すぐに読まなきゃ」と感じるような魅力的な内容になり、文字数も適切です。
# *   **導入部分**で、なぜ今このテーマを読むべきなのかが明確に提示され、読者の関心を惹きつけます。
# *   **サブタイトル**には親しみやすい絵文字が追加され、視覚的にも記事が読みやすくなりました。
# *   **具体例**は箇条書きと太字で視覚的に強調され、読者が実践しやすい形で提示されています。複数のセクションで実践的なアイデアが豊富に紹介されており、読者がすぐにアクションを起こせる構成です。
# *   全体的に、秋の豊かな情景が浮かび、読者が心地よく季節を感じられる素晴らしい記事に仕上がっています。
#
# ### 修正ポイント
#
# この記事に関して、さらなる修正点はありません。記事の条件をすべて満たしており、完成度の高い内容です。
# #### レビューに基づいて記事の修正を依頼しますか？

# %%
query = '''
これで完成です。完成した記事を表示してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。完成した記事はこちらです。
#
# ---
#
# # 【今日から変わる！】近場で「最高に美しい秋」を感じる簡単テク5選
#
# 忙しい毎日、遠出はなかなか難しいけれど、実は私たちの身近には、美しい秋の気配がたくさん隠れています。この記事では、いつもの日常を豊かに彩る、とっておきの秋の楽しみ方をご紹介します。
#
# ## 🍂近場で秋を感じるって、どういうこと？
#
# 秋の気配は、遠くに出かけなくても意外と身近に転がっています。例えば、いつもの公園の木々が色づき始めたり、スーパーに並ぶ旬の食材が秋めいてきたり。そう、私たちが普段過ごしている場所や家の中で、意識的に「秋」を取り入れる工夫のことなんです。鮮やかな紅葉を眺めたり、旬の美味しいものを味わったり、秋らしい香りに包まれたり。五感をフル活用して、季節の移ろいをゆっくりと感じてみましょう。
#
# ## ✨身近な「五感の秋」で心豊かに
#
# 最近では、単に目で見るだけでなく、五感をフル活用して季節を感じることが注目されています。例えば、
# *   **金木犀の甘い香り**を求めて散歩に出かける
# *   **温かいほうじ茶**を淹れて読書を楽しむ
# *   自宅で、**カボチャやシナモン系の香りのアロマ**を焚いてみる
# *   **暖色系のクッションカバー**に替えてみる
# *   **温かい光の間接照明**を取り入れることで、日没が早くなる秋の夜長も心地よく過ごせます
#
# SNSなどで見かけるおしゃれな「秋のしつらえ」も、実は身近な場所で手に入るもので工夫されていることがほとんど。特別なことをしなくても、ちょっとしたアイテムや行動で、日々の暮らしに豊かな彩りを添えることができますよ。
#
# ## 🍁今日からできる！ミニ秋デコレーション
#
# せっかくなら、今日からすぐに秋を感じる工夫を始めてみませんか？一番手軽なのは、お部屋のちょっとしたスペースに秋の飾りを取り入れること。例えば、
#
# *   公園で拾った**可愛い松ぼっくりやどんぐり、落ち葉**を小瓶に入れる
# *   スーパーで見つけた**小さなカボチャ（観賞用）**を玄関に置く
# *   **ドライフラワーや秋色（オレンジ、ブラウン、ボルドーなど）の造花**を飾る
# *   **紅葉した枝を一本、花瓶に挿す**
#
# これだけでも、部屋の中にグッと秋らしい雰囲気が漂います。ちょっとしたことですが、目にするたびに季節の移ろいを感じて、心が和みますよ。ぜひ、お気に入りの「秋の欠片」を探してみてくださいね。
#
# ## 🌰秋は、すぐそこに
#
# 秋を感じる工夫は、遠くの観光地に行かなくても、日々の暮らしの中で見つけられます。身近な自然に目を向けたり、旬の食材を味わったり、お気に入りの香りに包まれたり。五感を意識するだけで、何気ない日常が豊かな秋色に染まります。忙しい毎日だからこそ、ちょっと立ち止まって、自分だけの秋を見つけてみませんか。
#
# ---

# %% [markdown]
# ## root agent を Agent Engine にデプロイ

# %%
class MyClientFactory(ClientFactory):
    def create(self, card, consumers=None, interceptors=None):
        if not self._config.httpx_client:
            self._config.httpx_client=httpx.AsyncClient(
                timeout=60,
                headers={'Content-Type': 'application/json'},
                auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
            )
            self._register_defaults(self._config.supported_transports)
        return super().create(card, consumers, interceptors)


class MyRemoteA2aAgent(RemoteA2aAgent):
    async def _ensure_httpx_client(self):
        if not self._httpx_client:
            self._httpx_client=httpx.AsyncClient(
                timeout=60,
                headers={'Content-Type': 'application/json'},
                auth=GoogleAuthRefresh(scopes=['https://www.googleapis.com/auth/cloud-platform']) 
            )
        return self._httpx_client


factory = MyClientFactory(
    ClientConfig(
        supported_transports=[TransportProtocol.http_json],
        use_client_preference=True,
    )
)

resource_name = get_agent_resource('research_agent1_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
research_agent1_remoteA2a = MyRemoteA2aAgent(
    name='research_agent1',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（テーマ選定）',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('research_agent2_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
research_agent2_remoteA2a = MyRemoteA2aAgent(
    name='research_agent2',
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント（レポート作成）',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('writer_agent_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
writer_agent_remoteA2a = MyRemoteA2aAgent(
    name='writer_agent',
    description='特定のテーマに関する読み物記事を書くエージェント',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

resource_name = get_agent_resource('review_agent_a2a')
a2a_url = f'https://{LOCATION}-aiplatform.googleapis.com/v1beta1/{resource_name}/a2a'
review_agent_remoteA2a = MyRemoteA2aAgent(
    name='review_agent',
    description='読み物記事をレビューするエージェント',
    agent_card=f'{a2a_url}/v1/card',
    a2a_client_factory=factory,
)

def get_print_agent(text):
    def before_model_callback(
        callback_context: CallbackContext, llm_request: LlmRequest
    ) -> LlmResponse:
        return LlmResponse(
            content=Content(
                role='model', parts=[Part(text=text)],
            )
        )
    return LlmAgent(
        name='print_agent',
        model='gemini-2.5-flash', # not used
        description='',
        instruction = '',
        before_model_callback=before_model_callback,
    )

research_agent = SequentialAgent(
    name='research_agent',
    sub_agents=[
        get_print_agent('\n---\n## リサーチエージェントが調査レポートを作成します。\n---\n'),
        get_print_agent('\n## 調査対象のトピックを選定します。\n'),
        research_agent1_remoteA2a,
        get_print_agent('\n## 選定したトピックに基づいて、調査レポートを作成します。\n'),
        research_agent2_remoteA2a,
        get_print_agent('\n#### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？\n'),
    ],
    description='記事の執筆に必要な情報を収集してレポートにまとめるエージェント',
)

write_and_review_agent = SequentialAgent(
    name='write_and_review_agent',
    sub_agents=[
        get_print_agent('\n---\n## ライターエージェントが記事を執筆します。\n---\n'),
        writer_agent_remoteA2a,
        get_print_agent('\n---\n## レビューエージェントが記事をレビューします。\n---\n'),
        review_agent_remoteA2a,
       get_print_agent('\n#### レビューに基づいて記事の修正を依頼しますか？\n'),
    ],
    description='記事を作成、レビューする。',
)

root_agent = LlmAgent(
    name='article_generation_flow',
    model='gemini-2.5-flash',
    instruction = '''
何ができるか聞かれた場合は、以下の処理をすることをわかりやすくフレンドリーな文章にまとめて返答してください。

- ユーザーが指定したテーマの記事を作成する業務フローを実行する。
- はじめに、テーマに関する調査レポートを作成する。
- その後、ライターエージェントとレビューエージェントが協力して、編集方針に則した記事を作成する。

ユーザーが記事のテーマを指定した場合は、次のフローを実行します。

1. そのテーマの記事の作成に取り掛かる旨を伝えて、research_agent に転送して、調査レポートを依頼します。
2. ユーザー記事の作成を指示したら、write_and_review_agent に転送して、記事の作成とレビューを依頼します。
3. ユーザーが記事の修正を希望する場合は、write_and_review_agent に転送します。

**条件**
research_agent のニックネームは、リサーチエージェント
write_and_review_agent のネックネームは、ライターエージェントとレビューエージェント

''',
    sub_agents=[
        research_agent,
        write_and_review_agent,
    ],
    description='記事を作成する業務フローを実行するエージェント'
)

adk_app = AdkApp(
    agent=root_agent,
    app_name='article_generation_app',
)
# Out:
# /var/tmp/ipykernel_112663/1283827700.py:33: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent1_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_112663/1283827700.py:42: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   research_agent2_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_112663/1283827700.py:51: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   writer_agent_remoteA2a = MyRemoteA2aAgent(
# /var/tmp/ipykernel_112663/1283827700.py:60: UserWarning: [EXPERIMENTAL] RemoteA2aAgent: ADK Implementation for A2A support (A2aAgentExecutor, RemoteA2aAgent and corresponding supporting components etc.) is in experimental mode and is subject to breaking changes. A2A protocol and SDK are themselves not experimental. Once it's stable enough the experimental mode will be removed. Your feedback is welcome.
#   review_agent_remoteA2a = MyRemoteA2aAgent(
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.
# Found duplicate sub-agent names: `print_agent`. All sub-agents must have unique names.

# %%
agent_name = adk_app._tmpl_attrs['agent'].name
description = adk_app._tmpl_attrs['agent'].description

config = {
    'agent_framework': 'google-adk',
    'display_name': agent_name,
    'description': description,
    'requirements': [
        'google-adk==1.27.2',
        'google-genai==1.68.0',
        'google-cloud-aiplatform==1.141.0',
        'a2a-sdk==0.3.25'
    ],
    'staging_bucket': f'gs://{PROJECT_ID}',
    'gcs_dir_name': f'{agent_name}-{datetime.datetime.now().strftime("%Y%m%d-%H%M%S%f")}',
}
    
resource_name = get_agent_resource(agent_name)
   
if resource_name is None:
    print(f'Deploying... {agent_name}: {description}')
    remote_app = client.agent_engines.create(
        agent=adk_app,
        config=config,
    )
else:
    print(f'Updating... {agent_name}: {description}')
    remote_app = client.agent_engines.update(
        name=resource_name,
        agent=adk_app,
        config=config,
    )
# Out:
# The following requirements are missing: {'pydantic', 'cloudpickle'}
# Updating... article_generation_flow: 記事を作成する業務フローを実行するエージェント

# %%
chat_client = ChatClient(remote_app)

query = '''
こんにちは。何ができますか？
'''
response = await chat_client.async_stream_query(query)
# Out:
# こんにちは！私は記事作成の業務フローを実行できます。
#
# 具体的には、以下のようなことができます。
#
# *   ユーザーさんが指定したテーマで記事を作成するための業務フローを実行します。
# *   まず、テーマに関する調査レポートを作成します。この作業は「リサーチエージェント」が担当します。
# *   その後、「ライターエージェント」と「レビューエージェント」が協力して、編集方針に沿った記事を作成します。
#
# 記事のテーマが決まっている場合は、ぜひ教えてくださいね！

# %%
query = '''
「近場で秋を感じる工夫」をテーマに記事を作成してください。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました。「近場で秋を感じる工夫」をテーマにした記事の作成に取り掛かります。まずは、リサーチエージェントがこのテーマに関する調査レポートを作成しますので、少々お待ちください。
# ---
# ## リサーチエージェントが調査レポートを作成します。
# ---
# ## 調査対象のトピックを選定します。
# 「近場で秋を感じる工夫」に関する記事作成のための調査レポート作成にあたり、以下のトピックについて調査を進めます。
#
# 1.  **自宅や室内で秋を取り入れるアイデア**:
#     *   インテリア（秋色のクッション、ブランケット、小物など）
#     *   香り（金木犀、リンゴ、シナモンなどのアロマ、お香）
#     *   BGM（秋らしい音楽、自然音）
#     *   食卓の演出（秋の食材を使った料理、器）
#     *   読書や映画鑑賞など、おうち時間の充実
# 2.  **近所の自然や風景で秋を発見する楽しみ方**:
#     *   公園や路地裏での散歩、紅葉や落ち葉の観察
#     *   どんぐりや木の実拾い、秋の草花探し
#     *   夕焼けや月の鑑賞
#     *   写真撮影のヒント
# 3.  **食で秋を味わう工夫とレシピのヒント**:
#     *   旬の食材（きのこ、さつまいも、栗、柿、秋刀魚など）を使った簡単な料理
#     *   温かい飲み物（チャイ、ココア、ハーブティーなど）
#     *   秋の味覚を使ったスイーツ（大学芋、栗きんとんなど）
#     *   近所のスーパーや八百屋での旬の食材探し
# 4.  **五感を刺激する秋の体験とおすすめのアクティビティ**:
#     *   視覚（紅葉の飾り付け、キャンドルナイト）
#     *   聴覚（虫の音、焚き火の音、雨音）
#     *   嗅覚（金木犀、焼き芋、落ち葉の香り）
#     *   触覚（温かい飲み物、肌触りの良いもの）
#     *   近隣の小さな秋祭り、マルシェ、文化イベントなど
# 5.  **秋の夜長を豊かに過ごす趣味や習慣**:
#     *   読書、映画鑑賞、音楽鑑賞
#     *   手芸、絵画、書き物などクリエイティブな活動
#     *   お風呂でのリラックス、アロマテラピー
#     *   日記や感謝の習慣など内省的な時間
#
# 上記のトピックについて、具体的な情報やアイデアを収集し、レポートにまとめます。
# ## 選定したトピックに基づいて、調査レポートを作成します。
# ## 調査レポート：「近場で秋を感じる工夫」
#
# ### 1. 自宅や室内で秋を取り入れるアイデア
#
# 自宅や室内で秋の訪れを感じるには、インテリア、香り、音、食卓など、様々な側面から工夫を凝らすことができます。例えば、クッションカバーやブランケットをオレンジ、ブラウン、ボルドーといった秋らしい暖色系の色合いや、ウールやコーデュロイのような温かみのある素材に変えることで、視覚的に秋の雰囲気を演出できます。また、金木犀、リンゴとシナモン、パンプキンといった秋を代表する香りのアロマディフューザーやお香を使用することは、嗅覚を通じて空間に深みと季節感をもたらします。さらに、焚き火の音や雨音、クラシックやジャズなどの落ち着いたBGMを取り入れることで、聴覚からもリラックス効果と秋の情緒を感じられます。食卓には、カボチャや栗をモチーフにした食器を取り入れたり、温かいスープや煮込み料理を並べたりすることで、視覚と味覚の両方から秋の恵みを享受することが可能です。このように、身近なアイテムや環境を少し変えるだけで、家の中で快適に秋を感じることができます。
#
# ### 2. 近所の自然や風景で秋を発見する楽しみ方
#
# 近所の公園や庭、時には路地裏にさえ、秋の兆候は隠されています。散歩中に、赤や黄色に色づき始めた木の葉や、地面に落ちた落ち葉の絨毯を観察することは、手軽に秋の風景を楽しむ方法です。また、どんぐりや松ぼっくり、様々な種類の木の実を探したり、コスモスやススキといった秋の草花を見つけたりする活動は、発見の喜びを与えてくれます。夕暮れ時には、空がオレンジや紫に染まる美しい夕焼けや、澄んだ空に浮かぶ月を眺めることで、秋ならではの静かで幻想的な時間を過ごせます。スマートフォンやカメラを持参し、紅葉や落ち葉、夕焼けを写真に収めることで、その瞬間の美しさを記録し、後で振り返る楽しみも生まれます。このように、何気ない日常の風景の中に隠された秋の要素に目を向けることで、新たな発見と喜びを感じることができます。
#
# ### 3. 食で秋を味わう工夫とレシピのヒント
#
# 食卓を通じて秋を深く味わうことは、季節の変化を感じる最も身近で豊かな方法の一つです。きのこ類（しめじ、舞茸、エリンギなど）、さつまいも、栗、柿、秋刀魚といった旬の食材を積極的に取り入れることで、その時期にしか味わえない独特の風味と栄養を楽しむことができます。例えば、さつまいもを使った大学芋や栗を使った栗ごはん、きのこたっぷりのパスタや秋刀魚の塩焼きなどは、手軽に作れて食卓を豊かに彩る秋の代表的な料理です。また、肌寒くなる季節には、チャイ、ホットココア、ハーブティーなどの温かい飲み物をゆっくりと味わうことで、心身ともに温まります。近所のスーパーマーケットや八百屋を訪れ、旬の野菜や果物、魚を実際に手に取って選ぶことも、秋の味覚への期待感を高める体験となります。秋の味覚を存分に楽しむことで、季節の移ろいを五感で感じ取ることができます。
#
# ### 4. 五感を刺激する秋の体験とおすすめのアクティビティ
#
# 五感を意識的に刺激することで、秋の魅力をより深く体験することができます。視覚的には、自宅に紅葉の枝を飾ったり、キャンドルの温かい灯りを楽しんだりすることで、空間に秋の落ち着いた美しさを演出できます。聴覚においては、窓を開けて虫の音に耳を傾けたり、焚き火のパチパチという音や雨が降る音をBGMにしたりすることで、自然の音色がもたらす心地よさを感じられます。嗅覚では、金木犀の甘く上品な香りや、焼き芋の香ばしい匂い、落ち葉が土に還る独特の香りを意識的に吸い込むことで、秋特有の匂いを記憶に留めることができます。触覚では、温かいマグカップを手にしたり、肌触りの良いブランケットに包まれたりすることで、冷え込む秋の快適さを感じることができます。さらに、地域で開催される小さな秋祭りや収穫祭、マルシェなどに足を運ぶことは、地域コミュニティとの繋がりを感じながら、秋の文化や食を体験できる良い機会となります。
#
# ### 5. 秋の夜長を豊かに過ごす趣味や習慣
#
# 日中の時間が短くなり、夜が長くなる秋は、自分自身と向き合い、内面を豊かにするのに最適な季節です。読書、映画鑑賞、音楽鑑賞といったインドアの趣味は、秋の夜長を穏やかに過ごすための定番活動です。特に、温かい飲み物を片手に、心に響く物語や音楽に浸る時間は、日々の疲れを癒し、感性を磨きます。手芸、絵画、書き物など、何かを創造するクリエイティブな活動に取り組むことも、集中力と達成感をもたらし、充実した時間を過ごす助けとなります。また、アロマバスや半身浴で体を温め、リラックス効果のあるアロマオイルを使用するアロマテラピーは、心身のリフレッシュに効果的です。その日の出来事を日記に記したり、感謝したことを書き出したりする内省的な習慣は、自己理解を深め、心の平穏を保つ上で非常に有効です。このように、秋の夜長を自分らしい方法で豊かに過ごすことで、季節の移ろいを慈しみ、心豊かな時間を育むことができます。
# #### 調査レポートが準備できました。記事の作成に取り掛かってもよいでしょうか？

# %%
query = '''
はい。お願いします。
'''
response = await chat_client.async_stream_query(query)
# Out:
# 承知いたしました！調査レポートを元に、ライターエージェントとレビューエージェントが協力して記事の作成とレビューを行います。どうぞよろしくお願いいたします。
# ---
# ## ライターエージェントが記事を執筆します。
# ---
# 最近、めっきり秋を感じる機会が少なくなったな…なんて思っていませんか？実は、ちょっとした工夫で、身近な場所でも秋の訪れをぐっと感じられるようになるんです！
#
# ## 秋はすぐそこに！身近な場所で季節を感じよう
#
# 秋と聞くと、紅葉の名所や遠出をイメージしがちですが、実は私たちの日常生活の中に、秋を感じるヒントがたくさん隠されています。自宅のインテリアに秋色を取り入れたり、旬の食材で食卓を彩ったり、近所を散歩して秋の気配を見つけたり。五感を意識して過ごすことや、秋の夜長を豊かにする過ごし方など、身近な工夫で心穏やかな秋の時間を楽しむことができるんですよ。
#
# ## 五感で味わう、現代の秋の楽しみ方
#
# 特に注目したいのは、デジタル化が進む現代だからこそ意識したい「五感を刺激する秋の体験」です。例えば、自宅で紅葉の枝を飾って視覚で楽しみ、虫の音や焚き火の音をBGMにして聴覚を研ぎ澄ませる。金木犀や焼き芋の香りで嗅覚を刺激し、温かい飲み物や肌触りの良いブランケットで触覚を満たす。意識的に五感を働かせることで、秋の魅力をより深く、より鮮やかに感じ取ることができます。地域によっては小さな秋祭りやマルシェなども開催されるので、情報収集して足を運んでみるのもおすすめです。
#
# ## まずはここから！「おうちで秋」を始めてみよう
#
# せっかくなら、今日からでも「近場で秋を感じる工夫」を始めてみませんか？一番手軽なのは、やっぱり「おうちで秋」を取り入れること。
#
# *   **秋色にチェンジ！**
#     クッションカバーやブランケットを、オレンジ、ブラウン、ボルドーといった秋らしい暖色系や、ウールやコーデュロイなどの温かい素材に変えてみましょう。一気に部屋が秋らしい雰囲気に変わります。
# *   **香りで演出！**
#     金木犀、リンゴとシナモン、パンプキンなどの秋の香りのアロマディフューザーやお香を焚いてみてください。嗅覚から秋の深まりを感じられます。
# *   **BGMでリラックス！**
#     焚き火の音や雨音、クラシックやジャズなど、秋の夜長にぴったりの落ち着いたBGMを流すのもおすすめです。
#
# これらを組み合わせるだけで、いつものお部屋がぐっと秋らしく、心地よい空間に変わるはずです。
#
# ## 日常の中に、自分だけの秋を見つけよう
#
# 秋は、ただ過ぎ去るのを待つだけでなく、自ら見つけに行ける季節です。忙しい毎日の中でも、ちょっと視点を変えるだけで、たくさんの秋が私たちを待っています。ぜひ、この記事で紹介したヒントを参考に、あなたらしい「近場で秋を感じる工夫」を見つけて、今年の秋を心ゆくまで満喫してくださいね。
# ---
# ## レビューエージェントが記事をレビューします。
# ---
# 記事の良い点：
# *   導入部分で「最近、めっきり秋を感じる機会が少なくなったな…なんて思っていませんか？」と読者への問いかけがあり、共感を呼び、記事を読む動機付けがされています。
# *   「おうちで秋」のセクションでは、「秋色にチェンジ！」「香りで演出！」「BGMでリラックス！」と、今日から実践できる具体的な工夫が箇条書きで3つ提示されており、読者にとって非常に分かりやすいです。
# *   「五感を刺激する秋の体験」という視点は、現代のライフスタイルの中で季節を感じる良い提案だと感じました。
#
# 修正ポイント：
#
# *   **タイトル**:
#     *   現在のタイトル「## 秋はすぐそこに！身近な場所で季節を感じよう」（22文字）は、40文字程度の指定を満たしていません。また、「今日から役立つ生活情報があって『すぐに読まなきゃ』と読者が感じる」という条件も、もう少し強調が必要です。
#     *   マークダウンヘッダが`##`となっていますが、記事のタイトルなので`#`に修正してください。
#     *   **改善案の例：** `# 【見落としがち？】今日からできる！忙しいあなたも近場で秋を感じる5つの簡単テク`
# *   **各セクションのサブタイトル**:
#     *   絵文字を用いて親しみやすさを出すという条件が満たされていません。全てのサブタイトルに絵文字を追加してください。
#     *   「五感で味わう、現代の秋の楽しみ方」と「日常の中に、自分だけの秋を見つけよう」のサブタイトルは`##`ですが、「まずはここから！「おうちで秋」を始めてみよう」のサブタイトルは`###`となっており、統一されていません。全てのセクションのサブタイトルレベルを`##`で統一してください。
#     *   **改善案の例：**
#         *   `## 🍁五感で味わう、現代の秋の楽しみ方`
#         *   `## 🏡まずはここから！「おうちで秋」を始めてみよう`
#         *   `## ✨日常の中に、自分だけの秋を見つけよう`
# *   **実践できる具体例**:
#     *   「おうちで秋」のセクションでは3つの具体例が挙げられており、条件を満たしていますが、他のセクションでも読者が今日から実践できる具体的な行動を箇条書きなどで提示すると、さらに記事の価値が高まります。
#     *   特に「五感で味わう、現代の秋の楽しみ方」のセクションは具体的なヒントが多いので、箇条書きにすると分かりやすくなります。
#     *   **改善案の例（「五感で味わう」セクションに追加）：**
#         *   `🍂**近所の散歩で秋探し！** 公園や路地裏を歩いて、色づき始めた木々や落ち葉、どんぐりや木の実を探してみましょう。`
#         *   `🍲**旬の食材で食卓を彩る！** スーパーで秋刀魚、きのこ、さつまいもなどを手に取り、秋の味覚を楽しみましょう。`
#         *   `📚**秋の夜長を趣味で豊かに！** 温かい飲み物を片手に読書や映画鑑賞をしたり、手芸や書き物などクリエイティブな活動を始めてみませんか。`
# #### レビューに基づいて記事の修正を依頼しますか？
